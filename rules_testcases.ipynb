# %% [markdown]
# # Test cases and examples
#
# A. [Specific Procedures](#nodatabase)
#
# 1. [Add an Hypothesis](#addhypothesis)
#
# 2. [Axiom](#axiom)
#
# 2. [Coimplication Elimination](#coimplication_elim)
#
# 3. [Coimplication Introduction](#coimplication_intro)
#
# 4. [Conjunction Elimination](#conjunction_elim)
#
# 5. [Conjunction Introduction](#conjunction_intro)
#
# 2. [Definition](#definition)
#
# 6. [Disjunction Elimination](#disjunction_elim)
#
# 7. [Disjunction Introduction](#disjunction_intro)
#
# 7. [Entailment](#entailment)
#
# 8. [Explosion](#explosion)
#
# 9. [Goal](#goal)
#
# 10. [Hypothesis](#hypothesis)
#
# 11. [Implication Elimination](#implication_elim)
#
# 12. [Implication Introduction](#implication_intro)
#
# 12. [Item](#item)
#
# 13. [Logging Off](#logging_off)
#
# 14. [Logging On](#logging_on)
#
# 14. [Necessary Elimination](#necessary_elim)
#
# 14. [Necessary Introduction](#necessary_intro)
#
# 15. [Negation Elimination](#negation_elim)
#
# 16. [Negation Introduction](#negation_intro)
#
# 16. [Open/Close Subproof](#openclosesubproof)
#
# 16. [Open/Close Strict Subproof](#openclosestrictsubproof)
#
# 16. [Possibly Elimination](#possibly_elim)
#
# 16. [Possibly Introduction](#possibly_intro)
#
# 17. [Premise](#premise)
#
# 18. [Proposition](#proposition)
#
# 18. [Reiterate](#reiterate)
#
# 19. [Rule Help](#rulehelp)
#
# 20. [Set Logic](#setlogic)
#
# 21. [Substitution](#substitution)
#
# 23. [Tautology](#tautology)
#
# B. [Database Processing](#database)
#
# 1. [Create Logic](#addlogic)
#
# 2. [Set logic](#setdblogic)
#
# 3. [Save a proof](#saveproof)
#
# 4. [Use a proof](#useproof)
#
# 5. [Use a rule](#rule)
#
# 5. [Add axiom](#addaxiom)
#
# 6. [Remove axiom](#removeaxiom)
#
# 7. [Add definition](#adddefinition)
#
# 8. [Remove definition](#removedefinition)
#
# 9. [Remove logic](#removelogic)

# %% [markdown]
# <a id='nodatabase'></a>
# # Specific Procedures (No Database)

# %% [markdown]
# <a id='addhypothesis'></a>
# ## Add Hypothesis

# %%
# test_addhypothesis_clean_1

from IPython.display import display, Math, Markdown, Latex, display_markdown, HTML
import pandas as pd
pd.options.display.max_colwidth=500
from altrea.wffs import Implies, Wff, Iff, And
from altrea.rules import Proof

prf = Proof()
A = prf.proposition("A")
B = prf.proposition("B")
C = prf.proposition("C")
prf.setlogic()

prf.goal(B)

prf.opensubproof()
prf.hypothesis(A, comment="Each call to `hypothesis` creates a sub proof.")
prf.opensubproof()
prf.hypothesis(C, comment="Now I have a sub sub proof.")
prf.addhypothesis(B, comment="This adds a second hypothesis.")

display(prf.thisproof())
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th style="text-align:center"></th>
#       <th style="text-align:center">Item</th>
#       <th style="text-align:center">Level</th>
#       <th style="text-align:center">Proof</th>
#       <th style="text-align:center">Rule</th>
#       <th style="text-align:center">Type</th>
#       <th style="text-align:center">Lines</th>
#       <th style="text-align:center">Proofs</th>
#       <th style="text-align:center">Comment</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th style="text-align:center"></th>
#       <td style="text-align:left">$\color{blue}B$</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">GOAL</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#     </tr>
#     <tr>
#       <th style="text-align:center">1</th>
#       <td style="text-align:left">$|\hspace{0.35cm} $$\color{green}A$</td>
#       <td style="text-align:left">1</td>
#       <td style="text-align:left">1</td>
#       <td style="text-align:left">Hypothesis</td>
#       <td style="text-align:left">HYPO</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left">Each call to `hypothesis` creates a sub proof.</td>
#     </tr>
#     <tr>
#       <th style="text-align:center">2</th>
#       <td style="text-align:left">$|\hspace{0.35cm} $$|\hspace{0.35cm} $$\color{green}C$</td>
#       <td style="text-align:left">2</td>
#       <td style="text-align:left">2</td>
#       <td style="text-align:left">Hypothesis</td>
#       <td style="text-align:left">HYPO</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left">Now I have a sub sub proof.</td>
#     </tr>
#     <tr>
#       <th style="text-align:center">3</th>
#       <td style="text-align:left">$|\hspace{0.35cm} $$|\hspace{0.35cm} $$\color{green}B$</td>
#       <td style="text-align:left">2</td>
#       <td style="text-align:left">2</td>
#       <td style="text-align:left">Hypothesis</td>
#       <td style="text-align:left">HYPO</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left">This adds a second hypothesis.</td>
#     </tr>
#   </tbody>
# </table>

# %%
# test_addhypothesis_notwff_1: The proof is stopped if the hypothesis is entered as a string.

from IPython.display import display, Math, Markdown, Latex, display_markdown, HTML
import pandas as pd
pd.options.display.max_colwidth=500
from altrea.wffs import Implies, Wff, Iff, And
from altrea.rules import Proof

prf = Proof()
A = prf.proposition("A")
B = prf.proposition("B")
prf.setlogic()
prf.goal(B, comment='There is a difference between the Wff A and the string "A"')
prf.hypothesis(A)
prf.addhypothesis("~A")

display(prf.thisproof())

# %%
# test_addhypothesis_nosubproof_1:  The proof is stopped if no subproof has been started by a call to hypothesis.

from IPython.display import display, Math, Markdown, Latex, display_markdown, HTML
import pandas as pd
pd.options.display.max_colwidth=500
from altrea.wffs import Implies, Wff, Iff, And, Not
from altrea.rules import Proof

prf = Proof()
A = prf.proposition("A")
B = prf.proposition("B")
prf.setlogic()
prf.goal(B, comment='There is a difference between the Wff A and the string "A"')
# prf.hypothesis(A)
prf.addhypothesis(Not(A))

display(prf.thisproof())

# %% [markdown]
# <a id='axiom'></a>
# ## Axiom

# %%
# test_axiom_contradiction_explosion_1: Clean run of contradiction and explosion

from IPython.display import display, Math, Markdown, Latex, display_markdown, HTML
import pandas as pd
pd.options.display.max_colwidth=500
from altrea.wffs import Implies, Wff, Iff, And, Not
from altrea.rules import Proof

prf = Proof()
prf.setrestricted(False)
B = prf.proposition("B")
C = prf.proposition("C")
prf.setlogic()
prf.goal(B)
prf.entailment(
    And(prf.mvalpha, Not(prf.mvalpha)),
    [], 
    name="contradicting", 
    displayname= "Contradiction", 
    description="Contradiction", 
    kind=prf.label_axiom) 
prf.axiom("contradicting", [C])
prf.rule("conj elim l", [C, Not(C)], [1])
prf.rule("conj elim r", [C, Not(C)], [1])
prf.entailment(
    prf.mvbeta,
    [prf.mvalpha, Not(prf.mvalpha)], 
    name="exploding", 
    displayname= "Explosion", 
    description="Explosion", 
    kind=prf.label_axiom) 
prf.axiom("exploding", [C, B], [2, 3])

display(prf.thisproof())
# Out:
# SAVE AXIOM: The axiom named "contradicting" has been saved.
# SAVE AXIOM: The axiom named "contradicting" has been saved.
# SAVE AXIOM: The axiom named "exploding" has been saved.
# SAVE AXIOM: The axiom named "exploding" has been saved.
#                  Item  Level  Proof                    Rule   Type Lines  \
#       $\color{blue}B$      0      0                    GOAL
# 1  $C \wedge \lnot~C$      0      0           Contradiction  AXIOM
# 2                 $C$      0      0   Conjunction Elim Left   RULE     1
# 3           $\lnot~C$      0      0  Conjunction Elim Right   RULE     1
# 4     $\color{blue}B$      0      0               Explosion  AXIOM  2, 3
#
#   Proofs   Comment
#
# 1
# 2
# 3
# 4         COMPLETE

# %%
# test_axiom_dn_intro_elim_1: Clean run of double negation intro and double negation elim

from IPython.display import display, Math, Markdown, Latex, display_markdown, HTML
import pandas as pd
pd.options.display.max_colwidth=500
from altrea.wffs import Implies, Wff, Iff, And, Not
from altrea.rules import Proof

prf = Proof()
prf.setrestricted(False)
B = prf.proposition("B")
C = prf.proposition("C")
prf.setlogic()
prf.goal(B)
prf.premise(C)
prf.axiom("dneg intro", [prf.item(1)], [1])
prf.axiom("dneg elim", [C], [2])

display(prf.thisproof())
# Out:
#                            Item  Level  Proof      Rule   Type Lines Proofs  \
#                 $\color{blue}B$      0      0      GOAL
# 1              $\color{green}C$      0      0   Premise   PREM
# 2  $\color{green}\lnot~\lnot~C$      0      0  DN Intro  AXIOM     1
# 3              $\color{green}C$      0      0   DN Elim  AXIOM     2
#
#   Comment
#
# 1
# 2
# 3

# %%
# test_axiom_lem_wlem_2: Clean run of law of excluded middle and weak law of excluded middle

from IPython.display import display, Math, Markdown, Latex, display_markdown, HTML
import pandas as pd
pd.options.display.max_colwidth=500
from altrea.wffs import Implies, Wff, Iff, And, Not
from altrea.rules import Proof

prf = Proof()
prf.setrestricted(False)
B = prf.proposition("B")
C = prf.proposition("C")
prf.setlogic()
prf.goal(B)
prf.premise(C)
prf.axiom("lem", [prf.item(1)])
prf.axiom("wlem", [C])

display(prf.thisproof())
# Out:
#                                         Item  Level  Proof      Rule   Type  \
#                              $\color{blue}B$      0      0      GOAL
# 1                           $\color{green}C$      0      0   Premise   PREM
# 2              $\color{green}C \vee \lnot~C$      0      0       LEM  AXIOM
# 3  $\color{green}\lnot~C \vee \lnot~\lnot~C$      0      0  Weak LEM  AXIOM
#
#   Lines Proofs Comment
#
# 1
# 2
# 3

# %%
# test_axiom_modusponens_1: Clean run of modus ponens

from IPython.display import display, Math, Markdown, Latex, display_markdown, HTML
import pandas as pd
pd.options.display.max_colwidth=500
from altrea.wffs import Implies, Wff, Iff, And, Not
from altrea.rules import Proof

prf = Proof()
prf.setrestricted(False)
A = prf.proposition("A")
B = prf.proposition("B")
prf.setlogic()
prf.goal(B)
prf.premise(A)
prf.premise(Implies(A, B))
prf.axiom("modus ponens", [A, B], [1, 2])

display(prf.thisproof())
# Out:
#               Item  Level  Proof          Rule   Type Lines Proofs   Comment
#    $\color{blue}B$      0      0          GOAL
# 1              $A$      0      0       Premise   PREM
# 2   $A \supset  B$      0      0       Premise   PREM
# 3  $\color{blue}B$      0      0  Modus Ponens  AXIOM  1, 2         COMPLETE

# %%
# test_axiom_demorgan_1: Clean run of de morgan laws

from IPython.display import display, Math, Markdown, Latex, display_markdown, HTML
import pandas as pd
pd.options.display.max_colwidth=500
from altrea.wffs import Implies, Wff, Iff, And, Not, Or
from altrea.rules import Proof

prf = Proof()
prf.setrestricted(False)
A = prf.proposition("A")
B = prf.proposition("B")
prf.setlogic()
prf.goal(B)
prf.premise(Or(A, B))
prf.axiom("or to not and", [A, B], [1])
prf.axiom("not and to or", [A, B], [2])
prf.premise(And(A, B))
prf.axiom("and to not or", [A, B], [4])
prf.axiom("not or to and", [A, B], [5])

display(prf.thisproof())
# Out:
#                                     Item  Level  Proof       Rule   Type  \
#                          $\color{blue}B$      0      0       GOAL
# 1                $\color{green}A \vee B$      0      0    Premise   PREM
# 2  $\color{green}\lnot~A \wedge \lnot~B$      0      0  De Morgan  AXIOM
# 3                $\color{green}A \vee B$      0      0  De Morgan  AXIOM
# 4              $\color{green}A \wedge B$      0      0    Premise   PREM
# 5    $\color{green}\lnot~A \vee \lnot~B$      0      0  De Morgan  AXIOM
# 6              $\color{green}A \wedge B$      0      0  De Morgan  AXIOM
#
#   Lines Proofs Comment
#
# 1
# 2     1
# 3     2
# 4
# 5     4
# 6     5

# %%
# test_axiom_restricted_1: Error: trying to run axioms when non are present in restricted mode

from IPython.display import display, Math, Markdown, Latex, display_markdown, HTML
import pandas as pd
pd.options.display.max_colwidth=500
from altrea.wffs import Implies, Wff, Iff, And, Not, Or
from altrea.rules import Proof

prf = Proof()
B = prf.proposition("B")
C = prf.proposition("C")
prf.setlogic()
prf.setrestricted(True)
prf.goal(B)
prf.premise(C)
prf.axiom("dneg intro", [C], [1])
prf.axiom("dneg elim", [C], [2])

display(prf.thisproof())
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th style="text-align:center"></th>
#       <th style="text-align:center">Item</th>
#       <th style="text-align:center">Level</th>
#       <th style="text-align:center">Proof</th>
#       <th style="text-align:center">Rule</th>
#       <th style="text-align:center">Type</th>
#       <th style="text-align:center">Lines</th>
#       <th style="text-align:center">Proofs</th>
#       <th style="text-align:center">Comment</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th style="text-align:center"></th>
#       <td style="text-align:left">$\color{blue}B$</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">GOAL</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#     </tr>
#     <tr>
#       <th style="text-align:center">1</th>
#       <td style="text-align:left">$C$</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">Premise</td>
#       <td style="text-align:left">PREM</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#     </tr>
#     <tr>
#       <th style="text-align:center">2</th>
#       <td style="text-align:left"></td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">dneg intro</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left">STOPPED: The referenced name is not in the axiom list.</td>
#     </tr>
#   </tbody>
# </table>

# %%
# test_axiom_nosuchaxiom_1: Error: no such axiom

from IPython.display import display, Math, Markdown, Latex, display_markdown, HTML
import pandas as pd
pd.options.display.max_colwidth=500
from altrea.wffs import Implies, Wff, Iff, And, Not, Or
from altrea.rules import Proof

prf = Proof()
prf.setrestricted(False)
B = prf.proposition("B")
C = prf.proposition("C")
prf.setlogic()
prf.goal(B)
prf.axiom("r", [C])

display(prf.thisproof())
# Out:
#               Item  Level  Proof  Rule Type Lines Proofs  \
#    $\color{blue}B$      0      0  GOAL
# 1                       0      0     r
#
#                                                   Comment
#
# 1  STOPPED: The referenced name is not in the axiom list.

# %%
# test_axiom_nosubs_1: Error: no substitution values

from IPython.display import display, Math, Markdown, Latex, display_markdown, HTML
import pandas as pd
pd.options.display.max_colwidth=500
from altrea.wffs import Implies, Wff, Iff, And, Not, Or
from altrea.rules import Proof

prf = Proof()
prf.setrestricted(False)
B = prf.proposition("B")
C = prf.proposition("C")
prf.setlogic()
prf.goal(B)
prf.axiom("r", [C])

display(prf.thisproof())
# Out:
#               Item  Level  Proof  Rule Type Lines Proofs  \
#    $\color{blue}B$      0      0  GOAL
# 1                       0      0     r
#
#                                                   Comment
#
# 1  STOPPED: The referenced name is not in the axiom list.

# %%
# test_axiom_premisesdontmatch_1: Error premises don't match.

from IPython.display import display, Math, Markdown, Latex, display_markdown, HTML
import pandas as pd
pd.options.display.max_colwidth=500
from altrea.wffs import Implies, Wff, Iff, And, Not, Or
from altrea.rules import Proof

prf = Proof()
prf.setrestricted(False)
A = prf.proposition("A")
B = prf.proposition("B")
prf.setlogic()
prf.goal(B)
prf.premise(A)
prf.premise(Implies(A, B))
prf.axiom("modus ponens", [B, A], [1, 2])

display(prf.thisproof())
# Out:
#               Item  Level  Proof          Rule  Type Lines Proofs  \
#    $\color{blue}B$      0      0          GOAL
# 1              $A$      0      0       Premise  PREM
# 2   $A \supset  B$      0      0       Premise  PREM
# 3                       0      0  Modus Ponens
#
#                                                                    Comment
#
# 1
# 2
# 3  STOPPED: A required premise does not match a line in the current proof.

# %%
# test_axiom_notwff_1: Error a substitution value is not an instance of altrea.boolean.Wff.

from IPython.display import display, Math, Markdown, Latex, display_markdown, HTML
import pandas as pd
pd.options.display.max_colwidth=500
from altrea.wffs import Implies, Wff, Iff, And, Not, Or
from altrea.rules import Proof

prf = Proof()
prf.setrestricted(False)
A = prf.proposition("A")
B = prf.proposition("B")
prf.setlogic()
prf.goal(B)
prf.premise(A)
prf.premise(Implies(A, B))
prf.axiom("modus ponens", [A, "A"], [1, 2])

display(prf.thisproof())
# Out:
#               Item  Level  Proof          Rule  Type Lines Proofs  \
#    $\color{blue}B$      0      0          GOAL
# 1              $A$      0      0       Premise  PREM
# 2   $A \supset  B$      0      0       Premise  PREM
# 3                       0      0  Modus Ponens
#
#                                                     Comment
#
# 1
# 2
# 3  STOPPED: The input is not an instance of the Wff object.

# %%
# test_axiom_notinteger_1: Error A line number is not an integer.

from IPython.display import display, Math, Markdown, Latex, display_markdown, HTML
import pandas as pd
pd.options.display.max_colwidth=500
from altrea.wffs import Implies, Wff, Iff, And, Not, Or
from altrea.rules import Proof

prf = Proof()
prf = Proof()
prf.setrestricted(False)
A = prf.proposition("A")
B = prf.proposition("B")
prf.setlogic()
prf.goal(B)
prf.premise(A)
prf.premise(Implies(A, B))
prf.axiom("modus ponens", [A, B], [1, 2.1])

display(prf.thisproof())
# Out:
#               Item  Level  Proof          Rule  Type Lines Proofs  \
#    $\color{blue}B$      0      0          GOAL
# 1              $A$      0      0       Premise  PREM
# 2   $A \supset  B$      0      0       Premise  PREM
# 3                       0      0  Modus Ponens         2.1
#
#                                        Comment
#
# 1
# 2
# 3  STOPPED: The line number is not an integer.

# %%
# test_axiom_nosuchline_1: Error A line number is not a previous line of the proof.

from IPython.display import display, Math, Markdown, Latex, display_markdown, HTML
import pandas as pd
pd.options.display.max_colwidth=500
from altrea.wffs import Implies, Wff, Iff, And, Not, Or
from altrea.rules import Proof

prf = Proof()
prf.setrestricted(False)
A = prf.proposition("A")
B = prf.proposition("B")
prf.setlogic()
prf.goal(B)
prf.premise(A)
prf.premise(Implies(A, B))
prf.axiom("modus ponens", [A, B], [3, 2])

display(prf.thisproof())
# Out:
#               Item  Level  Proof          Rule  Type Lines Proofs  \
#    $\color{blue}B$      0      0          GOAL
# 1              $A$      0      0       Premise  PREM
# 2   $A \supset  B$      0      0       Premise  PREM
# 3                       0      0  Modus Ponens           3
#
#                                                              Comment
#
# 1
# 2
# 3  STOPPED: The referenced line is not a previous line of the proof.

# %%
# test_axiom_linescope_1: Error A line number is not in scope.

from IPython.display import display, Math, Markdown, Latex, display_markdown, HTML
import pandas as pd
pd.options.display.max_colwidth=500
from altrea.wffs import Implies, Wff, Iff, And, Not, Or
from altrea.rules import Proof

prf = Proof()
prf.setrestricted(False)
A = prf.proposition("A")
B = prf.proposition("B")
prf.setlogic()

prf.goal(B)

prf.opensubproof()
prf.hypothesis(A)
prf.closesubproof()
prf.implication_intro()
prf.premise(Implies(A, B))
#prf.axiom("modus ponens", [A, B], [1, 3])

prf.displaylog()
display(prf.thisproof())
# Out:
#  1 RESTRICTED: The restricted use of explosion has been set to False.
#  1 PROPOSITION: The letter "A" for a generic well-formed formula has been defined with 1 so far for this proof.
#  1 PROPOSITION: The letter "B" for a generic well-formed formula has been defined with 2 so far for this proof.
#  1 SET LOGIC: "" has been selected as the logic described as "No Description" and stored in database "No Database".
#  1 RESTRICTED: The restricted use of explosion has been set to False.
#  1 GOAL: The goal "B" has been added to the goals.
#  1 OPEN SUBPROOF: Subproof 1 has been opened with status "NORMAL".
#  1 HYPOTHESIS: A new subproof 1 has been started with item "A".
#  2 CLOSE SUBPROOF: The current "NORMAL" subproof 1 has been closed.
#  2 IMPLICATION INTRO: Item "A ⊃ A" has been derived upon closing subproof 1.
#  3 PREMISE: Item "A ⊃ B" has been added to the premises.
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th style="text-align:center"></th>
#       <th style="text-align:center">Item</th>
#       <th style="text-align:center">Level</th>
#       <th style="text-align:center">Proof</th>
#       <th style="text-align:center">Rule</th>
#       <th style="text-align:center">Type</th>
#       <th style="text-align:center">Lines</th>
#       <th style="text-align:center">Proofs</th>
#       <th style="text-align:center">Comment</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th style="text-align:center"></th>
#       <td style="text-align:left">$\color{blue}B$</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">GOAL</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#     </tr>
#     <tr>
#       <th style="text-align:center">1</th>
#       <td style="text-align:left">$|\hspace{0.35cm} $$\color{red}A$</td>
#       <td style="text-align:left">1</td>
#       <td style="text-align:left">1</td>
#       <td style="text-align:left">Hypothesis</td>
#       <td style="text-align:left">HYPO</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#     </tr>
#     <tr>
#       <th style="text-align:center">2</th>
#       <td style="text-align:left">$\color{green}A \supset  A$</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">Implication Intro</td>
#       <td style="text-align:left">TR</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left">1-1</td>
#       <td style="text-align:left"></td>
#     </tr>
#     <tr>
#       <th style="text-align:center">3</th>
#       <td style="text-align:left">$\color{green}A \supset  B$</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">Premise</td>
#       <td style="text-align:left">PREM</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#     </tr>
#   </tbody>
# </table>

# %%
print(prf.subproofavailable)
# Out:
# No

# %% [markdown]
# <a id='coimplication_elim'></a>
# ## Coimplication Elimination

# %%
# test_coimplication_elim_clean_1: Clean run

from IPython.display import display, Math, Markdown, Latex, display_markdown, HTML
import pandas as pd
pd.options.display.max_colwidth=500
from altrea.wffs import Implies, Wff, Iff, And
from altrea.rules import Proof

prf = Proof()
A = prf.proposition('A')
B = prf.proposition('B')
prf.setlogic()
prf.goal(Iff(A, B))
prf.premise(Iff(Implies(A, B), Implies(B, A)))
prf.rule("coimp elim", [prf.item(1).left, prf.item(1).right], [1])

display(prf.thisproof())

# %%
# test_coimplication_elim_nosuchline_1: Line does not exist

from IPython.display import display, Math, Markdown, Latex, display_markdown, HTML
import pandas as pd
pd.options.display.max_colwidth=500
from altrea.wffs import Implies, Wff, Iff, And
from altrea.rules import Proof

prf = Proof()
A = prf.proposition('A')
B = prf.proposition('B')
prf.setlogic()
prf.goal(Iff(A, B))
prf.premise(Iff(Implies(A, B), Implies(B, A)))
prf.rule("coimp elim", [prf.item(1).left, prf.item(1).right], [0])
prf.hypothesis(A, comment="Nothing can be added after the proof is stopped.")

display(prf.thisproof())

# %%
# test_coimplication_elim_linescope_1:  The line is not in scope.

from IPython.display import display, Math, Markdown, Latex, display_markdown, HTML
import pandas as pd
pd.options.display.max_colwidth=500
from altrea.wffs import Implies, Wff, Iff, And
from altrea.rules import Proof

prf = Proof()
A = prf.proposition('A')
B = prf.proposition('B')
prf.setlogic()

prf.goal(Iff(A, B))

prf.opensubproof()
prf.hypothesis(Iff(Implies(A, B), Implies(B, A)))
prf.closesubproof()
prf.implication_intro()
prf.rule("coimp elim", [prf.item(1).left, prf.item(1).right], [1])
prf.hypothesis(A, comment="Nothing can be added after the proof is stopped.")

display(prf.thisproof())
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th style="text-align:center"></th>
#       <th style="text-align:center">Item</th>
#       <th style="text-align:center">Level</th>
#       <th style="text-align:center">Proof</th>
#       <th style="text-align:center">Rule</th>
#       <th style="text-align:center">Type</th>
#       <th style="text-align:center">Lines</th>
#       <th style="text-align:center">Proofs</th>
#       <th style="text-align:center">Comment</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th style="text-align:center"></th>
#       <td style="text-align:left">$\color{blue}A \equiv  B$</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">GOAL</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#     </tr>
#     <tr>
#       <th style="text-align:center">1</th>
#       <td style="text-align:left">$|\hspace{0.35cm} $$(A \supset  B) \equiv  (B \supset  A)$</td>
#       <td style="text-align:left">1</td>
#       <td style="text-align:left">1</td>
#       <td style="text-align:left">Hypothesis</td>
#       <td style="text-align:left">HYPO</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#     </tr>
#     <tr>
#       <th style="text-align:center">2</th>
#       <td style="text-align:left">$((A \supset  B) \equiv  (B \supset  A)) \supset  ((A \supset  B) \equiv  (B \supset  A))$</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">Implication Intro</td>
#       <td style="text-align:left">TR</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left">1-1</td>
#       <td style="text-align:left"></td>
#     </tr>
#     <tr>
#       <th style="text-align:center">3</th>
#       <td style="text-align:left"></td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">Coimplication Elim</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left">1</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left">STOPPED: Referenced item is out of scope.</td>
#     </tr>
#   </tbody>
# </table>

# %%
# test_coimplication_elim_premisesdontmatch_1:  The premises don't match.

from IPython.display import display, Math, Markdown, Latex, display_markdown, HTML
import pandas as pd
pd.options.display.max_colwidth=500
from altrea.wffs import Implies, Wff, Iff, And
from altrea.rules import Proof

prf = Proof()
A = prf.proposition('A')
B = prf.proposition('B')
prf.setlogic()
prf.goal(Iff(A, B))
prf.premise(A)
prf.premise(Iff(Implies(A, B), Implies(B, A)))
prf.rule("coimp elim", [prf.item(2).left, prf.item(2).right], [1])
prf.hypothesis(A, comment="Nothing can be added after the proof is stopped.")

display(prf.thisproof())

# %% [markdown]
# <a id='coimplication_intro'></a>
# ## Coimplication Introduction

# %%
# test_coimplication_intro_clean_1: Clean run

from IPython.display import display, Math, Markdown, Latex, display_markdown, HTML
import pandas as pd
pd.options.display.max_colwidth=500
from altrea.wffs import Implies, Wff, Iff, And
from altrea.rules import Proof

prf = Proof()
A = prf.proposition('A')
B = prf.proposition('B')
prf.setlogic()
prf.goal(Iff(A, B))
prf.premise(And(Implies(A, B), Implies(B, A)))
prf.rule("coimp intro", [A, B], [1])

display(prf.thisproof())

# %%
# test_coimplication_elim_nosuchline_1: First line does not exist in the proof.

from IPython.display import display, Math, Markdown, Latex, display_markdown, HTML
import pandas as pd
pd.options.display.max_colwidth=500
from altrea.wffs import Implies, Wff, Iff
from altrea.rules import Proof

prf = Proof()
A = prf.proposition('A')
B = prf.proposition('B')
prf.setlogic()
prf.goal(Iff(A, B))
prf.premise(And(Implies(A, B), Implies(B, A)))
prf.rule("coimp intro", [A, B], [0])
prf.hypothesis(A, comment="Nothing can be added after the proof is stopped.")

display(prf.thisproof())

# %%
# test_coimplication_intro_linescope_1: First line is not accessible.

from IPython.display import display, Math, Markdown, Latex, display_markdown, HTML
import pandas as pd
pd.options.display.max_colwidth=500
from altrea.wffs import Implies, Wff, Iff
from altrea.rules import Proof

prf = Proof()
A = prf.proposition('A')
B = prf.proposition('B')
prf.setlogic()

prf.goal(Iff(A, B))

prf.opensubproof()
prf.hypothesis(And(Implies(A, B), Implies(B, A)))
prf.closesubproof()
prf.implication_intro()
prf.rule("coimp intro", [A, B], [1])
prf.hypothesis(A, comment="Nothing can be added after the proof is stopped.")

display(prf.thisproof())
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th style="text-align:center"></th>
#       <th style="text-align:center">Item</th>
#       <th style="text-align:center">Level</th>
#       <th style="text-align:center">Proof</th>
#       <th style="text-align:center">Rule</th>
#       <th style="text-align:center">Type</th>
#       <th style="text-align:center">Lines</th>
#       <th style="text-align:center">Proofs</th>
#       <th style="text-align:center">Comment</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th style="text-align:center"></th>
#       <td style="text-align:left">$\color{blue}A \equiv  B$</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">GOAL</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#     </tr>
#     <tr>
#       <th style="text-align:center">1</th>
#       <td style="text-align:left">$|\hspace{0.35cm} $$(A \supset  B) \wedge (B \supset  A)$</td>
#       <td style="text-align:left">1</td>
#       <td style="text-align:left">1</td>
#       <td style="text-align:left">Hypothesis</td>
#       <td style="text-align:left">HYPO</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#     </tr>
#     <tr>
#       <th style="text-align:center">2</th>
#       <td style="text-align:left">$((A \supset  B) \wedge (B \supset  A)) \supset  ((A \supset  B) \wedge (B \supset  A))$</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">Implication Intro</td>
#       <td style="text-align:left">TR</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left">1-1</td>
#       <td style="text-align:left"></td>
#     </tr>
#     <tr>
#       <th style="text-align:center">3</th>
#       <td style="text-align:left"></td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">Coimplication Intro</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left">1</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left">STOPPED: Referenced item is out of scope.</td>
#     </tr>
#   </tbody>
# </table>

# %%
# test_coimplication_elim_premisesdontmatch_1:  The premises don't match.

from IPython.display import display, Math, Markdown, Latex, display_markdown, HTML
import pandas as pd
pd.options.display.max_colwidth=500
from altrea.wffs import Implies, Wff, Iff, And
from altrea.rules import Proof

prf = Proof()
A = prf.proposition('A')
B = prf.proposition('B')
prf.setlogic()
prf.goal(Iff(A, B))
prf.premise(And(Implies(A, B), Implies(B, A)))
prf.premise(A)
prf.rule("coimp intro", [A, B], [2])
prf.hypothesis(A, comment="Nothing can be added after the proof is stopped.")

display(prf.thisproof())

# %% [markdown]
# <a id='conjunction_elim'></a>
# ## Conjunction Elimination

# %%
# test_conjunction_elim_clean_1

from IPython.display import display, Math, Markdown, Latex, display_markdown, HTML
import pandas as pd
pd.options.display.max_colwidth=500
from altrea.wffs import And, Implies, Iff, Wff
from altrea.rules import Proof

prf = Proof()
A = prf.proposition('A')
B = prf.proposition('B')
prf.setlogic()

prf.goal(Iff(And(A, B), And(B, A)))

prf.opensubproof()
prf.hypothesis(And(A, B))
prf.rule('conj elim l', [A, B], [1], comment='The left side is the default.')
prf.rule('conj elim r', [A, B], [1], comment='Now do the right side.')

display(prf.thisproof())
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th style="text-align:center"></th>
#       <th style="text-align:center">Item</th>
#       <th style="text-align:center">Level</th>
#       <th style="text-align:center">Proof</th>
#       <th style="text-align:center">Rule</th>
#       <th style="text-align:center">Type</th>
#       <th style="text-align:center">Lines</th>
#       <th style="text-align:center">Proofs</th>
#       <th style="text-align:center">Comment</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th style="text-align:center"></th>
#       <td style="text-align:left">$\color{blue}(A \wedge B) \equiv  (B \wedge A)$</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">GOAL</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#     </tr>
#     <tr>
#       <th style="text-align:center">1</th>
#       <td style="text-align:left">$|\hspace{0.35cm} $$\color{green}A \wedge B$</td>
#       <td style="text-align:left">1</td>
#       <td style="text-align:left">1</td>
#       <td style="text-align:left">Hypothesis</td>
#       <td style="text-align:left">HYPO</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#     </tr>
#     <tr>
#       <th style="text-align:center">2</th>
#       <td style="text-align:left">$|\hspace{0.35cm} $$\color{green}A$</td>
#       <td style="text-align:left">1</td>
#       <td style="text-align:left">1</td>
#       <td style="text-align:left">Conjunction Elim Left</td>
#       <td style="text-align:left">RULE</td>
#       <td style="text-align:left">1</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left">The left side is the default.</td>
#     </tr>
#     <tr>
#       <th style="text-align:center">3</th>
#       <td style="text-align:left">$|\hspace{0.35cm} $$\color{green}B$</td>
#       <td style="text-align:left">1</td>
#       <td style="text-align:left">1</td>
#       <td style="text-align:left">Conjunction Elim Right</td>
#       <td style="text-align:left">RULE</td>
#       <td style="text-align:left">1</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left">Now do the right side.</td>
#     </tr>
#   </tbody>
# </table>

# %%
# test_conjunction_elim_nosuchline_1:  The line does not exist.

from IPython.display import display, Math, Markdown, Latex, display_markdown, HTML
import pandas as pd
pd.options.display.max_colwidth=500
from altrea.wffs import And, Wff
from altrea.rules import Proof

prf = Proof()
A = prf.proposition("A")
B = prf.proposition("B")
C = prf.proposition("C")
prf.setlogic()
prf.goal(C)
prf.premise(And(A, B))
prf.rule('conj elim l', [A, B], [0])
prf.hypothesis(A, comment="Nothing can be added after the proof is stopped.")
prf.displaylog()

display(prf.thisproof())

# %%
# test_conjunction_elim_linescope_1: The line is not accessible.

from IPython.display import display, Math, Markdown, Latex, display_markdown, HTML
import pandas as pd
pd.options.display.max_colwidth=500
from altrea.wffs import And, Wff
from altrea.rules import Proof

prf = Proof()
A = prf.proposition("A")
B = prf.proposition("B")
C = prf.proposition("C")
prf.setlogic()

prf.goal(C)

prf.opensubproof()
prf.hypothesis(And(A, B))
prf.opensubproof()
prf.hypothesis(C)
prf.rule('conj elim l', [A, B], [1])
prf.hypothesis(A, comment="Nothing can be added after the proof is stopped.")

display(prf.thisproof())
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th style="text-align:center"></th>
#       <th style="text-align:center">Item</th>
#       <th style="text-align:center">Level</th>
#       <th style="text-align:center">Proof</th>
#       <th style="text-align:center">Rule</th>
#       <th style="text-align:center">Type</th>
#       <th style="text-align:center">Lines</th>
#       <th style="text-align:center">Proofs</th>
#       <th style="text-align:center">Comment</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th style="text-align:center"></th>
#       <td style="text-align:left">$\color{blue}C$</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">GOAL</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#     </tr>
#     <tr>
#       <th style="text-align:center">1</th>
#       <td style="text-align:left">$|\hspace{0.35cm} $$A \wedge B$</td>
#       <td style="text-align:left">1</td>
#       <td style="text-align:left">1</td>
#       <td style="text-align:left">Hypothesis</td>
#       <td style="text-align:left">HYPO</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#     </tr>
#     <tr>
#       <th style="text-align:center">2</th>
#       <td style="text-align:left">$|\hspace{0.35cm} $$|\hspace{0.35cm} $$C$</td>
#       <td style="text-align:left">2</td>
#       <td style="text-align:left">2</td>
#       <td style="text-align:left">Hypothesis</td>
#       <td style="text-align:left">HYPO</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#     </tr>
#     <tr>
#       <th style="text-align:center">3</th>
#       <td style="text-align:left"></td>
#       <td style="text-align:left">2</td>
#       <td style="text-align:left">2</td>
#       <td style="text-align:left">Conjunction Elim Left</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left">1</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left">STOPPED: Referenced item is out of scope.</td>
#     </tr>
#   </tbody>
# </table>

# %%
# test_conjunction_elim_premisesdontmatch_1: The line is not a conjunction

from IPython.display import display, Math, Markdown, Latex, display_markdown, HTML
import pandas as pd
pd.options.display.max_colwidth=500
from altrea.wffs import And, Wff
from altrea.rules import Proof

prf = Proof()
A = prf.proposition("A")
C = prf.proposition("C")
prf.setlogic()
prf.goal(C)
prf.premise(A)
prf.rule("conj elim l", [A, C], [1])
prf.hypothesis(A, comment="Nothing can be added after the proof is stopped.")
prf.displaylog()

display(prf.thisproof())

# %% [markdown]
# <a id='conjunction_intro'></a>
# ## Conjunction Introduction

# %%
# test_conjunction_intro_clean_1: Clean run 1.

from IPython.display import display, Math, Markdown, Latex, display_markdown, HTML
import pandas as pd
pd.options.display.max_colwidth=500
from altrea.wffs import And, Wff
from altrea.rules import Proof

prf = Proof()
A = prf.proposition('A')
B = prf.proposition('B')
prf.setlogic()
prf.goal(And(B, A))
prf.premise(A)
prf.premise(B)
prf.rule('conj intro', [prf.item(2), prf.item(1)], [2, 1])
prf.displaylog()

display(prf.thisproof())

# %%
# test_conjunction_intro_clean_2: Clean run 2.

from IPython.display import display, Math, Markdown, Latex, display_markdown, HTML
import pandas as pd
pd.options.display.max_colwidth=500
from altrea.wffs import And, Wff
from altrea.rules import Proof

prf = Proof()
A = prf.proposition('A')
prf.setlogic()
prf.goal(And(A, A))
prf.premise(A)
prf.rule("conj intro", [A, A], [1, 1])

display(prf.thisproof())

# %%
# test_conjunction_intro_nosuchline_1: The first line does not exist in the proof.

from IPython.display import display, Math, Markdown, Latex, display_markdown, HTML
import pandas as pd
pd.options.display.max_colwidth=500
from altrea.wffs import And, Wff
from altrea.rules import Proof

prf = Proof()
A = prf.proposition("A")
B = prf.proposition("B")
prf.setlogic()
prf.goal(And(A, B))
prf.premise(A)
prf.premise(B)
prf.rule("conj intro", [A, B], [3, 2])

display(prf.thisproof())

# %%
# test_conjunction_intro_nosuchline_2: The second line does not exist in the proof.

from IPython.display import display, Math, Markdown, Latex, display_markdown, HTML
import pandas as pd
pd.options.display.max_colwidth=500
from altrea.wffs import And, Wff
from altrea.rules import Proof

prf = Proof()
A = prf.proposition("A")
B = prf.proposition("B")
prf.setlogic()
prf.goal(And(A, B))
prf.premise(A)
prf.premise(B)
prf.rule("conj intro", [A, B], [1, 3])
prf.hypothesis(A, comment="Nothing can be added after the proof is stopped.")

display(prf.thisproof())

# %%
# test_conjunction_elim_linescope_1:  The first line is not accessible.

from IPython.display import display, Math, Markdown, Latex, display_markdown, HTML
import pandas as pd
pd.options.display.max_colwidth=500
from altrea.wffs import And, Wff
from altrea.rules import Proof

prf = Proof()
A = prf.proposition("A")
B = prf.proposition("B")
prf.setlogic()

prf.goal(And(A, B))

prf.opensubproof()
prf.hypothesis(A)
prf.opensubproof()
prf.hypothesis(B)
prf.rule("conj intro", [A, B], [1, 2])
prf.hypothesis(A, comment="Nothing can be added after the proof is stopped.")

display(prf.thisproof())
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th style="text-align:center"></th>
#       <th style="text-align:center">Item</th>
#       <th style="text-align:center">Level</th>
#       <th style="text-align:center">Proof</th>
#       <th style="text-align:center">Rule</th>
#       <th style="text-align:center">Type</th>
#       <th style="text-align:center">Lines</th>
#       <th style="text-align:center">Proofs</th>
#       <th style="text-align:center">Comment</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th style="text-align:center"></th>
#       <td style="text-align:left">$\color{blue}A \wedge B$</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">GOAL</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#     </tr>
#     <tr>
#       <th style="text-align:center">1</th>
#       <td style="text-align:left">$|\hspace{0.35cm} $$A$</td>
#       <td style="text-align:left">1</td>
#       <td style="text-align:left">1</td>
#       <td style="text-align:left">Hypothesis</td>
#       <td style="text-align:left">HYPO</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#     </tr>
#     <tr>
#       <th style="text-align:center">2</th>
#       <td style="text-align:left">$|\hspace{0.35cm} $$|\hspace{0.35cm} $$B$</td>
#       <td style="text-align:left">2</td>
#       <td style="text-align:left">2</td>
#       <td style="text-align:left">Hypothesis</td>
#       <td style="text-align:left">HYPO</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#     </tr>
#     <tr>
#       <th style="text-align:center">3</th>
#       <td style="text-align:left"></td>
#       <td style="text-align:left">2</td>
#       <td style="text-align:left">2</td>
#       <td style="text-align:left">Conjunction Intro</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left">1</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left">STOPPED: Referenced item is out of scope.</td>
#     </tr>
#   </tbody>
# </table>

# %%
# test_conjunction_elim_linescope_2

from IPython.display import display, Math, Markdown, Latex, display_markdown, HTML
import pandas as pd
pd.options.display.max_colwidth=500
from altrea.wffs import And, Wff
from altrea.rules import Proof

prf = Proof()
A = prf.proposition("A")
B = prf.proposition("B")
prf.setlogic()

prf.goal(And(A, B))

prf.opensubproof()
prf.hypothesis(A)
prf.opensubproof()
prf.hypothesis(B)
prf.rule("conj intro", [A, B], [2, 1])
prf.hypothesis(A, comment="Nothing can be added after the proof is stopped.")

display(prf.thisproof())
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th style="text-align:center"></th>
#       <th style="text-align:center">Item</th>
#       <th style="text-align:center">Level</th>
#       <th style="text-align:center">Proof</th>
#       <th style="text-align:center">Rule</th>
#       <th style="text-align:center">Type</th>
#       <th style="text-align:center">Lines</th>
#       <th style="text-align:center">Proofs</th>
#       <th style="text-align:center">Comment</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th style="text-align:center"></th>
#       <td style="text-align:left">$\color{blue}A \wedge B$</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">GOAL</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#     </tr>
#     <tr>
#       <th style="text-align:center">1</th>
#       <td style="text-align:left">$|\hspace{0.35cm} $$A$</td>
#       <td style="text-align:left">1</td>
#       <td style="text-align:left">1</td>
#       <td style="text-align:left">Hypothesis</td>
#       <td style="text-align:left">HYPO</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#     </tr>
#     <tr>
#       <th style="text-align:center">2</th>
#       <td style="text-align:left">$|\hspace{0.35cm} $$|\hspace{0.35cm} $$B$</td>
#       <td style="text-align:left">2</td>
#       <td style="text-align:left">2</td>
#       <td style="text-align:left">Hypothesis</td>
#       <td style="text-align:left">HYPO</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#     </tr>
#     <tr>
#       <th style="text-align:center">3</th>
#       <td style="text-align:left"></td>
#       <td style="text-align:left">2</td>
#       <td style="text-align:left">2</td>
#       <td style="text-align:left">Conjunction Intro</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left">1</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left">STOPPED: Referenced item is out of scope.</td>
#     </tr>
#   </tbody>
# </table>

# %%
# test_conjunction_intro_premiseslengthsdontmatch_1 

from IPython.display import display, Math, Markdown, Latex, display_markdown, HTML
import pandas as pd
pd.options.display.max_colwidth=500
from altrea.wffs import And, Wff
from altrea.rules import Proof

prf = Proof()
A = prf.proposition("A")
B = prf.proposition("B")
prf.setlogic()
prf.goal(And(A, B))
prf.hypothesis(A)
prf.hypothesis(B)
prf.rule("conj intro", [A, B], [])
prf.hypothesis(A, comment="Nothing can be added after the proof is stopped.")

display(prf.thisproof())
# Out:
#                                     Item  Level  Proof               Rule  \
#                 $\color{blue}A \wedge B$      0      0               GOAL
# 1                   $A \hspace{0.35cm}|$      1      1         Hypothesis
# 2  $B \hspace{0.35cm}| \hspace{0.35cm}|$      2      2         Hypothesis
# 3                                             2      2  Conjunction Intro
#
#    Type Lines Proofs  \
#
# 1  HYPO
# 2  HYPO
# 3
#
#                                                      Comment
#
# 1
# 2
# 3  STOPPED: The number of premises do not match the pattern.

# %% [markdown]
# <a id='definition'></a>
# ## Definition

# %%
# test_definition_iff_1: Clean run of coimpliction intro and elim as definitions

from IPython.display import display, Math, Markdown, Latex, display_markdown, HTML
import pandas as pd
pd.options.display.max_colwidth=500
from altrea.wffs import And, Wff
from altrea.rules import Proof

prf = Proof()
prf.setrestricted(False)
A = prf.proposition('A')
B = prf.proposition('B')
prf.setlogic()
prf.goal(B)
prf.premise(Implies(A, B))
prf.premise(Implies(B, A))
prf.rule("conj intro", [prf.item(1), prf.item(2)], [1, 2])
prf.definition('iff intro', [A, B], [3])
prf.definition('iff elim', [A, B], [4])

display(prf.thisproof())
# Out:
#                                                   Item  Level  Proof  \
#                                        $\color{blue}B$      0      0
# 1                          $\color{green}A \supset  B$      0      0
# 2                          $\color{green}B \supset  A$      0      0
# 3  $\color{green}(A \supset  B) \wedge (B \supset  A)$      0      0
# 4                           $\color{green}A \equiv  B$      0      0
# 5  $\color{green}(A \supset  B) \wedge (B \supset  A)$      0      0
#
#                 Rule  Type Lines Proofs Comment
#                 GOAL
# 1            Premise  PREM
# 2            Premise  PREM
# 3  Conjunction Intro  RULE  1, 2
# 4          Iff Intro   DEF     3
# 5           Iff Elim   DEF     4

# %%
# test_definition_restricted_1: Error: restriction set to true, so no definitions are available

from IPython.display import display, Math, Markdown, Latex, display_markdown, HTML
import pandas as pd
pd.options.display.max_colwidth=500
from altrea.wffs import And, Wff
from altrea.rules import Proof

prf = Proof()
prf.setrestricted(True)
A = prf.proposition('A')
B = prf.proposition('B')
prf.setlogic()
prf.goal(B)
prf.premise(Implies(A, B))
prf.premise(Implies(B, A))
prf.rule("conj intro", [prf.item(1), prf.item(2)], [1, 2])
prf.definition('iff intro', [A, B], [3])
prf.definition('iff elim', [A, B], [4])

display(prf.thisproof())
# Out:
#                                      Item  Level  Proof               Rule  \
#                           $\color{blue}B$      0      0               GOAL
# 1                          $A \supset  B$      0      0            Premise
# 2                          $B \supset  A$      0      0            Premise
# 3  $(A \supset  B) \wedge (B \supset  A)$      0      0  Conjunction Intro
# 4                                              0      0          iff intro
#
#    Type Lines Proofs  \
#
# 1  PREM
# 2  PREM
# 3  RULE  1, 2
# 4
#
#                                                        Comment
#
# 1
# 2
# 3
# 4  STOPPED: The referenced name is not in the definition list.

# %%
# test_definition_premisesdontmatch_1: Error: Order of substitues is incorrrect

from IPython.display import display, Math, Markdown, Latex, display_markdown, HTML
import pandas as pd
pd.options.display.max_colwidth=500
from altrea.wffs import And, Wff
from altrea.rules import Proof

prf = Proof()
A = prf.proposition('A')
B = prf.proposition('B')
prf.setlogic()
prf.setrestricted(False)
prf.goal(B)
prf.premise(Implies(A, B))
prf.premise(Implies(B, A))
prf.rule("conj intro", [prf.item(1), prf.item(2)], [1, 2])
prf.definition('iff intro', [B, A], [3])

display(prf.thisproof())
# Out:
#                                      Item  Level  Proof               Rule  \
#                           $\color{blue}B$      0      0               GOAL
# 1                          $A \supset  B$      0      0            Premise
# 2                          $B \supset  A$      0      0            Premise
# 3  $(A \supset  B) \wedge (B \supset  A)$      0      0  Conjunction Intro
# 4                                              0      0          Iff Intro
#
#    Type Lines Proofs  \
#
# 1  PREM
# 2  PREM
# 3  RULE  1, 2
# 4
#
#                                                                    Comment
#
# 1
# 2
# 3
# 4  STOPPED: A required premise does not match a line in the current proof.

# %%
# test_definition_premiseslengthsdontmatch_2: Error: Required premises were not covered by lines of the proof.

from IPython.display import display, Math, Markdown, Latex, display_markdown, HTML
import pandas as pd
pd.options.display.max_colwidth=500
from altrea.wffs import And, Wff, Implies
from altrea.rules import Proof

prf = Proof()
A = prf.proposition('A')
B = prf.proposition('B')
prf.setlogic()
prf.setrestricted(False)
prf.goal(B)
prf.premise(Implies(A, B))
prf.premise(Implies(B, A))
prf.rule("conj intro", [prf.item(1), prf.item(2)], [1, 2])
prf.definition('iff intro', [A, B], [])

display(prf.thisproof())
# Out:
#                                      Item  Level  Proof               Rule  \
#                           $\color{blue}B$      0      0               GOAL
# 1                          $A \supset  B$      0      0            Premise
# 2                          $B \supset  A$      0      0            Premise
# 3  $(A \supset  B) \wedge (B \supset  A)$      0      0  Conjunction Intro
# 4                                              0      0          Iff Intro
#
#    Type Lines Proofs  \
#
# 1  PREM
# 2  PREM
# 3  RULE  1, 2
# 4
#
#                                                      Comment
#
# 1
# 2
# 3
# 4  STOPPED: The number of premises do not match the pattern.

# %%
# test_definition_nosubs_1: Error: Lack of substitutes

from IPython.display import display, Math, Markdown, Latex, display_markdown, HTML
import pandas as pd
pd.options.display.max_colwidth=500
from altrea.wffs import And, Wff
from altrea.rules import Proof

prf = Proof()
A = prf.proposition('A')
B = prf.proposition('B')
prf.setlogic()
prf.setrestricted(False)
prf.goal(B)
prf.premise(Implies(A, B))
prf.premise(Implies(B, A))
prf.rule("conj intro", [prf.item(1), prf.item(2)], [1, 2])
prf.definition('iff intro', [], [3])

display(prf.thisproof())
# Out:
#                                      Item  Level  Proof               Rule  \
#                           $\color{blue}B$      0      0               GOAL
# 1                          $A \supset  B$      0      0            Premise
# 2                          $B \supset  A$      0      0            Premise
# 3  $(A \supset  B) \wedge (B \supset  A)$      0      0  Conjunction Intro
# 4                                              0      0          Iff Intro
#
#    Type Lines Proofs                                        Comment
#
# 1  PREM
# 2  PREM
# 3  RULE  1, 2
# 4                     STOPPED: There were no substitutions entered.

# %%
# test_definition_notwff_1: Error: Not an instance of altrea.boolean.Wff.

from IPython.display import display, Math, Markdown, Latex, display_markdown, HTML
import pandas as pd
pd.options.display.max_colwidth=500
from altrea.wffs import And, Wff
from altrea.rules import Proof

prf = Proof()
prf.setrestricted(False)
A = prf.proposition('A')
B = prf.proposition('B')
prf.setlogic()
prf.goal(B)
prf.premise(Implies(A, B))
prf.premise(Implies(B, A))
prf.rule("conj intro", [prf.item(1), prf.item(2)], [1, 2])
prf.definition('iff intro', ['A', 'B'], [3])

display(prf.thisproof())
# Out:
#                                      Item  Level  Proof               Rule  \
#                           $\color{blue}B$      0      0               GOAL
# 1                          $A \supset  B$      0      0            Premise
# 2                          $B \supset  A$      0      0            Premise
# 3  $(A \supset  B) \wedge (B \supset  A)$      0      0  Conjunction Intro
# 4                                              0      0          Iff Intro
#
#    Type Lines Proofs                                                   Comment
#
# 1  PREM
# 2  PREM
# 3  RULE  1, 2
# 4                     STOPPED: The input is not an instance of the Wff object.

# %%
# test_definition_notinteger_1: Error: Referenced line is not an integer.

from IPython.display import display, Math, Markdown, Latex, display_markdown, HTML
import pandas as pd
pd.options.display.max_colwidth=500
from altrea.wffs import And, Wff
from altrea.rules import Proof

prf = Proof()
prf.setrestricted(False)
A = prf.proposition('A')
B = prf.proposition('B')
prf.setlogic()
prf.goal(B)
prf.premise(Implies(A, B))
prf.premise(Implies(B, A))
prf.rule("conj intro", [prf.item(1), prf.item(2)], [1, 2])
prf.definition('iff intro', [A, B], [-3.14])

display(prf.thisproof())
# Out:
#                                      Item  Level  Proof               Rule  \
#                           $\color{blue}B$      0      0               GOAL
# 1                          $A \supset  B$      0      0            Premise
# 2                          $B \supset  A$      0      0            Premise
# 3  $(A \supset  B) \wedge (B \supset  A)$      0      0  Conjunction Intro
# 4                                              0      0          Iff Intro
#
#    Type  Lines Proofs                                      Comment
#
# 1  PREM
# 2  PREM
# 3  RULE   1, 2
# 4        -3.14         STOPPED: The line number is not an integer.

# %%
# test_definition_nosuchline_1: Error: Referenced line is not in the proof.

from IPython.display import display, Math, Markdown, Latex, display_markdown, HTML
import pandas as pd
pd.options.display.max_colwidth=500
from altrea.wffs import And, Wff
from altrea.rules import Proof

prf = Proof()
prf.setrestricted(False)
A = prf.proposition('A')
B = prf.proposition('B')
prf.setlogic()
prf.goal(B)
prf.premise(Implies(A, B))
prf.premise(Implies(B, A))
prf.rule("conj intro", [prf.item(1), prf.item(2)], [1, 2])
prf.definition('iff intro', [A, B], [4])

display(prf.thisproof())
# Out:
#                                      Item  Level  Proof               Rule  \
#                           $\color{blue}B$      0      0               GOAL
# 1                          $A \supset  B$      0      0            Premise
# 2                          $B \supset  A$      0      0            Premise
# 3  $(A \supset  B) \wedge (B \supset  A)$      0      0  Conjunction Intro
# 4                                              0      0          Iff Intro
#
#    Type Lines Proofs  \
#
# 1  PREM
# 2  PREM
# 3  RULE  1, 2
# 4           4
#
#                                                              Comment
#
# 1
# 2
# 3
# 4  STOPPED: The referenced line is not a previous line of the proof.

# %%
# test_definition_linescope_1: Error: Referenced line is not in scope.

from IPython.display import display, Math, Markdown, Latex, display_markdown, HTML
import pandas as pd
pd.options.display.max_colwidth=500
from altrea.wffs import *
from altrea.rules import Proof

prf = Proof()
prf.setrestricted(False)
A = prf.proposition('A')
B = prf.proposition('B')
prf.setlogic()

prf.goal(B)

prf.opensubproof()
prf.hypothesis(Implies(A, B))
prf.hypothesis(Implies(B, A))
prf.rule("conj intro", [prf.item(1), prf.item(2)], [1, 2])
prf.closesubproof()
prf.implication_intro()
prf.definition('iff intro', [A, B], [3])

display(prf.thisproof())
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th style="text-align:center"></th>
#       <th style="text-align:center">Item</th>
#       <th style="text-align:center">Level</th>
#       <th style="text-align:center">Proof</th>
#       <th style="text-align:center">Rule</th>
#       <th style="text-align:center">Type</th>
#       <th style="text-align:center">Lines</th>
#       <th style="text-align:center">Proofs</th>
#       <th style="text-align:center">Comment</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th style="text-align:center"></th>
#       <td style="text-align:left">$\color{blue}B$</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">GOAL</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#     </tr>
#     <tr>
#       <th style="text-align:center">1</th>
#       <td style="text-align:left">$|\hspace{0.35cm} $$A \supset  B$</td>
#       <td style="text-align:left">1</td>
#       <td style="text-align:left">1</td>
#       <td style="text-align:left">Hypothesis</td>
#       <td style="text-align:left">HYPO</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#     </tr>
#     <tr>
#       <th style="text-align:center">2</th>
#       <td style="text-align:left">$|\hspace{0.35cm} $$B \supset  A$</td>
#       <td style="text-align:left">1</td>
#       <td style="text-align:left">1</td>
#       <td style="text-align:left">Hypothesis</td>
#       <td style="text-align:left">HYPO</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#     </tr>
#     <tr>
#       <th style="text-align:center">3</th>
#       <td style="text-align:left">$|\hspace{0.35cm} $$(A \supset  B) \wedge (B \supset  A)$</td>
#       <td style="text-align:left">1</td>
#       <td style="text-align:left">1</td>
#       <td style="text-align:left">Conjunction Intro</td>
#       <td style="text-align:left">RULE</td>
#       <td style="text-align:left">1, 2</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#     </tr>
#     <tr>
#       <th style="text-align:center">4</th>
#       <td style="text-align:left">$(A \supset  B) \supset  ((A \supset  B) \wedge (B \supset  A))$</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">Implication Intro</td>
#       <td style="text-align:left">TR</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left">1-3</td>
#       <td style="text-align:left"></td>
#     </tr>
#     <tr>
#       <th style="text-align:center">5</th>
#       <td style="text-align:left"></td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">Iff Intro</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left">3</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left">STOPPED: Referenced item is out of scope.</td>
#     </tr>
#   </tbody>
# </table>

# %%
print(prf.subproofavailable)
# Out:
# No

# %% [markdown]
# <a id='disjunction_elim'></a>
# ## Disjunction Elimination

# %%
# test_disjunction_elim_clean_1: Clean run 1.

from IPython.display import display, Math, Markdown, Latex, display_markdown, HTML
import pandas as pd
pd.options.display.max_colwidth=500
from altrea.wffs import And, Wff
from altrea.rules import Proof

prf = Proof()
A = prf.proposition("A")
prf.setlogic()

prf.goal(A)
prf.premise(Or(A, A))

prf.opensubproof()
prf.hypothesis(A)
prf.closesubproof()
prf.implication_intro()
prf.rule('disj elim', [A, A, A], [1, 3, 3])

display(prf.thisproof())
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th style="text-align:center"></th>
#       <th style="text-align:center">Item</th>
#       <th style="text-align:center">Level</th>
#       <th style="text-align:center">Proof</th>
#       <th style="text-align:center">Rule</th>
#       <th style="text-align:center">Type</th>
#       <th style="text-align:center">Lines</th>
#       <th style="text-align:center">Proofs</th>
#       <th style="text-align:center">Comment</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th style="text-align:center"></th>
#       <td style="text-align:left">$\color{blue}A$</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">GOAL</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#     </tr>
#     <tr>
#       <th style="text-align:center">1</th>
#       <td style="text-align:left">$A \vee A$</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">Premise</td>
#       <td style="text-align:left">PREM</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#     </tr>
#     <tr>
#       <th style="text-align:center">2</th>
#       <td style="text-align:left">$|\hspace{0.35cm} $$A$</td>
#       <td style="text-align:left">1</td>
#       <td style="text-align:left">1</td>
#       <td style="text-align:left">Hypothesis</td>
#       <td style="text-align:left">HYPO</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#     </tr>
#     <tr>
#       <th style="text-align:center">3</th>
#       <td style="text-align:left">$A \supset  A$</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">Implication Intro</td>
#       <td style="text-align:left">TR</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left">2-2</td>
#       <td style="text-align:left"></td>
#     </tr>
#     <tr>
#       <th style="text-align:center">4</th>
#       <td style="text-align:left">$\color{blue}A$</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">Disjunction Elim</td>
#       <td style="text-align:left">RULE</td>
#       <td style="text-align:left">1, 3, 3</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left">COMPLETE</td>
#     </tr>
#   </tbody>
# </table>

# %%
# test_disjunction_elim_clean_2: Clean run 2.

from IPython.display import display, Math, Markdown, Latex, display_markdown, HTML
import pandas as pd
pd.options.display.max_colwidth=500
from altrea.wffs import And, Wff
from altrea.rules import Proof

prf = Proof()
A = prf.proposition("A")
B = prf.proposition("B")
C = prf.proposition("C")
prf.setlogic()

prf.goal(A)
prf.premise(Implies(B, A))
prf.premise(Implies(C, A))
prf.premise(Or(B, C))

prf.opensubproof()
prf.hypothesis(B)
prf.reiterate(1)
prf.rule('imp elim', [B, A], [4, 5])
prf.closesubproof()
prf.implication_intro()

prf.opensubproof()
prf.hypothesis(C)
prf.reiterate(2)
prf.rule('imp elim', [C, A], [8, 9])
prf.closesubproof()
prf.implication_intro()
prf.rule('disj elim', [B, C, A], [3, 7, 11])

display(prf.thisproof())
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th style="text-align:center"></th>
#       <th style="text-align:center">Item</th>
#       <th style="text-align:center">Level</th>
#       <th style="text-align:center">Proof</th>
#       <th style="text-align:center">Rule</th>
#       <th style="text-align:center">Type</th>
#       <th style="text-align:center">Lines</th>
#       <th style="text-align:center">Proofs</th>
#       <th style="text-align:center">Comment</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th style="text-align:center"></th>
#       <td style="text-align:left">$\color{blue}A$</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">GOAL</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#     </tr>
#     <tr>
#       <th style="text-align:center">1</th>
#       <td style="text-align:left">$B \supset  A$</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">Premise</td>
#       <td style="text-align:left">PREM</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#     </tr>
#     <tr>
#       <th style="text-align:center">2</th>
#       <td style="text-align:left">$C \supset  A$</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">Premise</td>
#       <td style="text-align:left">PREM</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#     </tr>
#     <tr>
#       <th style="text-align:center">3</th>
#       <td style="text-align:left">$B \vee C$</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">Premise</td>
#       <td style="text-align:left">PREM</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#     </tr>
#     <tr>
#       <th style="text-align:center">4</th>
#       <td style="text-align:left">$|\hspace{0.35cm} $$B$</td>
#       <td style="text-align:left">1</td>
#       <td style="text-align:left">1</td>
#       <td style="text-align:left">Hypothesis</td>
#       <td style="text-align:left">HYPO</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#     </tr>
#     <tr>
#       <th style="text-align:center">5</th>
#       <td style="text-align:left">$|\hspace{0.35cm} $$B \supset  A$</td>
#       <td style="text-align:left">1</td>
#       <td style="text-align:left">1</td>
#       <td style="text-align:left">Reiteration</td>
#       <td style="text-align:left">REIT</td>
#       <td style="text-align:left">1</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#     </tr>
#     <tr>
#       <th style="text-align:center">6</th>
#       <td style="text-align:left">$|\hspace{0.35cm} $$A$</td>
#       <td style="text-align:left">1</td>
#       <td style="text-align:left">1</td>
#       <td style="text-align:left">Implication Elim</td>
#       <td style="text-align:left">RULE</td>
#       <td style="text-align:left">4, 5</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#     </tr>
#     <tr>
#       <th style="text-align:center">7</th>
#       <td style="text-align:left">$B \supset  A$</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">Implication Intro</td>
#       <td style="text-align:left">TR</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left">4-6</td>
#       <td style="text-align:left"></td>
#     </tr>
#     <tr>
#       <th style="text-align:center">8</th>
#       <td style="text-align:left">$|\hspace{0.35cm} $$C$</td>
#       <td style="text-align:left">1</td>
#       <td style="text-align:left">2</td>
#       <td style="text-align:left">Hypothesis</td>
#       <td style="text-align:left">HYPO</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#     </tr>
#     <tr>
#       <th style="text-align:center">9</th>
#       <td style="text-align:left">$|\hspace{0.35cm} $$C \supset  A$</td>
#       <td style="text-align:left">1</td>
#       <td style="text-align:left">2</td>
#       <td style="text-align:left">Reiteration</td>
#       <td style="text-align:left">REIT</td>
#       <td style="text-align:left">2</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#     </tr>
#     <tr>
#       <th style="text-align:center">10</th>
#       <td style="text-align:left">$|\hspace{0.35cm} $$A$</td>
#       <td style="text-align:left">1</td>
#       <td style="text-align:left">2</td>
#       <td style="text-align:left">Implication Elim</td>
#       <td style="text-align:left">RULE</td>
#       <td style="text-align:left">8, 9</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#     </tr>
#     <tr>
#       <th style="text-align:center">11</th>
#       <td style="text-align:left">$C \supset  A$</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">Implication Intro</td>
#       <td style="text-align:left">TR</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left">8-10</td>
#       <td style="text-align:left"></td>
#     </tr>
#     <tr>
#       <th style="text-align:center">12</th>
#       <td style="text-align:left">$\color{blue}A$</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">Disjunction Elim</td>
#       <td style="text-align:left">RULE</td>
#       <td style="text-align:left">3, 7, 11</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left">COMPLETE</td>
#     </tr>
#   </tbody>
# </table>

# %%
# test_disjunction_elim_nosuchline_1: The first referenced line of the three does not exist in the proof.

from IPython.display import display, Math, Markdown, Latex, display_markdown, HTML
import pandas as pd
pd.options.display.max_colwidth=500
from altrea.wffs import And, Wff
from altrea.rules import Proof

prf = Proof()
A = prf.proposition("A")
prf.setlogic()

prf.goal(A)
prf.premise(Or(A, A))

prf.opensubproof()
prf.hypothesis(A)
prf.closesubproof()
prf.implication_intro()
prf.rule('disj elim', [A, A, A], [10, 3, 3])
prf.hypothesis(A, comment="Nothing can be added after the proof is stopped.")

display(prf.thisproof())
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th style="text-align:center"></th>
#       <th style="text-align:center">Item</th>
#       <th style="text-align:center">Level</th>
#       <th style="text-align:center">Proof</th>
#       <th style="text-align:center">Rule</th>
#       <th style="text-align:center">Type</th>
#       <th style="text-align:center">Lines</th>
#       <th style="text-align:center">Proofs</th>
#       <th style="text-align:center">Comment</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th style="text-align:center"></th>
#       <td style="text-align:left">$\color{blue}A$</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">GOAL</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#     </tr>
#     <tr>
#       <th style="text-align:center">1</th>
#       <td style="text-align:left">$A \vee A$</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">Premise</td>
#       <td style="text-align:left">PREM</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#     </tr>
#     <tr>
#       <th style="text-align:center">2</th>
#       <td style="text-align:left">$|\hspace{0.35cm} $$A$</td>
#       <td style="text-align:left">1</td>
#       <td style="text-align:left">1</td>
#       <td style="text-align:left">Hypothesis</td>
#       <td style="text-align:left">HYPO</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#     </tr>
#     <tr>
#       <th style="text-align:center">3</th>
#       <td style="text-align:left">$A \supset  A$</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">Implication Intro</td>
#       <td style="text-align:left">TR</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left">2-2</td>
#       <td style="text-align:left"></td>
#     </tr>
#     <tr>
#       <th style="text-align:center">4</th>
#       <td style="text-align:left"></td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">Disjunction Elim</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left">10</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left">STOPPED: The referenced line is not a previous line of the proof.</td>
#     </tr>
#   </tbody>
# </table>

# %%
# test_disjunction_elim_nosuchline_2: The second referenced line of the three does not exist in the proof.

from IPython.display import display, Math, Markdown, Latex, display_markdown, HTML
import pandas as pd
pd.options.display.max_colwidth=500
from altrea.wffs import And, Wff
from altrea.rules import Proof

prf = Proof()
A = prf.proposition("A")
prf.setlogic()

prf.goal(A)
prf.premise(Or(A, A))

prf.opensubproof()
prf.hypothesis(A)
prf.closesubproof()
prf.implication_intro()
prf.rule('disj elim', [A, A, A], [1, -10, 3])
prf.hypothesis(A, comment="Nothing can be added after the proof is stopped.")

display(prf.thisproof())
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th style="text-align:center"></th>
#       <th style="text-align:center">Item</th>
#       <th style="text-align:center">Level</th>
#       <th style="text-align:center">Proof</th>
#       <th style="text-align:center">Rule</th>
#       <th style="text-align:center">Type</th>
#       <th style="text-align:center">Lines</th>
#       <th style="text-align:center">Proofs</th>
#       <th style="text-align:center">Comment</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th style="text-align:center"></th>
#       <td style="text-align:left">$\color{blue}A$</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">GOAL</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#     </tr>
#     <tr>
#       <th style="text-align:center">1</th>
#       <td style="text-align:left">$A \vee A$</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">Premise</td>
#       <td style="text-align:left">PREM</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#     </tr>
#     <tr>
#       <th style="text-align:center">2</th>
#       <td style="text-align:left">$|\hspace{0.35cm} $$A$</td>
#       <td style="text-align:left">1</td>
#       <td style="text-align:left">1</td>
#       <td style="text-align:left">Hypothesis</td>
#       <td style="text-align:left">HYPO</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#     </tr>
#     <tr>
#       <th style="text-align:center">3</th>
#       <td style="text-align:left">$A \supset  A$</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">Implication Intro</td>
#       <td style="text-align:left">TR</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left">2-2</td>
#       <td style="text-align:left"></td>
#     </tr>
#     <tr>
#       <th style="text-align:center">4</th>
#       <td style="text-align:left"></td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">Disjunction Elim</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left">-10</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left">STOPPED: The referenced line is not a previous line of the proof.</td>
#     </tr>
#   </tbody>
# </table>

# %%
# test_disjunction_elim_notinteger_1: The third referenced line of the three does not exist in the proof.

from IPython.display import display, Math, Markdown, Latex, display_markdown, HTML
import pandas as pd
pd.options.display.max_colwidth=500
from altrea.wffs import And, Wff
from altrea.rules import Proof

prf = Proof()
A = prf.proposition("A")
prf.setlogic()

prf.goal(A)
prf.premise(Or(A, A))

prf.opensubproof()
prf.hypothesis(A)
prf.closesubproof()
prf.implication_intro()
prf.rule('disj elim', [A, A, A], [1, 3, 3.1416])
prf.hypothesis(A, comment="Nothing can be added after the proof is stopped.")

display(prf.thisproof())
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th style="text-align:center"></th>
#       <th style="text-align:center">Item</th>
#       <th style="text-align:center">Level</th>
#       <th style="text-align:center">Proof</th>
#       <th style="text-align:center">Rule</th>
#       <th style="text-align:center">Type</th>
#       <th style="text-align:center">Lines</th>
#       <th style="text-align:center">Proofs</th>
#       <th style="text-align:center">Comment</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th style="text-align:center"></th>
#       <td style="text-align:left">$\color{blue}A$</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">GOAL</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#     </tr>
#     <tr>
#       <th style="text-align:center">1</th>
#       <td style="text-align:left">$A \vee A$</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">Premise</td>
#       <td style="text-align:left">PREM</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#     </tr>
#     <tr>
#       <th style="text-align:center">2</th>
#       <td style="text-align:left">$|\hspace{0.35cm} $$A$</td>
#       <td style="text-align:left">1</td>
#       <td style="text-align:left">1</td>
#       <td style="text-align:left">Hypothesis</td>
#       <td style="text-align:left">HYPO</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#     </tr>
#     <tr>
#       <th style="text-align:center">3</th>
#       <td style="text-align:left">$A \supset  A$</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">Implication Intro</td>
#       <td style="text-align:left">TR</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left">2-2</td>
#       <td style="text-align:left"></td>
#     </tr>
#     <tr>
#       <th style="text-align:center">4</th>
#       <td style="text-align:left"></td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">Disjunction Elim</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left">3.1416</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left">STOPPED: The line number is not an integer.</td>
#     </tr>
#   </tbody>
# </table>

# %%
# test_disjunction_elim_linescope_1: The first referenced line of the three is not accessible.

from IPython.display import display, Math, Markdown, Latex, display_markdown, HTML
import pandas as pd
pd.options.display.max_colwidth=500
from altrea.wffs import And, Wff
from altrea.rules import Proof

prf = Proof()
A = prf.proposition("A")
C = prf.proposition("C")
prf.setlogic()

prf.goal(A)
prf.premise(Or(A, A))

prf.opensubproof()
prf.hypothesis(C)
prf.opensubproof()
prf.hypothesis(A)
prf.closesubproof()
prf.implication_intro()
prf.rule('disj elim', [A, A, A], [1, 4, 4])
prf.hypothesis(A, comment="Nothing can be added after the proof is stopped.")

display(prf.thisproof())
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th style="text-align:center"></th>
#       <th style="text-align:center">Item</th>
#       <th style="text-align:center">Level</th>
#       <th style="text-align:center">Proof</th>
#       <th style="text-align:center">Rule</th>
#       <th style="text-align:center">Type</th>
#       <th style="text-align:center">Lines</th>
#       <th style="text-align:center">Proofs</th>
#       <th style="text-align:center">Comment</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th style="text-align:center"></th>
#       <td style="text-align:left">$\color{blue}A$</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">GOAL</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#     </tr>
#     <tr>
#       <th style="text-align:center">1</th>
#       <td style="text-align:left">$A \vee A$</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">Premise</td>
#       <td style="text-align:left">PREM</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#     </tr>
#     <tr>
#       <th style="text-align:center">2</th>
#       <td style="text-align:left">$|\hspace{0.35cm} $$C$</td>
#       <td style="text-align:left">1</td>
#       <td style="text-align:left">1</td>
#       <td style="text-align:left">Hypothesis</td>
#       <td style="text-align:left">HYPO</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#     </tr>
#     <tr>
#       <th style="text-align:center">3</th>
#       <td style="text-align:left">$|\hspace{0.35cm} $$|\hspace{0.35cm} $$A$</td>
#       <td style="text-align:left">2</td>
#       <td style="text-align:left">2</td>
#       <td style="text-align:left">Hypothesis</td>
#       <td style="text-align:left">HYPO</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#     </tr>
#     <tr>
#       <th style="text-align:center">4</th>
#       <td style="text-align:left">$|\hspace{0.35cm} $$A \supset  A$</td>
#       <td style="text-align:left">1</td>
#       <td style="text-align:left">1</td>
#       <td style="text-align:left">Implication Intro</td>
#       <td style="text-align:left">TR</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left">3-3</td>
#       <td style="text-align:left"></td>
#     </tr>
#     <tr>
#       <th style="text-align:center">5</th>
#       <td style="text-align:left"></td>
#       <td style="text-align:left">1</td>
#       <td style="text-align:left">1</td>
#       <td style="text-align:left">Disjunction Elim</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left">1</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left">STOPPED: Referenced item is out of scope.</td>
#     </tr>
#   </tbody>
# </table>

# %%
# test_disjunction_elim_linescope_2: The second referenced line of the three is not accessible.

from IPython.display import display, Math, Markdown, Latex, display_markdown, HTML
import pandas as pd
pd.options.display.max_colwidth=500
from altrea.wffs import And, Wff
from altrea.rules import Proof

prf = Proof()
A = prf.proposition("A")
prf.setlogic()

prf.goal(A)
prf.premise(Or(A, A))

prf.opensubproof()
prf.hypothesis(A)
prf.closesubproof()
prf.implication_intro()
prf.rule('disj elim', [A, A, A], [1, 2, 3])
prf.hypothesis(A, comment="Nothing can be added after the proof is stopped.")

display(prf.thisproof())
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th style="text-align:center"></th>
#       <th style="text-align:center">Item</th>
#       <th style="text-align:center">Level</th>
#       <th style="text-align:center">Proof</th>
#       <th style="text-align:center">Rule</th>
#       <th style="text-align:center">Type</th>
#       <th style="text-align:center">Lines</th>
#       <th style="text-align:center">Proofs</th>
#       <th style="text-align:center">Comment</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th style="text-align:center"></th>
#       <td style="text-align:left">$\color{blue}A$</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">GOAL</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#     </tr>
#     <tr>
#       <th style="text-align:center">1</th>
#       <td style="text-align:left">$A \vee A$</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">Premise</td>
#       <td style="text-align:left">PREM</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#     </tr>
#     <tr>
#       <th style="text-align:center">2</th>
#       <td style="text-align:left">$|\hspace{0.35cm} $$A$</td>
#       <td style="text-align:left">1</td>
#       <td style="text-align:left">1</td>
#       <td style="text-align:left">Hypothesis</td>
#       <td style="text-align:left">HYPO</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#     </tr>
#     <tr>
#       <th style="text-align:center">3</th>
#       <td style="text-align:left">$A \supset  A$</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">Implication Intro</td>
#       <td style="text-align:left">TR</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left">2-2</td>
#       <td style="text-align:left"></td>
#     </tr>
#     <tr>
#       <th style="text-align:center">4</th>
#       <td style="text-align:left"></td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">Disjunction Elim</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left">2</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left">STOPPED: Referenced item is out of scope.</td>
#     </tr>
#   </tbody>
# </table>

# %%
# test_disjunction_elim_linescope_3: The third referenced line of the three is not accessible.

from IPython.display import display, Math, Markdown, Latex, display_markdown, HTML
import pandas as pd
pd.options.display.max_colwidth=500
from altrea.wffs import And, Wff
from altrea.rules import Proof

prf = Proof()
A = prf.proposition("A")
prf.setlogic()

prf.goal(A)
prf.premise(Or(A, A))

prf.opensubproof()
prf.hypothesis(A)
prf.closesubproof()
prf.implication_intro()
prf.rule('disj elim', [A, A, A], [1, 3, 2])
prf.hypothesis(A, comment="Nothing can be added after the proof is stopped.")

display(prf.thisproof())
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th style="text-align:center"></th>
#       <th style="text-align:center">Item</th>
#       <th style="text-align:center">Level</th>
#       <th style="text-align:center">Proof</th>
#       <th style="text-align:center">Rule</th>
#       <th style="text-align:center">Type</th>
#       <th style="text-align:center">Lines</th>
#       <th style="text-align:center">Proofs</th>
#       <th style="text-align:center">Comment</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th style="text-align:center"></th>
#       <td style="text-align:left">$\color{blue}A$</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">GOAL</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#     </tr>
#     <tr>
#       <th style="text-align:center">1</th>
#       <td style="text-align:left">$A \vee A$</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">Premise</td>
#       <td style="text-align:left">PREM</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#     </tr>
#     <tr>
#       <th style="text-align:center">2</th>
#       <td style="text-align:left">$|\hspace{0.35cm} $$A$</td>
#       <td style="text-align:left">1</td>
#       <td style="text-align:left">1</td>
#       <td style="text-align:left">Hypothesis</td>
#       <td style="text-align:left">HYPO</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#     </tr>
#     <tr>
#       <th style="text-align:center">3</th>
#       <td style="text-align:left">$A \supset  A$</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">Implication Intro</td>
#       <td style="text-align:left">TR</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left">2-2</td>
#       <td style="text-align:left"></td>
#     </tr>
#     <tr>
#       <th style="text-align:center">4</th>
#       <td style="text-align:left"></td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">Disjunction Elim</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left">2</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left">STOPPED: Referenced item is out of scope.</td>
#     </tr>
#   </tbody>
# </table>

# %%
# test_disjunction_elim_premisesdontmatch_1: The first referenced line is not a disjunction.

from IPython.display import display, Math, Markdown, Latex, display_markdown, HTML
import pandas as pd
pd.options.display.max_colwidth=500
from altrea.wffs import And, Wff
from altrea.rules import Proof

prf = Proof()
A = prf.proposition("A")
prf.setlogic()

prf.goal(A)
prf.premise(And(A, A))

prf.opensubproof()
prf.hypothesis(A)
prf.closesubproof()
prf.implication_intro()
prf.rule('disj elim', [A, A, A], [1, 3, 3])
prf.hypothesis(A, comment="Nothing can be added after the proof is stopped.")

display(prf.thisproof())
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th style="text-align:center"></th>
#       <th style="text-align:center">Item</th>
#       <th style="text-align:center">Level</th>
#       <th style="text-align:center">Proof</th>
#       <th style="text-align:center">Rule</th>
#       <th style="text-align:center">Type</th>
#       <th style="text-align:center">Lines</th>
#       <th style="text-align:center">Proofs</th>
#       <th style="text-align:center">Comment</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th style="text-align:center"></th>
#       <td style="text-align:left">$\color{blue}A$</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">GOAL</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#     </tr>
#     <tr>
#       <th style="text-align:center">1</th>
#       <td style="text-align:left">$A \wedge A$</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">Premise</td>
#       <td style="text-align:left">PREM</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#     </tr>
#     <tr>
#       <th style="text-align:center">2</th>
#       <td style="text-align:left">$|\hspace{0.35cm} $$A$</td>
#       <td style="text-align:left">1</td>
#       <td style="text-align:left">1</td>
#       <td style="text-align:left">Hypothesis</td>
#       <td style="text-align:left">HYPO</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#     </tr>
#     <tr>
#       <th style="text-align:center">3</th>
#       <td style="text-align:left">$A \supset  A$</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">Implication Intro</td>
#       <td style="text-align:left">TR</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left">2-2</td>
#       <td style="text-align:left"></td>
#     </tr>
#     <tr>
#       <th style="text-align:center">4</th>
#       <td style="text-align:left"></td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">Disjunction Elim</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left">STOPPED: A required premise does not match a line in the current proof.</td>
#     </tr>
#   </tbody>
# </table>

# %%
# test_disjunction_elim_premisesdontmatch_2: The second referenced line is not an implication.

from IPython.display import display, Math, Markdown, Latex, display_markdown, HTML
import pandas as pd
pd.options.display.max_colwidth=500
from altrea.wffs import And, Wff, Or
from altrea.rules import Proof

prf = Proof()
A = prf.proposition("A")
prf.setlogic()

prf.goal(A)
prf.premise(Or(A, A))

prf.opensubproof()
prf.hypothesis(A)
prf.closesubproof()
prf.implication_intro()
prf.rule('disj elim', [A, A, A], [1, 1, 3])
prf.hypothesis(A, comment="Nothing can be added after the proof is stopped.")

display(prf.thisproof())
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th style="text-align:center"></th>
#       <th style="text-align:center">Item</th>
#       <th style="text-align:center">Level</th>
#       <th style="text-align:center">Proof</th>
#       <th style="text-align:center">Rule</th>
#       <th style="text-align:center">Type</th>
#       <th style="text-align:center">Lines</th>
#       <th style="text-align:center">Proofs</th>
#       <th style="text-align:center">Comment</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th style="text-align:center"></th>
#       <td style="text-align:left">$\color{blue}A$</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">GOAL</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#     </tr>
#     <tr>
#       <th style="text-align:center">1</th>
#       <td style="text-align:left">$A \vee A$</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">Premise</td>
#       <td style="text-align:left">PREM</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#     </tr>
#     <tr>
#       <th style="text-align:center">2</th>
#       <td style="text-align:left">$|\hspace{0.35cm} $$A$</td>
#       <td style="text-align:left">1</td>
#       <td style="text-align:left">1</td>
#       <td style="text-align:left">Hypothesis</td>
#       <td style="text-align:left">HYPO</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#     </tr>
#     <tr>
#       <th style="text-align:center">3</th>
#       <td style="text-align:left">$A \supset  A$</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">Implication Intro</td>
#       <td style="text-align:left">TR</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left">2-2</td>
#       <td style="text-align:left"></td>
#     </tr>
#     <tr>
#       <th style="text-align:center">4</th>
#       <td style="text-align:left"></td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">Disjunction Elim</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left">STOPPED: A required premise does not match a line in the current proof.</td>
#     </tr>
#   </tbody>
# </table>

# %%
# test_disjunction_elim_premisesdontmatch_3: The third referenced line is not an implication.

from IPython.display import display, Math, Markdown, Latex, display_markdown, HTML
import pandas as pd
pd.options.display.max_colwidth=500
from altrea.wffs import And, Wff
from altrea.rules import Proof

prf = Proof()
A = prf.proposition("A")
prf.setlogic()

prf.goal(A)
prf.premise(Or(A, A))

prf.opensubproof()
prf.hypothesis(A)
prf.closesubproof()
prf.implication_intro()
prf.rule('disj elim', [A, A, A], [1, 3, 1])
prf.hypothesis(A, comment="Nothing can be added after the proof is stopped.")

display(prf.thisproof())
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th style="text-align:center"></th>
#       <th style="text-align:center">Item</th>
#       <th style="text-align:center">Level</th>
#       <th style="text-align:center">Proof</th>
#       <th style="text-align:center">Rule</th>
#       <th style="text-align:center">Type</th>
#       <th style="text-align:center">Lines</th>
#       <th style="text-align:center">Proofs</th>
#       <th style="text-align:center">Comment</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th style="text-align:center"></th>
#       <td style="text-align:left">$\color{blue}A$</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">GOAL</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#     </tr>
#     <tr>
#       <th style="text-align:center">1</th>
#       <td style="text-align:left">$A \vee A$</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">Premise</td>
#       <td style="text-align:left">PREM</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#     </tr>
#     <tr>
#       <th style="text-align:center">2</th>
#       <td style="text-align:left">$|\hspace{0.35cm} $$A$</td>
#       <td style="text-align:left">1</td>
#       <td style="text-align:left">1</td>
#       <td style="text-align:left">Hypothesis</td>
#       <td style="text-align:left">HYPO</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#     </tr>
#     <tr>
#       <th style="text-align:center">3</th>
#       <td style="text-align:left">$A \supset  A$</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">Implication Intro</td>
#       <td style="text-align:left">TR</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left">2-2</td>
#       <td style="text-align:left"></td>
#     </tr>
#     <tr>
#       <th style="text-align:center">4</th>
#       <td style="text-align:left"></td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">Disjunction Elim</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left">STOPPED: A required premise does not match a line in the current proof.</td>
#     </tr>
#   </tbody>
# </table>

# %%
# test_disjunction_elim_premisesdontmatch_4: The conclusions of the two implications are not the same.

from IPython.display import display, Math, Markdown, Latex, display_markdown, HTML
import pandas as pd
pd.options.display.max_colwidth=500
from altrea.wffs import And, Wff, Implies, Or
from altrea.rules import Proof

prf = Proof()
A = prf.proposition("A")
B = prf.proposition("B")
C = prf.proposition("C")
prf.setlogic()

prf.goal(A)
prf.premise(Implies(B, A))
prf.premise(Implies(C, B))
prf.premise(Or(B, C))

prf.opensubproof()
prf.hypothesis(B)
prf.reiterate(1)
prf.rule('imp elim', [B, A], [4, 5])
prf.closesubproof()
prf.implication_intro()

prf.opensubproof()
prf.hypothesis(C)
prf.reiterate(2)
prf.rule('imp elim', [C, B], [8, 9])
prf.closesubproof()
prf.implication_intro()
prf.rule('disj elim', [B, C, A], [3, 7, 11])
prf.hypothesis(A, comment="Nothing can be added after the proof is stopped.")

display(prf.thisproof())
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th style="text-align:center"></th>
#       <th style="text-align:center">Item</th>
#       <th style="text-align:center">Level</th>
#       <th style="text-align:center">Proof</th>
#       <th style="text-align:center">Rule</th>
#       <th style="text-align:center">Type</th>
#       <th style="text-align:center">Lines</th>
#       <th style="text-align:center">Proofs</th>
#       <th style="text-align:center">Comment</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th style="text-align:center"></th>
#       <td style="text-align:left">$\color{blue}A$</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">GOAL</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#     </tr>
#     <tr>
#       <th style="text-align:center">1</th>
#       <td style="text-align:left">$B \supset  A$</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">Premise</td>
#       <td style="text-align:left">PREM</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#     </tr>
#     <tr>
#       <th style="text-align:center">2</th>
#       <td style="text-align:left">$C \supset  B$</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">Premise</td>
#       <td style="text-align:left">PREM</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#     </tr>
#     <tr>
#       <th style="text-align:center">3</th>
#       <td style="text-align:left">$B \vee C$</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">Premise</td>
#       <td style="text-align:left">PREM</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#     </tr>
#     <tr>
#       <th style="text-align:center">4</th>
#       <td style="text-align:left">$|\hspace{0.35cm} $$B$</td>
#       <td style="text-align:left">1</td>
#       <td style="text-align:left">1</td>
#       <td style="text-align:left">Hypothesis</td>
#       <td style="text-align:left">HYPO</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#     </tr>
#     <tr>
#       <th style="text-align:center">5</th>
#       <td style="text-align:left">$|\hspace{0.35cm} $$B \supset  A$</td>
#       <td style="text-align:left">1</td>
#       <td style="text-align:left">1</td>
#       <td style="text-align:left">Reiteration</td>
#       <td style="text-align:left">REIT</td>
#       <td style="text-align:left">1</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#     </tr>
#     <tr>
#       <th style="text-align:center">6</th>
#       <td style="text-align:left">$|\hspace{0.35cm} $$A$</td>
#       <td style="text-align:left">1</td>
#       <td style="text-align:left">1</td>
#       <td style="text-align:left">Implication Elim</td>
#       <td style="text-align:left">RULE</td>
#       <td style="text-align:left">4, 5</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#     </tr>
#     <tr>
#       <th style="text-align:center">7</th>
#       <td style="text-align:left">$B \supset  A$</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">Implication Intro</td>
#       <td style="text-align:left">TR</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left">4-6</td>
#       <td style="text-align:left"></td>
#     </tr>
#     <tr>
#       <th style="text-align:center">8</th>
#       <td style="text-align:left">$|\hspace{0.35cm} $$C$</td>
#       <td style="text-align:left">1</td>
#       <td style="text-align:left">2</td>
#       <td style="text-align:left">Hypothesis</td>
#       <td style="text-align:left">HYPO</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#     </tr>
#     <tr>
#       <th style="text-align:center">9</th>
#       <td style="text-align:left">$|\hspace{0.35cm} $$C \supset  B$</td>
#       <td style="text-align:left">1</td>
#       <td style="text-align:left">2</td>
#       <td style="text-align:left">Reiteration</td>
#       <td style="text-align:left">REIT</td>
#       <td style="text-align:left">2</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#     </tr>
#     <tr>
#       <th style="text-align:center">10</th>
#       <td style="text-align:left">$|\hspace{0.35cm} $$B$</td>
#       <td style="text-align:left">1</td>
#       <td style="text-align:left">2</td>
#       <td style="text-align:left">Implication Elim</td>
#       <td style="text-align:left">RULE</td>
#       <td style="text-align:left">8, 9</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#     </tr>
#     <tr>
#       <th style="text-align:center">11</th>
#       <td style="text-align:left">$C \supset  B$</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">Implication Intro</td>
#       <td style="text-align:left">TR</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left">8-10</td>
#       <td style="text-align:left"></td>
#     </tr>
#     <tr>
#       <th style="text-align:center">12</th>
#       <td style="text-align:left"></td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">Disjunction Elim</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left">STOPPED: A required premise does not match a line in the current proof.</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# <a id='disjunction_intro'></a>
# ## Disjunction Introduction

# %%
# test_disjunction_intro_clean_1: Clean run 1

from IPython.display import display, Math, Markdown, Latex, display_markdown, HTML
import pandas as pd
pd.options.display.max_colwidth=500
from altrea.wffs import And, Wff, Or
from altrea.rules import Proof

prf = Proof()
prf.setrestricted(False)
A = prf.proposition("A")
B = prf.proposition("B")
prf.setlogic()
prf.goal(Or(A, B))
prf.premise(A)
prf.rule("disj intro r", [A, B], [1])
#prf.disjunction_intro(1, right=B)

display(prf.thisproof())
# Out:
#                      Item  Level  Proof                     Rule  Type Lines  \
#    $\color{blue}A \vee B$      0      0                     GOAL
# 1                     $A$      0      0                  Premise  PREM
# 2  $\color{blue}A \vee B$      0      0  Disjunction Intro Right  RULE     1
#
#   Proofs   Comment
#
# 1
# 2         COMPLETE

# %%
# test_disjunction_intro_clean_2: Clean run 2

from IPython.display import display, Math, Markdown, Latex, display_markdown, HTML
import pandas as pd
pd.options.display.max_colwidth=500
from altrea.wffs import And, Wff, Or
from altrea.rules import Proof

prf = Proof()
prf.setrestricted(False)
A = prf.proposition("A")
B = prf.proposition("B")
prf.setlogic()
prf.goal(Or(A, B))
prf.premise(B)
prf.rule("disj intro l", [B, A], [1])
#prf.disjunction_intro(1, left=A)

display(prf.thisproof())
# Out:
#                      Item  Level  Proof                    Rule  Type Lines  \
#    $\color{blue}A \vee B$      0      0                    GOAL
# 1                     $B$      0      0                 Premise  PREM
# 2  $\color{blue}A \vee B$      0      0  Disjunction Intro Left  RULE     1
#
#   Proofs   Comment
#
# 1
# 2         COMPLETE

# %%
# test_disjunction_intro_notwff_1: Stops if the the left side is a string rather than a Wff class.

from IPython.display import display, Math, Markdown, Latex, display_markdown, HTML
import pandas as pd
pd.options.display.max_colwidth=500
from altrea.wffs import And, Wff, Or
from altrea.rules import Proof

prf = Proof()
prf.setrestricted(False)
A = prf.proposition("A")
B = prf.proposition("B")
prf.setlogic()
prf.goal(Or(A, B))
prf.premise(B)
prf.rule("disj intro l", ["A", B], [1])
#prf.disjunction_intro(1, left="A")
prf.hypothesis(A, comment="Nothing can be added after the proof is stopped.")

display(prf.thisproof())
# Out:
#                      Item  Level  Proof                    Rule  Type Lines  \
#    $\color{blue}A \vee B$      0      0                    GOAL
# 1                     $B$      0      0                 Premise  PREM
# 2                              0      0  Disjunction Intro Left
#
#   Proofs                                                   Comment
#
# 1
# 2         STOPPED: The input is not an instance of the Wff object.

# %%
# test_disjunction_intro_nosuchline_1: The line does not exist in the proof

from IPython.display import display, Math, Markdown, Latex, display_markdown, HTML
import pandas as pd
pd.options.display.max_colwidth=500
from altrea.wffs import And, Wff, Or
from altrea.rules import Proof

prf = Proof()
prf.setrestricted(False)
A = prf.proposition("A")
B = prf.proposition("B")
prf.setlogic()

prf.goal(Or(A, B))
prf.premise(A)

prf.rule("disj intro r", [A, B], [-2])

display(prf.thisproof())
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th style="text-align:center"></th>
#       <th style="text-align:center">Item</th>
#       <th style="text-align:center">Level</th>
#       <th style="text-align:center">Proof</th>
#       <th style="text-align:center">Rule</th>
#       <th style="text-align:center">Type</th>
#       <th style="text-align:center">Lines</th>
#       <th style="text-align:center">Proofs</th>
#       <th style="text-align:center">Comment</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th style="text-align:center"></th>
#       <td style="text-align:left">$\color{blue}A \vee B$</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">GOAL</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#     </tr>
#     <tr>
#       <th style="text-align:center">1</th>
#       <td style="text-align:left">$A$</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">Premise</td>
#       <td style="text-align:left">PREM</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#     </tr>
#     <tr>
#       <th style="text-align:center">2</th>
#       <td style="text-align:left"></td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">Disjunction Intro Right</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left">-2</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left">STOPPED: The referenced line is not a previous line of the proof.</td>
#     </tr>
#   </tbody>
# </table>

# %%
# test_disjunction_intro_linescope_1: The line is not accessible.

from IPython.display import display, Math, Markdown, Latex, display_markdown, HTML
import pandas as pd
pd.options.display.max_colwidth=500
from altrea.wffs import And, Wff, Or
from altrea.rules import Proof

prf = Proof()
prf.setrestricted(False)
A = prf.proposition("A")
B = prf.proposition("B")
prf.setlogic()

prf.goal(Or(A, B))

prf.opensubproof()
prf.hypothesis(A)
prf.closesubproof()
prf.implication_intro()
prf.rule("disj intro r", [A, B], [1])

display(prf.thisproof())
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th style="text-align:center"></th>
#       <th style="text-align:center">Item</th>
#       <th style="text-align:center">Level</th>
#       <th style="text-align:center">Proof</th>
#       <th style="text-align:center">Rule</th>
#       <th style="text-align:center">Type</th>
#       <th style="text-align:center">Lines</th>
#       <th style="text-align:center">Proofs</th>
#       <th style="text-align:center">Comment</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th style="text-align:center"></th>
#       <td style="text-align:left">$\color{blue}A \vee B$</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">GOAL</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#     </tr>
#     <tr>
#       <th style="text-align:center">1</th>
#       <td style="text-align:left">$|\hspace{0.35cm} $$A$</td>
#       <td style="text-align:left">1</td>
#       <td style="text-align:left">1</td>
#       <td style="text-align:left">Hypothesis</td>
#       <td style="text-align:left">HYPO</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#     </tr>
#     <tr>
#       <th style="text-align:center">2</th>
#       <td style="text-align:left">$A \supset  A$</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">Implication Intro</td>
#       <td style="text-align:left">TR</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left">1-1</td>
#       <td style="text-align:left"></td>
#     </tr>
#     <tr>
#       <th style="text-align:center">3</th>
#       <td style="text-align:left"></td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">Disjunction Intro Right</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left">1</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left">STOPPED: Referenced item is out of scope.</td>
#     </tr>
#   </tbody>
# </table>

# %%
# No value was passed for either the left or the right side.

from IPython.display import display, Math, Markdown, Latex, display_markdown, HTML
import pandas as pd
pd.options.display.max_colwidth=500
from altrea.wffs import And, Wff, Or
from altrea.rules import Proof

prf = Proof()
A = prf.proposition('A')
B = prf.proposition('B')
C = prf.proposition('C')
D = prf.proposition('D')
E = prf.proposition('E')
prf.setlogic()
prf.goal(Or(A, B))
prf.premise(A)
prf.disjunction_intro(1)

display(prf.thisproof())

# %% [markdown]
# <a id='entailment'></a>
# ## Entailment

# %%
# test_entailment_rule_clean_1

from IPython.display import display, Math, Markdown, Latex, display_markdown, HTML
import pandas as pd
pd.options.display.max_colwidth=500
from altrea.wffs import And, Wff, Not
from altrea.rules import Proof

prf = Proof("testproof", "Special", "Trivial Proof")
B = prf.proposition("B")
prf.setlogic()
prf.saveaxiom(
    "contradiction",
    "Contradiction",
    "All Contradictions Are True",
    And(prf.mvalpha, Not(prf.mvalpha)),
    [],
)
prf.axiom("contradiction", [B], [])
prf.entailment(
    prf.mvalpha, 
    [And(prf.mvalpha, prf.mvbeta)], 
    name="conjeliml", 
    displayname= "Conjunction Elim Left", 
    description="Conjunction Elimination Left Side", 
    kind=prf.label_rule) 
prf.goal(B)
prf.rule("conjeliml", [prf.item(1).left, prf.item(1).right], [1])

display(prf.thisproof())
# Out:
# SAVE AXIOM: An axiom with the name "contradiction" already exists.
# SAVE RULE: The rule named "conjeliml" has been saved.
#                  Item  Level  Proof                   Rule   Type Lines  \
#       $\color{blue}B$      0      0                   GOAL
# 1  $B \wedge \lnot~B$      0      0          Contradiction  AXIOM
# 2     $\color{blue}B$      0      0  Conjunction Elim Left   RULE     1
#
#   Proofs   Comment
#
# 1
# 2         COMPLETE

# %%
# test_entailment_axiom_clean_1

from IPython.display import display, Math, Markdown, Latex, display_markdown, HTML
import pandas as pd
pd.options.display.max_colwidth=500
from altrea.wffs import And, Wff, Not
from altrea.rules import Proof

prf = Proof("testproof", "Special", "Trivial Proof")
B = prf.proposition("B")
prf.setlogic()
prf.entailment(
    And(prf.mvalpha, Not(prf.mvalpha)), 
    [], 
    name="contra", 
    displayname= "Contradiction", 
    description="Assume Contradictions", 
    kind=prf.label_axiom) 
prf.goal(B)
prf.axiom("contra", [B], [])

display(prf.thisproof())
# Out:
# SAVE AXIOM: The axiom named "contra" has been saved.
#                               Item  Level  Proof           Rule   Type Lines  \
#                    $\color{blue}B$      0      0           GOAL
# 1  $\color{green}B \wedge \lnot~B$      0      0  Contradiction  AXIOM
#
#   Proofs Comment
#
# 1

# %%
# test_entailment_definition_clean_1

from IPython.display import display, Math, Markdown, Latex, display_markdown, HTML
import pandas as pd
pd.options.display.max_colwidth=500
from altrea.wffs import And, Wff, Not
from altrea.rules import Proof

prf = Proof()
A = prf.proposition("A")
B = prf.proposition("B")
prf.setlogic()
prf.entailment(
    prf.mvalpha, 
    [prf.mvbeta], 
    name="identity", 
    displayname= "A=B", 
    description="Everything Equals Everything", 
    kind=prf.label_definition) 
prf.goal(B)
prf.premise(A)
prf.definition("identity", [A, B], [1])

display(prf.thisproof())
# Out:
# SAVE DEFINITION: The definition named "identity" has been saved.
#               Item  Level  Proof     Rule  Type Lines Proofs   Comment
#    $\color{blue}B$      0      0     GOAL
# 1              $A$      0      0  Premise  PREM
# 2  $\color{blue}B$      0      0      A=B   DEF     1         COMPLETE

# %%
# Logic already exists

from IPython.display import display, Math, Markdown, Latex, display_markdown, HTML
import pandas as pd
pd.options.display.max_colwidth=500
from altrea.wffs import And, Wff, Possibly
from altrea.rules import Proof

prf = Proof()
prf.setlogic('modalfitch')
#display(prf.definitions())
#display(prf.axioms())
#display(prf.rules())
display(prf.entailment(
    Possibly(prf.mvalpha), 
    [prf.mvalpha], 
    name="pos intro", 
    displayname= "Possibly Intro", 
    description="Possibly Introduction", 
    kind=""
))
# Out:
#                                                                                                                   Display
# Name                                                                                                            pos intro
# Display Name                                                                                               Possibly Intro
# Description                                                                                         Possibly Introduction
# Text                                                                                                           {α}  ⊢  ◇α
# LaTeX                                                                              $\{\alpha\} ~\vdash~ \Diamond~ \alpha$
# Expanded                                                                                            {[α]}  ⊢  Possibly(α)
# Pattern       (logic, 'pos intro', 'ConclusionPremises(Possibly({0}), [{0}])', 'Possibly Intro', 'Possibly Introduction')

# %%
# Logic is not defined

from IPython.display import display, Math, Markdown, Latex, display_markdown, HTML
import pandas as pd
pd.options.display.max_colwidth=500
from altrea.wffs import And, Wff, Or
from altrea.rules import Proof

prf = Proof()
prf.setlogic()
display(prf.entailment(
    Or(prf.mvalpha, prf.mvbeta), 
    [prf.mvalpha], 
    name="disj intro r", 
    displayname= "Disjunction Intro Right", 
    description="Disjunction Introduction Right Side", 
    kind= "" #prf.label_rule, prf.label_axiom, prf.label_definition
))
# Out:
#                                                                                                                                             Display
# Name                                                                                                                                   disj intro r
# Display Name                                                                                                                Disjunction Intro Right
# Description                                                                                                     Disjunction Introduction Right Side
# Text                                                                                                                                  {α}  ⊢  α | β
# LaTeX                                                                                                       $\{\alpha\} ~\vdash~ \alpha \vee \beta$
# Expanded                                                                                                                         {[α]}  ⊢  Or(α, β)
# Pattern       (logic, "disj intro r", "ConclusionPremises(Or({0}, {1}), [{0}])", "Disjunction Intro Right", "Disjunction Introduction Right Side"),

# %%
display(prf.rules())
# Out:
#                                                                                                                               Rules  \
# coimp elim                               $\{\alpha \equiv  \beta\} ~\vdash~ (\alpha \supset  \beta) \wedge (\beta \supset  \alpha)$
# coimp intro                              $\{(\alpha \supset  \beta) \wedge (\beta \supset  \alpha)\} ~\vdash~ \alpha \equiv  \beta$
# conj elim l                                                                               $\{\alpha \wedge \beta\} ~\vdash~ \alpha$
# conj elim r                                                                                $\{\alpha \wedge \beta\} ~\vdash~ \beta$
# conj intro                                                                         $\{\alpha,~\beta\} ~\vdash~ \alpha \wedge \beta$
# consistent intro                                                  $\{\Diamond~ (\alpha \wedge \beta)\} ~\vdash~ \alpha \circ \beta$
# consistent elim                                                   $\{\alpha \circ \beta\} ~\vdash~ \Diamond~ (\alpha \wedge \beta)$
# disj elim                                    $\{\alpha \vee \beta,~\alpha \supset  \gamma,~\beta \supset  \gamma\} ~\vdash~ \gamma$
# disj elim l       $\{\alpha \vee \beta,~\alpha \supset  \gamma,~\beta \supset  \bot~(\delta \wedge \lnot~\delta)\} ~\vdash~ \gamma$
# disj elim r       $\{\alpha \vee \beta,~\alpha \supset  \bot~(\delta \wedge \lnot~\delta),~\beta \supset  \gamma\} ~\vdash~ \gamma$
# imp elim                                                                         $\{\alpha,~\alpha \supset  \beta\} ~\vdash~ \beta$
# modusponens                                                                      $\{\alpha,~\alpha \supset  \beta\} ~\vdash~ \beta$
# nec elim                                                                                         $\{\Box~ \alpha\} ~\vdash~ \alpha$
# neg elim                                                      $\{\alpha,~\lnot~\alpha\} ~\vdash~ \bot~(\alpha \wedge \lnot~\alpha)$
# pos intro                                                                                    $\{\alpha\} ~\vdash~ \Diamond~ \alpha$
# s coimp elim                                                  $\{\alpha ~\backsimeq~ \beta\} ~\vdash~ \Box~ (\alpha \equiv  \beta)$
# s coimp intro                                                 $\{\Box~ (\alpha \equiv  \beta)\} ~\vdash~ \alpha ~\backsimeq~ \beta$
# s imp elim                                                        $\{\alpha ~\prec~ \beta\} ~\vdash~ \Box~ (\alpha \supset  \beta)$
# s imp intro                                                       $\{\Box~ (\alpha \supset  \beta)\} ~\vdash~ \alpha ~\prec~ \beta$
#
#                                          Description
# coimp elim                 Coimplication Elimination
# coimp intro               Coimplication Introduction
# conj elim l        Conjunction Elimination Left Side
# conj elim r       Conjunction Elimination Right Side
# conj intro                  Conjunction Introduction
# consistent intro        Consistent With Introduction
# consistent elim          Consistent With Elimination
# disj elim                    Disjunction Elimination
# disj elim l             Disjunction Elimination Left
# disj elim r            Disjunction Elimination Right
# imp elim                     Implication Elimination
# modusponens                             Modus Ponens
# nec elim                       Necessary Elimination
# neg elim                      Nenegation Elimination
# pos intro                      Possibly Introduction
# s coimp elim        Strict Coimplication Elimination
# s coimp intro      Strict Coimplication Introduction
# s imp elim            Strict Implication Elimination
# s imp intro          Strict Implication Introduction

# %% [markdown]
# <a id='goal'></a>
# ## Goal

# %%
# test_goal_clean_1: trivial proof

from IPython.display import display, Math, Markdown, Latex, display_markdown, HTML
import pandas as pd
pd.options.display.max_colwidth=500
from altrea.wffs import And, Wff
from altrea.rules import Proof

prf = Proof()
A = prf.proposition("A")
prf.setlogic()
prf.goal(A)
prf.premise(A)

display(prf.thisproof())
# Out:
#               Item  Level  Proof     Rule  Type Lines Proofs   Comment
#    $\color{blue}A$      0      0     GOAL
# 1  $\color{blue}A$      0      0  Premise  PREM               COMPLETE

# %%
# test_goal_notwff_1: Input cannot be a string.

from IPython.display import display, Math, Markdown, Latex, display_markdown, HTML
import pandas as pd
pd.options.display.max_colwidth=500
from altrea.wffs import And, Wff
from altrea.rules import Proof

prf = Proof()
A = prf.proposition("A")
prf.setlogic()
prf.goal("A")
prf.premise(A)

display(prf.thisproof())
# Out:
#  Item  Level  Proof Rule Type Lines Proofs  \
#            0      0
#
#                                                    Comment
#   STOPPED: The input is not an instance of the Wff object.

# %%
# test_goal_nologic_1: A logic must be defined before the goal is set so the goal can be constrained by it.

from IPython.display import display, Math, Markdown, Latex, display_markdown, HTML
import pandas as pd
pd.options.display.max_colwidth=500
from altrea.wffs import And, Wff
from altrea.rules import Proof

prf = Proof()
A = prf.proposition("A")
# prf.setlogic()
prf.goal(A)
prf.premise(A)

display(prf.thisproof())
# Out:
#  Item  Level  Proof Rule Type Lines Proofs  \
#            0      0
#
#                                              Comment
#   STOPPED: No logic has been declared for the proof.

# %% [markdown]
# <a id='hypothesis'></a>
# ## Hypothesis

# %%
# test_hypothesis_clean_1: Clean runfrom 

from IPython.display import display, Math, Markdown, Latex, display_markdown, HTML
import pandas as pd
pd.options.display.max_colwidth=500
from altrea.wffs import *
from altrea.rules import Proof

prf = Proof()
A = prf.proposition('A')
B = prf.proposition('B')
prf.setlogic()

prf.goal(Implies(A, B))
prf.premise(B)

prf.opensubproof()
prf.hypothesis(A)
prf.reiterate(1)
prf.closesubproof()
prf.implication_intro()

display(prf.thisproof())
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th style="text-align:center"></th>
#       <th style="text-align:center">Item</th>
#       <th style="text-align:center">Level</th>
#       <th style="text-align:center">Proof</th>
#       <th style="text-align:center">Rule</th>
#       <th style="text-align:center">Type</th>
#       <th style="text-align:center">Lines</th>
#       <th style="text-align:center">Proofs</th>
#       <th style="text-align:center">Comment</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th style="text-align:center"></th>
#       <td style="text-align:left">$\color{blue}A \supset  B$</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">GOAL</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#     </tr>
#     <tr>
#       <th style="text-align:center">1</th>
#       <td style="text-align:left">$B$</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">Premise</td>
#       <td style="text-align:left">PREM</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#     </tr>
#     <tr>
#       <th style="text-align:center">2</th>
#       <td style="text-align:left">$|\hspace{0.35cm} $$A$</td>
#       <td style="text-align:left">1</td>
#       <td style="text-align:left">1</td>
#       <td style="text-align:left">Hypothesis</td>
#       <td style="text-align:left">HYPO</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#     </tr>
#     <tr>
#       <th style="text-align:center">3</th>
#       <td style="text-align:left">$|\hspace{0.35cm} $$B$</td>
#       <td style="text-align:left">1</td>
#       <td style="text-align:left">1</td>
#       <td style="text-align:left">Reiteration</td>
#       <td style="text-align:left">REIT</td>
#       <td style="text-align:left">1</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#     </tr>
#     <tr>
#       <th style="text-align:center">4</th>
#       <td style="text-align:left">$\color{blue}A \supset  B$</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">Implication Intro</td>
#       <td style="text-align:left">TR</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left">2-3</td>
#       <td style="text-align:left">COMPLETE</td>
#     </tr>
#   </tbody>
# </table>

# %%
# test_hypothesis_notwff_1: The proof is stopped if the hypothesis is entered as a string.

from IPython.display import display, Math, Markdown, Latex, display_markdown, HTML
import pandas as pd
pd.options.display.max_colwidth=500
from altrea.wffs import And, Wff
from altrea.rules import Proof

prf = Proof()
B = prf.proposition('B')
prf.setlogic()

prf.goal(B, comment='There is a difference between the Wff A and the string "A"')

prf.opensubproof()
prf.hypothesis('A')  

display(prf.thisproof())
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th style="text-align:center"></th>
#       <th style="text-align:center">Item</th>
#       <th style="text-align:center">Level</th>
#       <th style="text-align:center">Proof</th>
#       <th style="text-align:center">Rule</th>
#       <th style="text-align:center">Type</th>
#       <th style="text-align:center">Lines</th>
#       <th style="text-align:center">Proofs</th>
#       <th style="text-align:center">Comment</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th style="text-align:center"></th>
#       <td style="text-align:left">$\color{blue}B$</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">GOAL</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left">There is a difference between the Wff A and the string "A"</td>
#     </tr>
#     <tr>
#       <th style="text-align:center">1</th>
#       <td style="text-align:left"></td>
#       <td style="text-align:left">1</td>
#       <td style="text-align:left">1</td>
#       <td style="text-align:left">Hypothesis</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left">STOPPED: The input is not an instance of the Wff object.</td>
#     </tr>
#   </tbody>
# </table>

# %%
# test_hypothesis_nogoal_1: The proof is stopped if there is no goal.

from IPython.display import display, Math, Markdown, Latex, display_markdown, HTML
import pandas as pd
pd.options.display.max_colwidth=500
from altrea.wffs import And, Wff
from altrea.rules import Proof

prf = Proof()
A = prf.proposition('A')
prf.setlogic()

#prf.goal(B, comment='There is a difference between the Wff A and the string "A"')

prf.opensubproof()
prf.hypothesis(A)  

display(prf.thisproof())
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th style="text-align:center"></th>
#       <th style="text-align:center">Item</th>
#       <th style="text-align:center">Level</th>
#       <th style="text-align:center">Proof</th>
#       <th style="text-align:center">Rule</th>
#       <th style="text-align:center">Type</th>
#       <th style="text-align:center">Lines</th>
#       <th style="text-align:center">Proofs</th>
#       <th style="text-align:center">Comment</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th style="text-align:center"></th>
#       <td style="text-align:left"></td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#     </tr>
#     <tr>
#       <th style="text-align:center">1</th>
#       <td style="text-align:left"></td>
#       <td style="text-align:left">1</td>
#       <td style="text-align:left">1</td>
#       <td style="text-align:left">Hypothesis</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left">STOPPED: The proof does not yet have a goal.</td>
#     </tr>
#   </tbody>
# </table>

# %%
# test_hypothesis_unavailablesubproof_1

from IPython.display import display, Math, Markdown, Latex, display_markdown, HTML
import pandas as pd
pd.options.display.max_colwidth=500
from altrea.wffs import And, Wff
from altrea.rules import Proof

prf = Proof()
A = prf.proposition('A')
prf.setlogic()

prf.goal(A)

prf.hypothesis(A)

display(prf.thisproof())
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th style="text-align:center"></th>
#       <th style="text-align:center">Item</th>
#       <th style="text-align:center">Level</th>
#       <th style="text-align:center">Proof</th>
#       <th style="text-align:center">Rule</th>
#       <th style="text-align:center">Type</th>
#       <th style="text-align:center">Lines</th>
#       <th style="text-align:center">Proofs</th>
#       <th style="text-align:center">Comment</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th style="text-align:center"></th>
#       <td style="text-align:left">$\color{blue}A$</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">GOAL</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#     </tr>
#     <tr>
#       <th style="text-align:center">1</th>
#       <td style="text-align:left"></td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">Hypothesis</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left">STOPPED: The subproof is not available.</td>
#     </tr>
#   </tbody>
# </table>

# %%
for i in prf.prooflist:
    print(i)
# Out:
# [0, [1, 1], -1, [1], 'NORMAL']

# %% [markdown]
# <a id='implication_elim'></a>
# ## Implication Elimination

# %%
# test_implication_elim_clean_1: Clean run: modus ponens

from IPython.display import display, Math, Markdown, Latex, display_markdown, HTML
import pandas as pd
pd.options.display.max_colwidth=500
from altrea.wffs import And, Wff
from altrea.rules import Proof

prf = Proof()
A = prf.proposition("A")
B = prf.proposition("B")
prf.setlogic()
prf.goal(B, comment="Modus Ponens")
prf.premise(A)
prf.premise(Implies(A, B))
prf.rule('imp elim', [A, B], [1, 2])

display(prf.thisproof())
# Out:
#               Item  Level  Proof              Rule  Type Lines Proofs  \
#    $\color{blue}B$      0      0              GOAL
# 1              $A$      0      0           Premise  PREM
# 2   $A \supset  B$      0      0           Premise  PREM
# 3  $\color{blue}B$      0      0  Implication Elim  RULE  1, 2
#
#         Comment
#    Modus Ponens
# 1
# 2
# 3      COMPLETE

# %%
# test_implication_elim_nosuchline_1: The first referenced line does not exist in the proof.

from IPython.display import display, Math, Markdown, Latex, display_markdown, HTML
import pandas as pd
pd.options.display.max_colwidth=500
from altrea.wffs import And, Wff
from altrea.rules import Proof

prf = Proof()
A = prf.proposition("A")
B = prf.proposition("B")
prf.setlogic()
prf.goal(B, comment="Modus Ponens")
prf.premise(A)
prf.premise(Implies(A, B))
prf.rule('imp elim', [A, B], [3, 2])
prf.hypothesis(A, comment="Nothing can be added after the proof is stopped.")

display(prf.thisproof())
# Out:
#               Item  Level  Proof              Rule  Type Lines Proofs  \
#    $\color{blue}B$      0      0              GOAL
# 1              $A$      0      0           Premise  PREM
# 2   $A \supset  B$      0      0           Premise  PREM
# 3                       0      0  Implication Elim           3
#
#                                                              Comment
#                                                         Modus Ponens
# 1
# 2
# 3  STOPPED: The referenced line is not a previous line of the proof.

# %%
# test_implication_elim_notinteger_2: The second referenced line does not exist in the proof.

from IPython.display import display, Math, Markdown, Latex, display_markdown, HTML
import pandas as pd
pd.options.display.max_colwidth=500
from altrea.wffs import And, Wff
from altrea.rules import Proof

prf = Proof()
A = prf.proposition("A")
B = prf.proposition("B")
prf.setlogic()
prf.goal(B, comment="Modus Ponens")
prf.premise(A)
prf.premise(Implies(A, B))
prf.rule('imp elim', [A, B], [1, -2.56789])
prf.hypothesis(A, comment="Nothing can be added after the proof is stopped.")

display(prf.thisproof())
# Out:
#               Item  Level  Proof              Rule  Type     Lines Proofs  \
#    $\color{blue}B$      0      0              GOAL
# 1              $A$      0      0           Premise  PREM
# 2   $A \supset  B$      0      0           Premise  PREM
# 3                       0      0  Implication Elim        -2.56789
#
#                                        Comment
#                                   Modus Ponens
# 1
# 2
# 3  STOPPED: The line number is not an integer.

# %%
# test_implication_elim_linescope_1: The first referenced line is not accessible.

from IPython.display import display, Math, Markdown, Latex, display_markdown, HTML
import pandas as pd
pd.options.display.max_colwidth=500
from altrea.wffs import And, Wff
from altrea.rules import Proof

prf = Proof()
A = prf.proposition("A")
B = prf.proposition("B")
prf.setlogic()

prf.goal(B, comment="Modus Ponens")
prf.premise(Implies(A, B))

prf.opensubproof()
prf.hypothesis(A)
prf.closesubproof()
prf.implication_intro()
prf.rule('imp elim', [A, B], [2, 1])
prf.hypothesis(A, comment="Nothing can be added after the proof is stopped.")

display(prf.thisproof())
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th style="text-align:center"></th>
#       <th style="text-align:center">Item</th>
#       <th style="text-align:center">Level</th>
#       <th style="text-align:center">Proof</th>
#       <th style="text-align:center">Rule</th>
#       <th style="text-align:center">Type</th>
#       <th style="text-align:center">Lines</th>
#       <th style="text-align:center">Proofs</th>
#       <th style="text-align:center">Comment</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th style="text-align:center"></th>
#       <td style="text-align:left">$\color{blue}B$</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">GOAL</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left">Modus Ponens</td>
#     </tr>
#     <tr>
#       <th style="text-align:center">1</th>
#       <td style="text-align:left">$A \supset  B$</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">Premise</td>
#       <td style="text-align:left">PREM</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#     </tr>
#     <tr>
#       <th style="text-align:center">2</th>
#       <td style="text-align:left">$|\hspace{0.35cm} $$A$</td>
#       <td style="text-align:left">1</td>
#       <td style="text-align:left">1</td>
#       <td style="text-align:left">Hypothesis</td>
#       <td style="text-align:left">HYPO</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#     </tr>
#     <tr>
#       <th style="text-align:center">3</th>
#       <td style="text-align:left">$A \supset  A$</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">Implication Intro</td>
#       <td style="text-align:left">TR</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left">2-2</td>
#       <td style="text-align:left"></td>
#     </tr>
#     <tr>
#       <th style="text-align:center">4</th>
#       <td style="text-align:left"></td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">Implication Elim</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left">2</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left">STOPPED: Referenced item is out of scope.</td>
#     </tr>
#   </tbody>
# </table>

# %%
# test_implication_elim_linescope_2: 

from IPython.display import display, Math, Markdown, Latex, display_markdown, HTML
import pandas as pd
pd.options.display.max_colwidth=500
from altrea.wffs import And, Wff
from altrea.rules import Proof

prf = Proof()
A = prf.proposition("A")
B = prf.proposition("B")
prf.setlogic()

prf.goal(B, comment="Modus Ponens")
prf.premise(Implies(A, B))

prf.opensubproof()
prf.hypothesis(A)
prf.closesubproof()
prf.implication_intro()
prf.rule('imp elim', [A, B], [1, 2])
prf.hypothesis(A, comment="Nothing can be added after the proof is stopped.")

display(prf.thisproof())
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th style="text-align:center"></th>
#       <th style="text-align:center">Item</th>
#       <th style="text-align:center">Level</th>
#       <th style="text-align:center">Proof</th>
#       <th style="text-align:center">Rule</th>
#       <th style="text-align:center">Type</th>
#       <th style="text-align:center">Lines</th>
#       <th style="text-align:center">Proofs</th>
#       <th style="text-align:center">Comment</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th style="text-align:center"></th>
#       <td style="text-align:left">$\color{blue}B$</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">GOAL</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left">Modus Ponens</td>
#     </tr>
#     <tr>
#       <th style="text-align:center">1</th>
#       <td style="text-align:left">$A \supset  B$</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">Premise</td>
#       <td style="text-align:left">PREM</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#     </tr>
#     <tr>
#       <th style="text-align:center">2</th>
#       <td style="text-align:left">$|\hspace{0.35cm} $$A$</td>
#       <td style="text-align:left">1</td>
#       <td style="text-align:left">1</td>
#       <td style="text-align:left">Hypothesis</td>
#       <td style="text-align:left">HYPO</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#     </tr>
#     <tr>
#       <th style="text-align:center">3</th>
#       <td style="text-align:left">$A \supset  A$</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">Implication Intro</td>
#       <td style="text-align:left">TR</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left">2-2</td>
#       <td style="text-align:left"></td>
#     </tr>
#     <tr>
#       <th style="text-align:center">4</th>
#       <td style="text-align:left"></td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">Implication Elim</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left">2</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left">STOPPED: Referenced item is out of scope.</td>
#     </tr>
#   </tbody>
# </table>

# %%
# test_implication_elim_notantecedent_1: The second referenced line is an implication, but the first is not the antecedent of it.

from IPython.display import display, Math, Markdown, Latex, display_markdown, HTML
import pandas as pd
pd.options.display.max_colwidth=500
from altrea.wffs import And, Wff
from altrea.rules import Proof

prf = Proof()
A = prf.proposition("A")
B = prf.proposition("B")
prf.setlogic()
prf.goal(B, comment="Modus Ponens")
prf.premise(Implies(A, B))
prf.premise(And(A, A))
prf.rule('imp elim', [A, B], [1, 2])
prf.hypothesis(A, comment="Nothing can be added after the proof is stopped.")

display(prf.thisproof())
# Out:
#               Item  Level  Proof              Rule  Type Lines Proofs  \
#    $\color{blue}B$      0      0              GOAL
# 1   $A \supset  B$      0      0           Premise  PREM
# 2     $A \wedge A$      0      0           Premise  PREM
# 3                       0      0  Implication Elim
#
#                                                                    Comment
#                                                               Modus Ponens
# 1
# 2
# 3  STOPPED: A required premise does not match a line in the current proof.

# %%
# test_implication_elim_notantecedent_2: Neither referenced line has an implication.

from IPython.display import display, Math, Markdown, Latex, display_markdown, HTML
import pandas as pd
pd.options.display.max_colwidth=500
from altrea.wffs import And, Wff
from altrea.rules import Proof

prf = Proof()
A = prf.proposition("A")
B = prf.proposition("B")
prf.setlogic()
prf.goal(B, comment="Modus Ponens")
prf.premise(Implies(A, B))
prf.premise(And(A, A))
prf.rule('imp elim', [A, B], [2, 1])
#prf.implication_elim(2, 1)
prf.hypothesis(A, comment="Nothing can be added after the proof is stopped.")

display(prf.thisproof())
# Out:
#               Item  Level  Proof              Rule  Type Lines Proofs  \
#    $\color{blue}B$      0      0              GOAL
# 1   $A \supset  B$      0      0           Premise  PREM
# 2     $A \wedge A$      0      0           Premise  PREM
# 3                       0      0  Implication Elim
#
#                                                                    Comment
#                                                               Modus Ponens
# 1
# 2
# 3  STOPPED: A required premise does not match a line in the current proof.

# %%
# test_implication_elim_notmodusponens_1

from IPython.display import display, Math, Markdown, Latex, display_markdown, HTML
import pandas as pd
pd.options.display.max_colwidth=500
from altrea.wffs import And, Wff
from altrea.rules import Proof

prf = Proof()
A = prf.proposition("A")
B = prf.proposition("B")
prf.setlogic()
prf.goal(B, comment="Modus Ponens")
prf.premise(A)
prf.premise(And(A, A))
prf.rule('imp elim', [A, B], [2, 1])
prf.hypothesis(A, comment="Nothing can be added after the proof is stopped.")

display(prf.thisproof())
# Out:
#               Item  Level  Proof              Rule  Type Lines Proofs  \
#    $\color{blue}B$      0      0              GOAL
# 1              $A$      0      0           Premise  PREM
# 2     $A \wedge A$      0      0           Premise  PREM
# 3                       0      0  Implication Elim
#
#                                                                    Comment
#                                                               Modus Ponens
# 1
# 2
# 3  STOPPED: A required premise does not match a line in the current proof.

# %% [markdown]
# <a id='implication_intro'></a>
# ## Implication Introduction

# %%
# test_implication_intro_clean_1: reflexivity of implication

from IPython.display import display, Math, Markdown, Latex, display_markdown, HTML
import pandas as pd
pd.options.display.max_colwidth=500
from altrea.wffs import And, Wff
from altrea.rules import Proof

prf = Proof()
A = prf.proposition("A")
prf.setlogic()

prf.goal(Implies(A, A), comment="Reflexivity of Implication")

prf.opensubproof()
prf.hypothesis(A)
prf.closesubproof()
prf.implication_intro()

display(prf.thisproof())
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th style="text-align:center"></th>
#       <th style="text-align:center">Item</th>
#       <th style="text-align:center">Level</th>
#       <th style="text-align:center">Proof</th>
#       <th style="text-align:center">Rule</th>
#       <th style="text-align:center">Type</th>
#       <th style="text-align:center">Lines</th>
#       <th style="text-align:center">Proofs</th>
#       <th style="text-align:center">Comment</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th style="text-align:center"></th>
#       <td style="text-align:left">$\color{blue}A \supset  A$</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">GOAL</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left">Reflexivity of Implication</td>
#     </tr>
#     <tr>
#       <th style="text-align:center">1</th>
#       <td style="text-align:left">$|\hspace{0.35cm} $$A$</td>
#       <td style="text-align:left">1</td>
#       <td style="text-align:left">1</td>
#       <td style="text-align:left">Hypothesis</td>
#       <td style="text-align:left">HYPO</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#     </tr>
#     <tr>
#       <th style="text-align:center">2</th>
#       <td style="text-align:left">$\color{blue}A \supset  A$</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">Implication Intro</td>
#       <td style="text-align:left">TR</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left">1-1</td>
#       <td style="text-align:left">COMPLETE</td>
#     </tr>
#   </tbody>
# </table>

# %%
# test_implication_intro_clean_2:

from IPython.display import display, Math, Markdown, Latex, display_markdown, HTML
import pandas as pd
pd.options.display.max_colwidth=500
from altrea.wffs import *
from altrea.rules import Proof

prf = Proof()
A = prf.proposition("A")
B = prf.proposition("B")
C = prf.proposition("C")
D = prf.proposition("D")
E = prf.proposition("E")
prf.setlogic()

prf.goal(Implies(E, Implies(D, Implies(C, And(A, B)))))
prf.premise(A)
prf.premise(B)

prf.opensubproof()
prf.hypothesis(E)
prf.opensubproof()
prf.hypothesis(D)
prf.opensubproof()
prf.hypothesis(C)
prf.reiterate(1)
prf.reiterate(2)
prf.rule("conj intro", [A, B], [6, 7])
prf.closesubproof()
prf.implication_intro()
prf.closesubproof()
prf.implication_intro()
prf.closesubproof()
prf.implication_intro()

prf.displaylog()
display(prf.thisproof())
# Out:
#  1 PROPOSITION: The letter "A" for a generic well-formed formula has been defined with 1 so far for this proof.
#  1 PROPOSITION: The letter "B" for a generic well-formed formula has been defined with 2 so far for this proof.
#  1 PROPOSITION: The letter "C" for a generic well-formed formula has been defined with 3 so far for this proof.
#  1 PROPOSITION: The letter "D" for a generic well-formed formula has been defined with 4 so far for this proof.
#  1 PROPOSITION: The letter "E" for a generic well-formed formula has been defined with 5 so far for this proof.
#  1 SET LOGIC: "" has been selected as the logic described as "No Description" and stored in database "No Database".
#  1 RESTRICTED: The restricted use of explosion has been set to False.
#  1 GOAL: The goal "E ⊃ (D ⊃ (C ⊃ (A & B)))" has been added to the goals.
#  1 PREMISE: Item "A" has been added to the premises.
#  2 PREMISE: Item "B" has been added to the premises.
#  3 OPEN SUBPROOF: Subproof 1 has been opened with status "NORMAL".
#  3 HYPOTHESIS: A new subproof 1 has been started with item "E".
#  4 OPEN SUBPROOF: Subproof 2 has been opened with status "NORMAL".
#  4 HYPOTHESIS: A new subproof 2 has been started with item "D".
#  5 OPEN SUBPROOF: Subproof 3 has been opened with status "NORMAL".
#  5 HYPOTHESIS: A new subproof 3 has been started with item "C".
#  6 REITERATION: Item "A" on line 1 has been reiterated into subproof 3.
#  7 REITERATION: Item "B" on line 2 has been reiterated into subproof 3.
#  8 SUBSTITUTE EVALUATE: The placeholder(s) in the string "ConclusionPremises(And({0}, {1}), [{0}, {1}])" have been replaced with "['A', 'B']" to become "ConclusionPremises(And(A, B), [A, B])".
#  8 RULE: Item "A & B" has been added through the "Conjunction Introduction" transformation rule.
#  9 CLOSE SUBPROOF: The current "NORMAL" subproof 3 has been closed.
#  9 IMPLICATION INTRO: Item "C ⊃ (A & B)" has been derived upon closing subproof 3.
# 10 CLOSE SUBPROOF: The current "NORMAL" subproof 2 has been closed.
# 10 IMPLICATION INTRO: Item "D ⊃ (C ⊃ (A & B))" has been derived upon closing subproof 2.
# 11 CLOSE SUBPROOF: The current "NORMAL" subproof 1 has been closed.
# 11 IMPLICATION INTRO: Item "E ⊃ (D ⊃ (C ⊃ (A & B)))" has been derived upon closing subproof 1.
# 11 The proof is complete.
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th style="text-align:center"></th>
#       <th style="text-align:center">Item</th>
#       <th style="text-align:center">Level</th>
#       <th style="text-align:center">Proof</th>
#       <th style="text-align:center">Rule</th>
#       <th style="text-align:center">Type</th>
#       <th style="text-align:center">Lines</th>
#       <th style="text-align:center">Proofs</th>
#       <th style="text-align:center">Comment</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th style="text-align:center"></th>
#       <td style="text-align:left">$\color{blue}E \supset  (D \supset  (C \supset  (A \wedge B)))$</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">GOAL</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#     </tr>
#     <tr>
#       <th style="text-align:center">1</th>
#       <td style="text-align:left">$A$</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">Premise</td>
#       <td style="text-align:left">PREM</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#     </tr>
#     <tr>
#       <th style="text-align:center">2</th>
#       <td style="text-align:left">$B$</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">Premise</td>
#       <td style="text-align:left">PREM</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#     </tr>
#     <tr>
#       <th style="text-align:center">3</th>
#       <td style="text-align:left">$|\hspace{0.35cm} $$E$</td>
#       <td style="text-align:left">1</td>
#       <td style="text-align:left">1</td>
#       <td style="text-align:left">Hypothesis</td>
#       <td style="text-align:left">HYPO</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#     </tr>
#     <tr>
#       <th style="text-align:center">4</th>
#       <td style="text-align:left">$|\hspace{0.35cm} $$|\hspace{0.35cm} $$D$</td>
#       <td style="text-align:left">2</td>
#       <td style="text-align:left">2</td>
#       <td style="text-align:left">Hypothesis</td>
#       <td style="text-align:left">HYPO</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#     </tr>
#     <tr>
#       <th style="text-align:center">5</th>
#       <td style="text-align:left">$|\hspace{0.35cm} $$|\hspace{0.35cm} $$|\hspace{0.35cm} $$C$</td>
#       <td style="text-align:left">3</td>
#       <td style="text-align:left">3</td>
#       <td style="text-align:left">Hypothesis</td>
#       <td style="text-align:left">HYPO</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#     </tr>
#     <tr>
#       <th style="text-align:center">6</th>
#       <td style="text-align:left">$|\hspace{0.35cm} $$|\hspace{0.35cm} $$|\hspace{0.35cm} $$A$</td>
#       <td style="text-align:left">3</td>
#       <td style="text-align:left">3</td>
#       <td style="text-align:left">Reiteration</td>
#       <td style="text-align:left">REIT</td>
#       <td style="text-align:left">1</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#     </tr>
#     <tr>
#       <th style="text-align:center">7</th>
#       <td style="text-align:left">$|\hspace{0.35cm} $$|\hspace{0.35cm} $$|\hspace{0.35cm} $$B$</td>
#       <td style="text-align:left">3</td>
#       <td style="text-align:left">3</td>
#       <td style="text-align:left">Reiteration</td>
#       <td style="text-align:left">REIT</td>
#       <td style="text-align:left">2</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#     </tr>
#     <tr>
#       <th style="text-align:center">8</th>
#       <td style="text-align:left">$|\hspace{0.35cm} $$|\hspace{0.35cm} $$|\hspace{0.35cm} $$A \wedge B$</td>
#       <td style="text-align:left">3</td>
#       <td style="text-align:left">3</td>
#       <td style="text-align:left">Conjunction Intro</td>
#       <td style="text-align:left">RULE</td>
#       <td style="text-align:left">6, 7</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#     </tr>
#     <tr>
#       <th style="text-align:center">9</th>
#       <td style="text-align:left">$|\hspace{0.35cm} $$|\hspace{0.35cm} $$C \supset  (A \wedge B)$</td>
#       <td style="text-align:left">2</td>
#       <td style="text-align:left">2</td>
#       <td style="text-align:left">Implication Intro</td>
#       <td style="text-align:left">TR</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left">5-8</td>
#       <td style="text-align:left"></td>
#     </tr>
#     <tr>
#       <th style="text-align:center">10</th>
#       <td style="text-align:left">$|\hspace{0.35cm} $$D \supset  (C \supset  (A \wedge B))$</td>
#       <td style="text-align:left">1</td>
#       <td style="text-align:left">1</td>
#       <td style="text-align:left">Implication Intro</td>
#       <td style="text-align:left">TR</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left">4-9</td>
#       <td style="text-align:left"></td>
#     </tr>
#     <tr>
#       <th style="text-align:center">11</th>
#       <td style="text-align:left">$\color{blue}E \supset  (D \supset  (C \supset  (A \wedge B)))$</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">Implication Intro</td>
#       <td style="text-align:left">TR</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left">3-10</td>
#       <td style="text-align:left">COMPLETE</td>
#     </tr>
#   </tbody>
# </table>

# %%
print(f"subproof_status = {prf.subproof_status}, subproofavailable = {prf.subproofavailable}, status ={prf.status}")
for i in prf.prooflist:
    print(i)
for i in prf.proofdata:
    print(i)
# Out:
# subproof_status = NORMAL, subproofavailable = Open, status =
# [0, [1], -1, [1, 2], 'NORMAL']
# [1, [3], 0, [3], 'NORMAL']
# [2, [4], 1, [4], 'NORMAL']
# [3, [5], 2, [5], 'NORMAL']
# ['', '', '', '']
# ['', <altrea.wffs.Proposition object at 0x000001F012BAF0E0>, 0, 0, 'Premise', '', '', '', 'PREM', '']
# ['', <altrea.wffs.Proposition object at 0x000001F013B1BF20>, 0, 0, 'Premise', '', '', '', 'PREM', '']
# ['', <altrea.wffs.Proposition object at 0x000001F01385E360>, 1, 1, 'Hypothesis', '', '', '', 'HYPO', '{0}']
# ['', <altrea.wffs.Proposition object at 0x000001F01385CAA0>, 2, 2, 'Hypothesis', '', '', '', 'HYPO', '{0}{0}']

# %%
# test_implication_intro_clean_3: 

from IPython.display import display, Math, Markdown, Latex, display_markdown, HTML
import pandas as pd
pd.options.display.max_colwidth=500
from altrea.wffs import *
from altrea.rules import Proof

prf = Proof()
A = prf.proposition("A")
B = prf.proposition("B")
C = prf.proposition("C")
prf.setlogic()

prf.goal(Implies(A, A))

prf.opensubproof()
prf.hypothesis(B)
prf.hypothesis(A)
prf.hypothesis(C)
prf.rule("conj intro", [B, A], [1, 2])
prf.closesubproof()
prf.implication_intro()

display(prf.thisproof())
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th style="text-align:center"></th>
#       <th style="text-align:center">Item</th>
#       <th style="text-align:center">Level</th>
#       <th style="text-align:center">Proof</th>
#       <th style="text-align:center">Rule</th>
#       <th style="text-align:center">Type</th>
#       <th style="text-align:center">Lines</th>
#       <th style="text-align:center">Proofs</th>
#       <th style="text-align:center">Comment</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th style="text-align:center"></th>
#       <td style="text-align:left">$\color{blue}A \supset  A$</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">GOAL</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#     </tr>
#     <tr>
#       <th style="text-align:center">1</th>
#       <td style="text-align:left">$|\hspace{0.35cm} $$\color{red}B$</td>
#       <td style="text-align:left">1</td>
#       <td style="text-align:left">1</td>
#       <td style="text-align:left">Hypothesis</td>
#       <td style="text-align:left">HYPO</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#     </tr>
#     <tr>
#       <th style="text-align:center">2</th>
#       <td style="text-align:left">$|\hspace{0.35cm} $$\color{red}A$</td>
#       <td style="text-align:left">1</td>
#       <td style="text-align:left">1</td>
#       <td style="text-align:left">Hypothesis</td>
#       <td style="text-align:left">HYPO</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#     </tr>
#     <tr>
#       <th style="text-align:center">3</th>
#       <td style="text-align:left">$|\hspace{0.35cm} $$\color{red}C$</td>
#       <td style="text-align:left">1</td>
#       <td style="text-align:left">1</td>
#       <td style="text-align:left">Hypothesis</td>
#       <td style="text-align:left">HYPO</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#     </tr>
#     <tr>
#       <th style="text-align:center">4</th>
#       <td style="text-align:left">$|\hspace{0.35cm} $$\color{red}B \wedge A$</td>
#       <td style="text-align:left">1</td>
#       <td style="text-align:left">1</td>
#       <td style="text-align:left">Conjunction Intro</td>
#       <td style="text-align:left">RULE</td>
#       <td style="text-align:left">1, 2</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#     </tr>
#     <tr>
#       <th style="text-align:center">5</th>
#       <td style="text-align:left">$\color{green}((B \wedge A) \wedge C) \supset  (B \wedge A)$</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">Implication Intro</td>
#       <td style="text-align:left">TR</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left">1-4</td>
#       <td style="text-align:left"></td>
#     </tr>
#   </tbody>
# </table>

# %%
# test_implication_intro_strict_clean_1: Clean run: strict subproof

from IPython.display import display, Math, Markdown, Latex, display_markdown, HTML
import pandas as pd
pd.options.display.max_colwidth=500
from altrea.wffs import And, Wff, Implies
from altrea.rules import Proof

prf = Proof()
A = prf.proposition("A")
prf.setlogic()

prf.goal(Implies(A, A), comment="Strict Subproof")

prf.openstrictsubproof()
prf.hypothesis(A)

prf.closestrictsubproof()
prf.implication_intro()

display(prf.thisproof())
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th style="text-align:center"></th>
#       <th style="text-align:center">Item</th>
#       <th style="text-align:center">Level</th>
#       <th style="text-align:center">Proof</th>
#       <th style="text-align:center">Rule</th>
#       <th style="text-align:center">Type</th>
#       <th style="text-align:center">Lines</th>
#       <th style="text-align:center">Proofs</th>
#       <th style="text-align:center">Comment</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th style="text-align:center"></th>
#       <td style="text-align:left">$\color{blue}A \supset  A$</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">GOAL</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left">Strict Subproof</td>
#     </tr>
#     <tr>
#       <th style="text-align:center">1</th>
#       <td style="text-align:left">$\Vert\hspace{0.35cm} $$A$</td>
#       <td style="text-align:left">1</td>
#       <td style="text-align:left">1</td>
#       <td style="text-align:left">Hypothesis</td>
#       <td style="text-align:left">HYPO</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#     </tr>
#     <tr>
#       <th style="text-align:center">2</th>
#       <td style="text-align:left">$\color{blue}A \supset  A$</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">Implication Intro</td>
#       <td style="text-align:left">TR</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left">1-1</td>
#       <td style="text-align:left">COMPLETE</td>
#     </tr>
#   </tbody>
# </table>

# %%
for i in prf.prooflist:
    print(i)

print(prf.closedproofid)
# Out:
# [0, [1, 2], -1, [], 'NORMAL']
# [1, [1, 1], 0, [1], 'STRICT']
# 0

# %%
# test_implication_intro_unavailablesubproof_1: Attempt to close the main proof which can only be closed by completing the proof.

from IPython.display import display, Math, Markdown, Latex, display_markdown, HTML
import pandas as pd
pd.options.display.max_colwidth=500
from altrea.wffs import *
from altrea.rules import Proof

prf = Proof()
A = prf.proposition("A")
prf.setlogic()

prf.goal(Implies(A, A))

prf.premise(A)
prf.implication_intro()
prf.hypothesis(A, comment="Nothing can be added after the proof is stopped.")

display(prf.thisproof())
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th style="text-align:center"></th>
#       <th style="text-align:center">Item</th>
#       <th style="text-align:center">Level</th>
#       <th style="text-align:center">Proof</th>
#       <th style="text-align:center">Rule</th>
#       <th style="text-align:center">Type</th>
#       <th style="text-align:center">Lines</th>
#       <th style="text-align:center">Proofs</th>
#       <th style="text-align:center">Comment</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th style="text-align:center"></th>
#       <td style="text-align:left">$\color{blue}A \supset  A$</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">GOAL</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#     </tr>
#     <tr>
#       <th style="text-align:center">1</th>
#       <td style="text-align:left">$A$</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">Premise</td>
#       <td style="text-align:left">PREM</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#     </tr>
#     <tr>
#       <th style="text-align:center">2</th>
#       <td style="text-align:left"></td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">Implication Intro</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left">STOPPED: The subproof is not available.</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# <a id='item'></a>
# ## Item

# %%
# test_item_clean_1: Clean run 1

from IPython.display import display, Math, Markdown, Latex, display_markdown, HTML
import pandas as pd
pd.options.display.max_colwidth=500
from altrea.wffs import And, Wff, Or
from altrea.rules import Proof

prf = Proof()
A = prf.proposition('A')
B = prf.proposition('B')
prf.setlogic()
prf.goal(Implies(Or(A, B), And(A, B)))
prf.premise(prf.item(0).left)
prf.premise(prf.item(0).right)

display(prf.thisproof())
# Out:
#                                              Item  Level  Proof     Rule  \
#    $\color{blue}(A \vee B) \supset  (A \wedge B)$      0      0     GOAL
# 1                         $\color{green}A \vee B$      0      0  Premise
# 2                       $\color{green}A \wedge B$      0      0  Premise
#
#    Type Lines Proofs Comment
#
# 1  PREM
# 2  PREM

# %%
# test_item_clean_2: Clean run 2

from IPython.display import display, Math, Markdown, Latex, display_markdown, HTML
import pandas as pd
pd.options.display.max_colwidth=500
from altrea.wffs import And, Wff, Necessary, Or, And
from altrea.rules import Proof

prf = Proof()
A = prf.proposition('A')
B = prf.proposition('B')
prf.setlogic()
prf.goal(Implies(Or(A, B), And(A, B)))
prf.premise(Necessary(A))
prf.rule('nec elim', [prf.item(1).wff], [1])

display(prf.thisproof())
# Out:
#                                              Item  Level  Proof  \
#    $\color{blue}(A \vee B) \supset  (A \wedge B)$      0      0
# 1                          $\color{green}\Box~ A$      0      0
# 2                                $\color{green}A$      0      0
#
#              Rule  Type Lines Proofs Comment
#              GOAL
# 1         Premise  PREM
# 2  Necessary Elim  RULE     1

# %%
# test_item_clean_3: Clean run 3

from IPython.display import display, Math, Markdown, Latex, display_markdown, HTML
import pandas as pd
pd.options.display.max_colwidth=500
from altrea.wffs import And, Wff
from altrea.rules import Proof

prf = Proof()
A = prf.proposition('A')
B = prf.proposition('B')
prf.setlogic()
prf.goal(And(Necessary(A), Necessary(B)))
prf.premise(prf.item(0).left)
prf.premise(prf.item(0).right)

display(prf.thisproof())
# Out:
#                                    Item  Level  Proof     Rule  Type Lines  \
#    $\color{blue}\Box~ A \wedge \Box~ B$      0      0     GOAL
# 1                $\color{green}\Box~ A$      0      0  Premise  PREM
# 2                $\color{green}\Box~ B$      0      0  Premise  PREM
#
#   Proofs Comment
#
# 1
# 2

# %% [markdown]
# <a id='necessary_elim'></a>
# ## Necessary Elimination

# %%
# test_necessary_elim_clean_1: Clean run

from IPython.display import display, Math, Markdown, Latex, display_markdown, HTML
import pandas as pd
pd.options.display.max_colwidth=500
from altrea.wffs import And, Wff, Necessary
from altrea.rules import Proof

prf = Proof()
prf.setrestricted(True)
A = prf.proposition("A")
prf.setlogic()
prf.goal(A)
prf.premise(Necessary(A))
prf.rule("nec elim", [prf.item(1).wff], [1])
#prf.necessary_elim(1)

display(prf.thisproof())
# Out:
#               Item  Level  Proof            Rule  Type Lines Proofs   Comment
#    $\color{blue}A$      0      0            GOAL
# 1        $\Box~ A$      0      0         Premise  PREM
# 2  $\color{blue}A$      0      0  Necessary Elim  RULE     1         COMPLETE

# %%
# test_necessary_elim_notnecessary_1: Error: not necessary

from IPython.display import display, Math, Markdown, Latex, display_markdown, HTML
import pandas as pd
pd.options.display.max_colwidth=500
from altrea.wffs import And, Wff
from altrea.rules import Proof

prf = Proof()
prf.setrestricted(True)
A = prf.proposition("A")
B = prf.proposition("B")
prf.setlogic()
prf.goal(A)
prf.premise(B)
prf.rule("nec elim", [B], [1])

display(prf.thisproof())
# Out:
#               Item  Level  Proof            Rule  Type Lines Proofs  \
#    $\color{blue}A$      0      0            GOAL
# 1              $B$      0      0         Premise  PREM
# 2                       0      0  Necessary Elim
#
#                                                                    Comment
#
# 1
# 2  STOPPED: A required premise does not match a line in the current proof.

# %%
# test_necessary_elim_nosuchline_1: Error: line does not exist

from IPython.display import display, Math, Markdown, Latex, display_markdown, HTML
import pandas as pd
pd.options.display.max_colwidth=500
from altrea.wffs import And, Wff
from altrea.rules import Proof

prf = Proof()
prf.setrestricted(True)
A = prf.proposition("A")
B = prf.proposition("B")
prf.setlogic()
prf.goal(A)
prf.premise(B)
prf.rule("nec elim", [B], [2])

display(prf.thisproof())
# Out:
#               Item  Level  Proof            Rule  Type Lines Proofs  \
#    $\color{blue}A$      0      0            GOAL
# 1              $B$      0      0         Premise  PREM
# 2                       0      0  Necessary Elim           2
#
#                                                              Comment
#
# 1
# 2  STOPPED: The referenced line is not a previous line of the proof.

# %%
# test_necessary_elim_linescope_1: Error: line not inscope

from IPython.display import display, Math, Markdown, Latex, display_markdown, HTML
import pandas as pd
pd.options.display.max_colwidth=500
from altrea.wffs import *
from altrea.rules import Proof

prf = Proof()
prf.setrestricted(True)
A = prf.proposition("A")
B = prf.proposition("B")
prf.setlogic()

prf.goal(A)

prf.opensubproof()
prf.hypothesis(Necessary(B))
prf.closesubproof()
prf.implication_intro()
prf.rule("nec elim", [B], [1])

display(prf.thisproof())
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th style="text-align:center"></th>
#       <th style="text-align:center">Item</th>
#       <th style="text-align:center">Level</th>
#       <th style="text-align:center">Proof</th>
#       <th style="text-align:center">Rule</th>
#       <th style="text-align:center">Type</th>
#       <th style="text-align:center">Lines</th>
#       <th style="text-align:center">Proofs</th>
#       <th style="text-align:center">Comment</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th style="text-align:center"></th>
#       <td style="text-align:left">$\color{blue}A$</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">GOAL</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#     </tr>
#     <tr>
#       <th style="text-align:center">1</th>
#       <td style="text-align:left">$|\hspace{0.35cm} $$\Box~ B$</td>
#       <td style="text-align:left">1</td>
#       <td style="text-align:left">1</td>
#       <td style="text-align:left">Hypothesis</td>
#       <td style="text-align:left">HYPO</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#     </tr>
#     <tr>
#       <th style="text-align:center">2</th>
#       <td style="text-align:left">$\Box~ B \supset  \Box~ B$</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">Implication Intro</td>
#       <td style="text-align:left">TR</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left">1-1</td>
#       <td style="text-align:left"></td>
#     </tr>
#     <tr>
#       <th style="text-align:center">3</th>
#       <td style="text-align:left"></td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">Necessary Elim</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left">1</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left">STOPPED: Referenced item is out of scope.</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# <a id='necessary_intro'></a>
# ## Necessary Introduction

# %%
# test_necessary_intro_clean_1: Clean run

from IPython.display import display, Math, Markdown, Latex, display_markdown, HTML
import pandas as pd
pd.options.display.max_colwidth=500
from altrea.wffs import And, Wff, Necessary
from altrea.rules import Proof

prf = Proof()
prf.setrestricted(True)
A = prf.proposition("A")
prf.setlogic()

prf.goal(A)
prf.premise(Necessary(A))

prf.openstrictsubproof()
prf.reiterate(1)
prf.closestrictsubproof()
prf.necessary_intro()

display(prf.thisproof())
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th style="text-align:center"></th>
#       <th style="text-align:center">Item</th>
#       <th style="text-align:center">Level</th>
#       <th style="text-align:center">Proof</th>
#       <th style="text-align:center">Rule</th>
#       <th style="text-align:center">Type</th>
#       <th style="text-align:center">Lines</th>
#       <th style="text-align:center">Proofs</th>
#       <th style="text-align:center">Comment</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th style="text-align:center"></th>
#       <td style="text-align:left">$\color{blue}A$</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">GOAL</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#     </tr>
#     <tr>
#       <th style="text-align:center">1</th>
#       <td style="text-align:left">$\color{green}\Box~ A$</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">Premise</td>
#       <td style="text-align:left">PREM</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#     </tr>
#     <tr>
#       <th style="text-align:center">2</th>
#       <td style="text-align:left">$\Vert\hspace{0.35cm} $$\color{red}\Box~ A$</td>
#       <td style="text-align:left">1</td>
#       <td style="text-align:left">1</td>
#       <td style="text-align:left">Reiteration</td>
#       <td style="text-align:left">REIT</td>
#       <td style="text-align:left">1</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#     </tr>
#     <tr>
#       <th style="text-align:center">3</th>
#       <td style="text-align:left">$\color{green}\Box~ \Box~ A$</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">Necessary Intro</td>
#       <td style="text-align:left">TR</td>
#       <td style="text-align:left">2</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#     </tr>
#   </tbody>
# </table>

# %%
# test_necessary_intro_clean_2: Clean run 

from IPython.display import display, Math, Markdown, Latex, display_markdown, HTML
import pandas as pd
pd.options.display.max_colwidth=500
from altrea.wffs import And, Wff, Necessary
from altrea.rules import Proof

prf = Proof()
prf.setrestricted(True)
A = prf.proposition("A")
prf.setlogic()

prf.goal(A)
prf.premise(Necessary(A))

prf.openstrictsubproof()
prf.reiterate(1)
prf.rule("nec elim", [A], [2])
prf.closestrictsubproof()
prf.necessary_intro()

display(prf.thisproof())
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th style="text-align:center"></th>
#       <th style="text-align:center">Item</th>
#       <th style="text-align:center">Level</th>
#       <th style="text-align:center">Proof</th>
#       <th style="text-align:center">Rule</th>
#       <th style="text-align:center">Type</th>
#       <th style="text-align:center">Lines</th>
#       <th style="text-align:center">Proofs</th>
#       <th style="text-align:center">Comment</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th style="text-align:center"></th>
#       <td style="text-align:left">$\color{blue}A$</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">GOAL</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#     </tr>
#     <tr>
#       <th style="text-align:center">1</th>
#       <td style="text-align:left">$\color{green}\Box~ A$</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">Premise</td>
#       <td style="text-align:left">PREM</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#     </tr>
#     <tr>
#       <th style="text-align:center">2</th>
#       <td style="text-align:left">$\Vert\hspace{0.35cm} $$\color{red}\Box~ A$</td>
#       <td style="text-align:left">1</td>
#       <td style="text-align:left">1</td>
#       <td style="text-align:left">Reiteration</td>
#       <td style="text-align:left">REIT</td>
#       <td style="text-align:left">1</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#     </tr>
#     <tr>
#       <th style="text-align:center">3</th>
#       <td style="text-align:left">$\Vert\hspace{0.35cm} $$\color{red}A$</td>
#       <td style="text-align:left">1</td>
#       <td style="text-align:left">1</td>
#       <td style="text-align:left">Necessary Elim</td>
#       <td style="text-align:left">RULE</td>
#       <td style="text-align:left">2</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#     </tr>
#     <tr>
#       <th style="text-align:center">4</th>
#       <td style="text-align:left">$\color{green}\Box~ A$</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">Necessary Intro</td>
#       <td style="text-align:left">TR</td>
#       <td style="text-align:left">3</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#     </tr>
#   </tbody>
# </table>

# %%
# test_necessary_intro_ruleclass_1: Error: ruleclass

from IPython.display import display, Math, Markdown, Latex, display_markdown, HTML
import pandas as pd
pd.options.display.max_colwidth=500
from altrea.wffs import And, Wff
from altrea.rules import Proof

prf = Proof()
prf.setrestricted(True)
A = prf.proposition("A")
prf.setlogic()

prf.goal(A)
prf.premise(Necessary(A))

prf.openstrictsubproof()
prf.reiterate(1)
prf.proofrules = prf.rule_axiomatic
prf.necessary_intro()

display(prf.thisproof())
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th style="text-align:center"></th>
#       <th style="text-align:center">Item</th>
#       <th style="text-align:center">Level</th>
#       <th style="text-align:center">Proof</th>
#       <th style="text-align:center">Rule</th>
#       <th style="text-align:center">Type</th>
#       <th style="text-align:center">Lines</th>
#       <th style="text-align:center">Proofs</th>
#       <th style="text-align:center">Comment</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th style="text-align:center"></th>
#       <td style="text-align:left">$\color{blue}A$</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">GOAL</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#     </tr>
#     <tr>
#       <th style="text-align:center">1</th>
#       <td style="text-align:left">$\Box~ A$</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">Premise</td>
#       <td style="text-align:left">PREM</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#     </tr>
#     <tr>
#       <th style="text-align:center">2</th>
#       <td style="text-align:left">$\Vert\hspace{0.35cm} $$\Box~ A$</td>
#       <td style="text-align:left">1</td>
#       <td style="text-align:left">1</td>
#       <td style="text-align:left">Reiteration</td>
#       <td style="text-align:left">REIT</td>
#       <td style="text-align:left">1</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#     </tr>
#     <tr>
#       <th style="text-align:center">3</th>
#       <td style="text-align:left"></td>
#       <td style="text-align:left">1</td>
#       <td style="text-align:left">1</td>
#       <td style="text-align:left">Necessary Intro</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left">STOPPED: This inference rule is not part of the selected set of rules.</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# <a id='negation_elim'></a>
# ## Negation Elimination

# %%
# test_negation_elim_clean_1: Clean run

from IPython.display import display, Math, Markdown, Latex, display_markdown, HTML
import pandas as pd
pd.options.display.max_colwidth=500
from altrea.wffs import And, Wff, Not
from altrea.rules import Proof

prf = Proof()
prf.setrestricted(True)
A = prf.proposition("A")
prf.setlogic()
prf.goal(And(A, A))
prf.premise(A)
prf.premise(Not(A))
prf.rule("neg elim", [A], [1, 2])
#prf.negation_elim(1, 2)

display(prf.thisproof())
# Out:
#                        Item  Level  Proof           Rule  Type Lines Proofs  \
#    $\color{blue}A \wedge A$      0      0           GOAL
# 1          $\color{green}A$      0      0        Premise  PREM
# 2    $\color{green}\lnot~A$      0      0        Premise  PREM
# 3      $\color{green}\bot~$      0      0  Negation Elim  RULE  1, 2
#
#    Comment
#
# 1
# 2
# 3  VACUOUS

# %%
# test_negation_elim_nosuchline_1: The first line does not exist in the proof.

from IPython.display import display, Math, Markdown, Latex, display_markdown, HTML
import pandas as pd
pd.options.display.max_colwidth=500
from altrea.wffs import And, Wff, Not
from altrea.rules import Proof

prf = Proof()
A = prf.proposition("A")
prf.setlogic()
prf.goal(And(A, A))
prf.premise(A)
prf.premise(Not(A))
prf.rule("neg elim", [A], [3, 2])

display(prf.thisproof())
# Out:
#                        Item  Level  Proof           Rule  Type Lines Proofs  \
#    $\color{blue}A \wedge A$      0      0           GOAL
# 1                       $A$      0      0        Premise  PREM
# 2                 $\lnot~A$      0      0        Premise  PREM
# 3                                0      0  Negation Elim           3
#
#                                                              Comment
#
# 1
# 2
# 3  STOPPED: The referenced line is not a previous line of the proof.

# %%
# test_negation_elim_nosuchline_2: The second line does not exist in the proof.

from IPython.display import display, Math, Markdown, Latex, display_markdown, HTML
import pandas as pd
pd.options.display.max_colwidth=500
from altrea.wffs import And, Wff, Not
from altrea.rules import Proof

prf = Proof()
A = prf.proposition("A")
prf.setlogic()
prf.goal(And(A, A))
prf.premise(A)
prf.premise(Not(A))
prf.rule("neg elim", [A], [1, 3567])

display(prf.thisproof())
# Out:
#                        Item  Level  Proof           Rule  Type Lines Proofs  \
#    $\color{blue}A \wedge A$      0      0           GOAL
# 1                       $A$      0      0        Premise  PREM
# 2                 $\lnot~A$      0      0        Premise  PREM
# 3                                0      0  Negation Elim        3567
#
#                                                              Comment
#
# 1
# 2
# 3  STOPPED: The referenced line is not a previous line of the proof.

# %%
# test_negation_elim_linescope_1: The first line is not accessible.

from IPython.display import display, Math, Markdown, Latex, display_markdown, HTML
import pandas as pd
pd.options.display.max_colwidth=500
from altrea.wffs import And, Wff, Not
from altrea.rules import Proof

prf = Proof()
A = prf.proposition("A")
prf.setlogic()

prf.goal(And(A, A))
prf.premise(A)

prf.opensubproof()
prf.hypothesis(Not(A))
prf.closesubproof()
prf.implication_intro()
prf.rule("neg elim", [A], [2, 1])

display(prf.thisproof())
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th style="text-align:center"></th>
#       <th style="text-align:center">Item</th>
#       <th style="text-align:center">Level</th>
#       <th style="text-align:center">Proof</th>
#       <th style="text-align:center">Rule</th>
#       <th style="text-align:center">Type</th>
#       <th style="text-align:center">Lines</th>
#       <th style="text-align:center">Proofs</th>
#       <th style="text-align:center">Comment</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th style="text-align:center"></th>
#       <td style="text-align:left">$\color{blue}A \wedge A$</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">GOAL</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#     </tr>
#     <tr>
#       <th style="text-align:center">1</th>
#       <td style="text-align:left">$A$</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">Premise</td>
#       <td style="text-align:left">PREM</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#     </tr>
#     <tr>
#       <th style="text-align:center">2</th>
#       <td style="text-align:left">$|\hspace{0.35cm} $$\lnot~A$</td>
#       <td style="text-align:left">1</td>
#       <td style="text-align:left">1</td>
#       <td style="text-align:left">Hypothesis</td>
#       <td style="text-align:left">HYPO</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#     </tr>
#     <tr>
#       <th style="text-align:center">3</th>
#       <td style="text-align:left">$\lnot~A \supset  \lnot~A$</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">Implication Intro</td>
#       <td style="text-align:left">TR</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left">2-2</td>
#       <td style="text-align:left"></td>
#     </tr>
#     <tr>
#       <th style="text-align:center">4</th>
#       <td style="text-align:left"></td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">Negation Elim</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left">2</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left">STOPPED: Referenced item is out of scope.</td>
#     </tr>
#   </tbody>
# </table>

# %%
# test_negation_elim_linescope_2: The two lines are not negations of one another.

from IPython.display import display, Math, Markdown, Latex, display_markdown, HTML
import pandas as pd
pd.options.display.max_colwidth=500
from altrea.wffs import And, Wff, Not
from altrea.rules import Proof

prf = Proof()
A = prf.proposition("A")
prf.setlogic()

prf.goal(And(A, A))
prf.premise(A)

prf.opensubproof()
prf.hypothesis(Not(A))
prf.closesubproof()
prf.implication_intro()
prf.rule("neg elim", [A], [1, 2])

display(prf.thisproof())
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th style="text-align:center"></th>
#       <th style="text-align:center">Item</th>
#       <th style="text-align:center">Level</th>
#       <th style="text-align:center">Proof</th>
#       <th style="text-align:center">Rule</th>
#       <th style="text-align:center">Type</th>
#       <th style="text-align:center">Lines</th>
#       <th style="text-align:center">Proofs</th>
#       <th style="text-align:center">Comment</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th style="text-align:center"></th>
#       <td style="text-align:left">$\color{blue}A \wedge A$</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">GOAL</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#     </tr>
#     <tr>
#       <th style="text-align:center">1</th>
#       <td style="text-align:left">$A$</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">Premise</td>
#       <td style="text-align:left">PREM</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#     </tr>
#     <tr>
#       <th style="text-align:center">2</th>
#       <td style="text-align:left">$|\hspace{0.35cm} $$\lnot~A$</td>
#       <td style="text-align:left">1</td>
#       <td style="text-align:left">1</td>
#       <td style="text-align:left">Hypothesis</td>
#       <td style="text-align:left">HYPO</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#     </tr>
#     <tr>
#       <th style="text-align:center">3</th>
#       <td style="text-align:left">$\lnot~A \supset  \lnot~A$</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">Implication Intro</td>
#       <td style="text-align:left">TR</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left">2-2</td>
#       <td style="text-align:left"></td>
#     </tr>
#     <tr>
#       <th style="text-align:center">4</th>
#       <td style="text-align:left"></td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">Negation Elim</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left">2</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left">STOPPED: Referenced item is out of scope.</td>
#     </tr>
#   </tbody>
# </table>

# %%
# test_negation_elim_premisesdontmatch_1

from IPython.display import display, Math, Markdown, Latex, display_markdown, HTML
import pandas as pd
pd.options.display.max_colwidth=500
from altrea.wffs import And, Wff, Not
from altrea.rules import Proof

prf = Proof()
A = prf.proposition("A")
prf.setlogic()
prf.goal(And(A, A))
prf.premise(A)
prf.premise(A)
prf.rule("neg elim", [A], [1, 2])

display(prf.thisproof())
# Out:
#                        Item  Level  Proof           Rule  Type Lines Proofs  \
#    $\color{blue}A \wedge A$      0      0           GOAL
# 1                       $A$      0      0        Premise  PREM
# 2                       $A$      0      0        Premise  PREM
# 3                                0      0  Negation Elim
#
#                                                                    Comment
#
# 1
# 2
# 3  STOPPED: A required premise does not match a line in the current proof.

# %% [markdown]
# <a id='negation_intro'></a>
# ## Negation Introduction

# %%
# test_negation_intro_clean_1: Clean run: modus tollens

from IPython.display import display, Math, Markdown, Latex, display_markdown, HTML
import pandas as pd
pd.options.display.max_colwidth=500
from altrea.wffs import And, Wff, Not
from altrea.rules import Proof

prf = Proof()
A = prf.proposition("A")
prf.setlogic()

prf.goal(Not(Not(A)))
prf.premise(A)

prf.opensubproof()
prf.hypothesis(Not(A))
prf.reiterate(1)
prf.rule("neg elim", [A], [3, 2])
prf.closesubproof()
prf.implication_intro()
prf.rule("neg intro", [Not(A), A], [5])

display(prf.thisproof())
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th style="text-align:center"></th>
#       <th style="text-align:center">Item</th>
#       <th style="text-align:center">Level</th>
#       <th style="text-align:center">Proof</th>
#       <th style="text-align:center">Rule</th>
#       <th style="text-align:center">Type</th>
#       <th style="text-align:center">Lines</th>
#       <th style="text-align:center">Proofs</th>
#       <th style="text-align:center">Comment</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th style="text-align:center"></th>
#       <td style="text-align:left">$\color{blue}\lnot~\lnot~A$</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">GOAL</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#     </tr>
#     <tr>
#       <th style="text-align:center">1</th>
#       <td style="text-align:left">$A$</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">Premise</td>
#       <td style="text-align:left">PREM</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#     </tr>
#     <tr>
#       <th style="text-align:center">2</th>
#       <td style="text-align:left">$|\hspace{0.35cm} $$\lnot~A$</td>
#       <td style="text-align:left">1</td>
#       <td style="text-align:left">1</td>
#       <td style="text-align:left">Hypothesis</td>
#       <td style="text-align:left">HYPO</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#     </tr>
#     <tr>
#       <th style="text-align:center">3</th>
#       <td style="text-align:left">$|\hspace{0.35cm} $$A$</td>
#       <td style="text-align:left">1</td>
#       <td style="text-align:left">1</td>
#       <td style="text-align:left">Reiteration</td>
#       <td style="text-align:left">REIT</td>
#       <td style="text-align:left">1</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#     </tr>
#     <tr>
#       <th style="text-align:center">4</th>
#       <td style="text-align:left">$|\hspace{0.35cm} $$\bot~$</td>
#       <td style="text-align:left">1</td>
#       <td style="text-align:left">1</td>
#       <td style="text-align:left">Negation Elim</td>
#       <td style="text-align:left">RULE</td>
#       <td style="text-align:left">3, 2</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#     </tr>
#     <tr>
#       <th style="text-align:center">5</th>
#       <td style="text-align:left">$\lnot~A \supset  \bot~$</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">Implication Intro</td>
#       <td style="text-align:left">TR</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left">2-4</td>
#       <td style="text-align:left"></td>
#     </tr>
#     <tr>
#       <th style="text-align:center">6</th>
#       <td style="text-align:left">$\color{blue}\lnot~\lnot~A$</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">Negation Intro</td>
#       <td style="text-align:left">RULE</td>
#       <td style="text-align:left">5</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left">COMPLETE</td>
#     </tr>
#   </tbody>
# </table>

# %%
# test_negation_intro_clean_2: Clean run: multiple hypotheses are negated

from IPython.display import display, Math, Markdown, Latex, display_markdown, HTML
import pandas as pd
pd.options.display.max_colwidth=500
from altrea.wffs import And, Wff, Not, Falsehood
from altrea.rules import Proof

prf = Proof()
A = prf.proposition("A")
prf.setlogic()

prf.goal(Not(And(A, Not(A))))

prf.opensubproof()
prf.hypothesis(A)
prf.hypothesis(Not(A))
prf.rule("neg elim", [A], [1, 2])
prf.closesubproof()
prf.implication_intro()
prf.rule("neg intro", [prf.item(4).left, A], [4])

display(prf.thisproof())
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th style="text-align:center"></th>
#       <th style="text-align:center">Item</th>
#       <th style="text-align:center">Level</th>
#       <th style="text-align:center">Proof</th>
#       <th style="text-align:center">Rule</th>
#       <th style="text-align:center">Type</th>
#       <th style="text-align:center">Lines</th>
#       <th style="text-align:center">Proofs</th>
#       <th style="text-align:center">Comment</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th style="text-align:center"></th>
#       <td style="text-align:left">$\color{blue}\lnot~(A \wedge \lnot~A)$</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">GOAL</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#     </tr>
#     <tr>
#       <th style="text-align:center">1</th>
#       <td style="text-align:left">$|\hspace{0.35cm} $$\color{red}A$</td>
#       <td style="text-align:left">1</td>
#       <td style="text-align:left">1</td>
#       <td style="text-align:left">Hypothesis</td>
#       <td style="text-align:left">HYPO</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#     </tr>
#     <tr>
#       <th style="text-align:center">2</th>
#       <td style="text-align:left">$|\hspace{0.35cm} $$\color{red}\lnot~A$</td>
#       <td style="text-align:left">1</td>
#       <td style="text-align:left">1</td>
#       <td style="text-align:left">Hypothesis</td>
#       <td style="text-align:left">HYPO</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#     </tr>
#     <tr>
#       <th style="text-align:center">3</th>
#       <td style="text-align:left">$|\hspace{0.35cm} $$\color{red}\bot~$</td>
#       <td style="text-align:left">1</td>
#       <td style="text-align:left">1</td>
#       <td style="text-align:left">Negation Elim</td>
#       <td style="text-align:left">RULE</td>
#       <td style="text-align:left">1, 2</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#     </tr>
#     <tr>
#       <th style="text-align:center">4</th>
#       <td style="text-align:left">$\color{green}A \supset  \bot~$</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">Implication Intro</td>
#       <td style="text-align:left">TR</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left">1-3</td>
#       <td style="text-align:left"></td>
#     </tr>
#     <tr>
#       <th style="text-align:center">5</th>
#       <td style="text-align:left">$\color{green}\lnot~A$</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">Negation Intro</td>
#       <td style="text-align:left">RULE</td>
#       <td style="text-align:left">4</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#     </tr>
#   </tbody>
# </table>

# %%
print(Falsehood().latex())
# Out:
# \bot~

# %%
# test_implication_intro_notfalse_1: Cannot close a subproof without a false item.

from IPython.display import display, Math, Markdown, Latex, display_markdown, HTML
import pandas as pd
pd.options.display.max_colwidth=500
from altrea.wffs import And, Wff
from altrea.rules import Proof

prf = Proof()
A = prf.proposition("A")
prf.setlogic()

prf.goal(Not(Not(A)))

prf.opensubproof()
prf.hypothesis(A)
prf.closesubproof()
prf.implication_intro()
prf.rule("neg intro", [A, A], [2])

display(prf.thisproof())
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th style="text-align:center"></th>
#       <th style="text-align:center">Item</th>
#       <th style="text-align:center">Level</th>
#       <th style="text-align:center">Proof</th>
#       <th style="text-align:center">Rule</th>
#       <th style="text-align:center">Type</th>
#       <th style="text-align:center">Lines</th>
#       <th style="text-align:center">Proofs</th>
#       <th style="text-align:center">Comment</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th style="text-align:center"></th>
#       <td style="text-align:left">$\color{blue}\lnot~\lnot~A$</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">GOAL</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#     </tr>
#     <tr>
#       <th style="text-align:center">1</th>
#       <td style="text-align:left">$|\hspace{0.35cm} $$A$</td>
#       <td style="text-align:left">1</td>
#       <td style="text-align:left">1</td>
#       <td style="text-align:left">Hypothesis</td>
#       <td style="text-align:left">HYPO</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#     </tr>
#     <tr>
#       <th style="text-align:center">2</th>
#       <td style="text-align:left">$A \supset  A$</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">Implication Intro</td>
#       <td style="text-align:left">TR</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left">1-1</td>
#       <td style="text-align:left"></td>
#     </tr>
#     <tr>
#       <th style="text-align:center">3</th>
#       <td style="text-align:left"></td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">Negation Intro</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left">STOPPED: A required premise does not match a line in the current proof.</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# <a id='openclosestrictsubproof'></a>
# ## Open/Close Strict Subproof

# %%
# test_openclosestrictsubproof_clean_1: Clean run

from IPython.display import display, Math, Markdown, Latex, display_markdown, HTML
import pandas as pd
pd.options.display.max_colwidth=500
from altrea.wffs import And, Wff, Necessary
from altrea.rules import Proof

prf = Proof()
prf.setrestricted(True)
A = prf.proposition("A")
B = prf.proposition("B")
prf.setlogic()

prf.goal(B)
prf.premise(Necessary(A))

prf.openstrictsubproof()
prf.reiterate(1)
prf.closestrictsubproof()

prf.displaylog()
display(prf.thisproof())
# Out:
#  1 RESTRICTED: The restricted use of explosion has been set to True.
#  1 PROPOSITION: The letter "A" for a generic well-formed formula has been defined with 1 so far for this proof.
#  1 PROPOSITION: The letter "B" for a generic well-formed formula has been defined with 2 so far for this proof.
#  1 SET LOGIC: "" has been selected as the logic described as "No Description" and stored in database "No Database".
#  1 RESTRICTED: The restricted use of explosion has been set to True.
#  1 GOAL: The goal "B" has been added to the goals.
#  1 PREMISE: Item "☐A" has been added to the premises.
#  2 OPEN STRICT SUBPROOF: A strict subproof "1" has been started with either line 0, additional hypothesis "None" or hypothesis "None".
#  2 REITERATION: Item "☐A" on line 1 has been reiterated into subproof 1.
#  3 CLOSE STRICT SUBPROOF: The current "STRICT" subproof 1 has been closed.
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th style="text-align:center"></th>
#       <th style="text-align:center">Item</th>
#       <th style="text-align:center">Level</th>
#       <th style="text-align:center">Proof</th>
#       <th style="text-align:center">Rule</th>
#       <th style="text-align:center">Type</th>
#       <th style="text-align:center">Lines</th>
#       <th style="text-align:center">Proofs</th>
#       <th style="text-align:center">Comment</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th style="text-align:center"></th>
#       <td style="text-align:left">$\color{blue}B$</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">GOAL</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#     </tr>
#     <tr>
#       <th style="text-align:center">1</th>
#       <td style="text-align:left">$\color{green}\Box~ A$</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">Premise</td>
#       <td style="text-align:left">PREM</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#     </tr>
#     <tr>
#       <th style="text-align:center">2</th>
#       <td style="text-align:left">$\Vert\hspace{0.35cm} $$\color{red}\Box~ A$</td>
#       <td style="text-align:left">1</td>
#       <td style="text-align:left">1</td>
#       <td style="text-align:left">Reiteration</td>
#       <td style="text-align:left">REIT</td>
#       <td style="text-align:left">1</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#     </tr>
#   </tbody>
# </table>

# %%
# test_openclosestrictsubproof_clean_2: Implication result

from IPython.display import display, Math, Markdown, Latex, display_markdown, HTML
import pandas as pd
pd.options.display.max_colwidth=500
from altrea.wffs import And, Wff, Necessary
from altrea.rules import Proof

prf = Proof()
prf.setrestricted(True)
A = prf.proposition("A")
B = prf.proposition("B")
C = prf.proposition("C")
prf.setlogic()

prf.goal(B)
prf.premise(Necessary(A))

prf.openstrictsubproof()
prf.hypothesis(C)
prf.closestrictsubproof()
prf.implication_intro()

display(prf.thisproof())
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th style="text-align:center"></th>
#       <th style="text-align:center">Item</th>
#       <th style="text-align:center">Level</th>
#       <th style="text-align:center">Proof</th>
#       <th style="text-align:center">Rule</th>
#       <th style="text-align:center">Type</th>
#       <th style="text-align:center">Lines</th>
#       <th style="text-align:center">Proofs</th>
#       <th style="text-align:center">Comment</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th style="text-align:center"></th>
#       <td style="text-align:left">$\color{blue}B$</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">GOAL</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#     </tr>
#     <tr>
#       <th style="text-align:center">1</th>
#       <td style="text-align:left">$\color{green}\Box~ A$</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">Premise</td>
#       <td style="text-align:left">PREM</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#     </tr>
#     <tr>
#       <th style="text-align:center">2</th>
#       <td style="text-align:left">$\Vert\hspace{0.35cm} $$\color{red}C$</td>
#       <td style="text-align:left">1</td>
#       <td style="text-align:left">1</td>
#       <td style="text-align:left">Hypothesis</td>
#       <td style="text-align:left">HYPO</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#     </tr>
#     <tr>
#       <th style="text-align:center">3</th>
#       <td style="text-align:left">$\color{green}C \supset  C$</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">Implication Intro</td>
#       <td style="text-align:left">TR</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left">2-2</td>
#       <td style="text-align:left"></td>
#     </tr>
#   </tbody>
# </table>

# %%
# test_openclosestrictsubproof_clean_3: Necessary result

from IPython.display import display, Math, Markdown, Latex, display_markdown, HTML
import pandas as pd
pd.options.display.max_colwidth=500
from altrea.wffs import And, Wff, Necessary
from altrea.rules import Proof

prf = Proof()
prf.setrestricted(True)
A = prf.proposition("A")
B = prf.proposition("B")
prf.setlogic()

prf.goal(B)
prf.premise(Necessary(A))

prf.openstrictsubproof()
prf.hypothesis(B)
prf.closestrictsubproof()
prf.implication_intro()

display(prf.thisproof())
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[5], line 21
#      19 prf.hypothesis(B)
#      20 prf.closestrictsubproof()
# ---> 21 prf.implication_intro()
#      23 display(prf.thisproof())
#
# File E:\Jupyter\AltRea\altrea\rules.py:4383, in Proof.implication_intro(self, comment)
#    4361         # if self.currentproofid == 0:
#    4362         #     self.logstep(
#    4363         #         self.log_closemainproof.format(
#    (...)
#    4374
#    4375 # If no errors, perform task
#    4376 if self.canproceed():
#    4377 #     proofid = self.currentproofid
#    4378 #     subproof_status = self.subproof_status
#    4379 #     self.prooflist[self.currentproofid][1].append(len(self.lines) - 1)
#    4380 #     self.level -= 1
#    4381 #     self.subproofchain = self.subproofchain[:-3]
#    4382     antecedent, consequent, previousproofid, previoussubproofstatus = (
# -> 4383         self.getproof(self.closedproofid)
#    4384     )
#    4385     proofid = self.closedproofid
#    4386     self.closedproofid = 0
#
# File E:\Jupyter\AltRea\altrea\rules.py:1177, in Proof.getproof(self, proofid)
#    1171 def getproof(self, proofid: int) -> tuple:
#    1172     """Returns one or more hypothesis statements conjoined together, the conclusion statement
#    1173     and the parent proof id.  It is used by functions such as implication_intro and
#    1174     negation_intro to close a subordinate proof.
#    1175     """
# -> 1177     hypothesis = self.lines[self.prooflist[proofid][3][0]][self.statementindex]
#    1178     if len(self.prooflist[proofid][3]) > 1:
#    1179         for i in range(len(self.prooflist[proofid][3])):
#
# IndexError: list index out of range

# %%
# test_openclosestrictsubproof_clean_4: All three

from IPython.display import display, Math, Markdown, Latex, display_markdown, HTML
import pandas as pd
pd.options.display.max_colwidth=500
from altrea.wffs import And, Wff, Necessary
from altrea.rules import Proof

prf = Proof()
prf.setrestricted(True)
A = prf.proposition("A")
B = prf.proposition("B")
prf.setlogic()

prf.goal(B)
prf.premise(Necessary(A))

prf.openstrictsubproof()
prf.reiterate(1)
prf.openstrictsubproof()
prf.hypothesis(B)
prf.openstrictsubproof()
prf.opensubproof()
prf.hypothesis(B)
prf.closesubproof()
prf.implication_intro()
prf.closestrictsubproof()
prf.necessary_intro()

display(prf.thisproof())
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th style="text-align:center"></th>
#       <th style="text-align:center">Item</th>
#       <th style="text-align:center">Level</th>
#       <th style="text-align:center">Proof</th>
#       <th style="text-align:center">Rule</th>
#       <th style="text-align:center">Type</th>
#       <th style="text-align:center">Lines</th>
#       <th style="text-align:center">Proofs</th>
#       <th style="text-align:center">Comment</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th style="text-align:center"></th>
#       <td style="text-align:left">$\color{blue}B$</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">GOAL</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#     </tr>
#     <tr>
#       <th style="text-align:center">1</th>
#       <td style="text-align:left">$\color{green}\Box~ A$</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">Premise</td>
#       <td style="text-align:left">PREM</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#     </tr>
#     <tr>
#       <th style="text-align:center">2</th>
#       <td style="text-align:left">$\Vert\hspace{0.35cm} $$\color{green}\Box~ A$</td>
#       <td style="text-align:left">1</td>
#       <td style="text-align:left">1</td>
#       <td style="text-align:left">Reiteration</td>
#       <td style="text-align:left">REIT</td>
#       <td style="text-align:left">1</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#     </tr>
#     <tr>
#       <th style="text-align:center">3</th>
#       <td style="text-align:left">$\Vert\hspace{0.35cm} $$\Vert\hspace{0.35cm} $$\color{green}B$</td>
#       <td style="text-align:left">2</td>
#       <td style="text-align:left">2</td>
#       <td style="text-align:left">Hypothesis</td>
#       <td style="text-align:left">HYPO</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#     </tr>
#     <tr>
#       <th style="text-align:center">4</th>
#       <td style="text-align:left">$\Vert\hspace{0.35cm} $$\Vert\hspace{0.35cm} $$\Vert\hspace{0.35cm} $$|\hspace{0.35cm} $$\color{red}B$</td>
#       <td style="text-align:left">4</td>
#       <td style="text-align:left">4</td>
#       <td style="text-align:left">Hypothesis</td>
#       <td style="text-align:left">HYPO</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#     </tr>
#     <tr>
#       <th style="text-align:center">5</th>
#       <td style="text-align:left">$\Vert\hspace{0.35cm} $$\Vert\hspace{0.35cm} $$\Vert\hspace{0.35cm} $$\color{red}B \supset  B$</td>
#       <td style="text-align:left">3</td>
#       <td style="text-align:left">3</td>
#       <td style="text-align:left">Implication Intro</td>
#       <td style="text-align:left">TR</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left">4-4</td>
#       <td style="text-align:left"></td>
#     </tr>
#     <tr>
#       <th style="text-align:center">6</th>
#       <td style="text-align:left">$\Vert\hspace{0.35cm} $$\Vert\hspace{0.35cm} $$\color{green}\Box~ (B \supset  B)$</td>
#       <td style="text-align:left">2</td>
#       <td style="text-align:left">2</td>
#       <td style="text-align:left">Necessary Intro</td>
#       <td style="text-align:left">TR</td>
#       <td style="text-align:left">5</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#     </tr>
#   </tbody>
# </table>

# %%
# test_openclosestrictsubproof_closewrongsubproof_1

from IPython.display import display, Math, Markdown, Latex, display_markdown, HTML
import pandas as pd
pd.options.display.max_colwidth=500
from altrea.wffs import *
from altrea.rules import Proof

prf = Proof()
prf.setrestricted(True)
A = prf.proposition("A")
B = prf.proposition("B")
prf.setlogic()

prf.goal(B)
prf.premise(Necessary(A))

prf.opensubproof()
prf.hypothesis(B)
prf.closestrictsubproof()
prf.necessary_intro()

display(prf.thisproof())
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th style="text-align:center"></th>
#       <th style="text-align:center">Item</th>
#       <th style="text-align:center">Level</th>
#       <th style="text-align:center">Proof</th>
#       <th style="text-align:center">Rule</th>
#       <th style="text-align:center">Type</th>
#       <th style="text-align:center">Lines</th>
#       <th style="text-align:center">Proofs</th>
#       <th style="text-align:center">Comment</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th style="text-align:center"></th>
#       <td style="text-align:left">$\color{blue}B$</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">GOAL</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#     </tr>
#     <tr>
#       <th style="text-align:center">1</th>
#       <td style="text-align:left">$\Box~ A$</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">Premise</td>
#       <td style="text-align:left">PREM</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#     </tr>
#     <tr>
#       <th style="text-align:center">2</th>
#       <td style="text-align:left">$|\hspace{0.35cm} $$B$</td>
#       <td style="text-align:left">1</td>
#       <td style="text-align:left">1</td>
#       <td style="text-align:left">Hypothesis</td>
#       <td style="text-align:left">HYPO</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#     </tr>
#     <tr>
#       <th style="text-align:center">3</th>
#       <td style="text-align:left"></td>
#       <td style="text-align:left">1</td>
#       <td style="text-align:left">1</td>
#       <td style="text-align:left">Close Subproof</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left">STOPPED: Attempting to close a subproof that is not open.</td>
#     </tr>
#   </tbody>
# </table>

# %%
# test_openclosestrictsubproof_unavailablesubproof_1

from IPython.display import display, Math, Markdown, Latex, display_markdown, HTML
import pandas as pd
pd.options.display.max_colwidth=500
from altrea.wffs import And, Wff, Necessary
from altrea.rules import Proof

prf = Proof()
prf.setrestricted(True)
A = prf.proposition("A")
B = prf.proposition("B")
prf.setlogic()

prf.goal(B)
prf.premise(Necessary(A))

prf.openstrictsubproof()
prf.necessary_intro()

display(prf.thisproof())
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th style="text-align:center"></th>
#       <th style="text-align:center">Item</th>
#       <th style="text-align:center">Level</th>
#       <th style="text-align:center">Proof</th>
#       <th style="text-align:center">Rule</th>
#       <th style="text-align:center">Type</th>
#       <th style="text-align:center">Lines</th>
#       <th style="text-align:center">Proofs</th>
#       <th style="text-align:center">Comment</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th style="text-align:center"></th>
#       <td style="text-align:left">$\color{blue}B$</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">GOAL</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#     </tr>
#     <tr>
#       <th style="text-align:center">1</th>
#       <td style="text-align:left">$\Box~ A$</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">Premise</td>
#       <td style="text-align:left">PREM</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#     </tr>
#     <tr>
#       <th style="text-align:center">2</th>
#       <td style="text-align:left"></td>
#       <td style="text-align:left">1</td>
#       <td style="text-align:left">1</td>
#       <td style="text-align:left">Necessary Intro</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left">STOPPED: The subproof is not available.</td>
#     </tr>
#   </tbody>
# </table>

# %%
# test_openclosestrictsubproof_unavailablesubproof_2

from IPython.display import display, Math, Markdown, Latex, display_markdown, HTML
import pandas as pd
pd.options.display.max_colwidth=500
from altrea.wffs import And, Wff, Necessary
from altrea.rules import Proof

prf = Proof()
prf.setrestricted(True)
A = prf.proposition("A")
B = prf.proposition("B")
prf.setlogic()

prf.goal(B)
prf.premise(Necessary(A))

prf.openstrictsubproof()
prf.possibly_elim()

display(prf.thisproof())
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th style="text-align:center"></th>
#       <th style="text-align:center">Item</th>
#       <th style="text-align:center">Level</th>
#       <th style="text-align:center">Proof</th>
#       <th style="text-align:center">Rule</th>
#       <th style="text-align:center">Type</th>
#       <th style="text-align:center">Lines</th>
#       <th style="text-align:center">Proofs</th>
#       <th style="text-align:center">Comment</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th style="text-align:center"></th>
#       <td style="text-align:left">$\color{blue}B$</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">GOAL</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#     </tr>
#     <tr>
#       <th style="text-align:center">1</th>
#       <td style="text-align:left">$\Box~ A$</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">Premise</td>
#       <td style="text-align:left">PREM</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#     </tr>
#     <tr>
#       <th style="text-align:center">2</th>
#       <td style="text-align:left"></td>
#       <td style="text-align:left">1</td>
#       <td style="text-align:left">1</td>
#       <td style="text-align:left">Possibly Elim</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left">STOPPED: The subproof is not available.</td>
#     </tr>
#   </tbody>
# </table>

# %%
# test_openclosestrictsubproof_unavailablesubproof_3

from IPython.display import display, Math, Markdown, Latex, display_markdown, HTML
import pandas as pd
pd.options.display.max_colwidth=500
from altrea.wffs import *
from altrea.rules import Proof

prf = Proof()
prf.setrestricted(True)
A = prf.proposition("A")
B = prf.proposition("B")
prf.setlogic()

prf.goal(B)
prf.premise(Necessary(A))

prf.openstrictsubproof()
prf.premise(And(A, B))

display(prf.thisproof())
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th style="text-align:center"></th>
#       <th style="text-align:center">Item</th>
#       <th style="text-align:center">Level</th>
#       <th style="text-align:center">Proof</th>
#       <th style="text-align:center">Rule</th>
#       <th style="text-align:center">Type</th>
#       <th style="text-align:center">Lines</th>
#       <th style="text-align:center">Proofs</th>
#       <th style="text-align:center">Comment</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th style="text-align:center"></th>
#       <td style="text-align:left">$\color{blue}B$</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">GOAL</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#     </tr>
#     <tr>
#       <th style="text-align:center">1</th>
#       <td style="text-align:left">$\Box~ A$</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">Premise</td>
#       <td style="text-align:left">PREM</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#     </tr>
#     <tr>
#       <th style="text-align:center">2</th>
#       <td style="text-align:left"></td>
#       <td style="text-align:left">1</td>
#       <td style="text-align:left">1</td>
#       <td style="text-align:left">Premise</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left">STOPPED: The subproof is not available.</td>
#     </tr>
#   </tbody>
# </table>

# %%
# test_openclosestrictsubproof_unavailablesubproof_4

from IPython.display import display, Math, Markdown, Latex, display_markdown, HTML
import pandas as pd
pd.options.display.max_colwidth=500
from altrea.wffs import *
from altrea.rules import Proof

prf = Proof()
prf.setrestricted(False)
A = prf.proposition("A")
B = prf.proposition("B")
prf.setlogic()

prf.goal(B)
prf.premise(Necessary(A))

prf.openstrictsubproof()
prf.axiom("lem", [A], [])

display(prf.thisproof())
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th style="text-align:center"></th>
#       <th style="text-align:center">Item</th>
#       <th style="text-align:center">Level</th>
#       <th style="text-align:center">Proof</th>
#       <th style="text-align:center">Rule</th>
#       <th style="text-align:center">Type</th>
#       <th style="text-align:center">Lines</th>
#       <th style="text-align:center">Proofs</th>
#       <th style="text-align:center">Comment</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th style="text-align:center"></th>
#       <td style="text-align:left">$\color{blue}B$</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">GOAL</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#     </tr>
#     <tr>
#       <th style="text-align:center">1</th>
#       <td style="text-align:left">$\Box~ A$</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">Premise</td>
#       <td style="text-align:left">PREM</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#     </tr>
#     <tr>
#       <th style="text-align:center">2</th>
#       <td style="text-align:left"></td>
#       <td style="text-align:left">1</td>
#       <td style="text-align:left">1</td>
#       <td style="text-align:left">Axiom</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left">STOPPED: The subproof is not available.</td>
#     </tr>
#   </tbody>
# </table>

# %%
# test_openclosestrictsubproof_unavailablesubproof_5

from IPython.display import display, Math, Markdown, Latex, display_markdown, HTML
import pandas as pd
pd.options.display.max_colwidth=500
from altrea.wffs import *
from altrea.rules import Proof

prf = Proof()
prf.setrestricted(False)
A = prf.proposition("A")
B = prf.proposition("B")
prf.setlogic()

prf.goal(B)
prf.premise(Necessary(A))

prf.openstrictsubproof()
prf.definition("iff intro", [A, B], [])

display(prf.thisproof())
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th style="text-align:center"></th>
#       <th style="text-align:center">Item</th>
#       <th style="text-align:center">Level</th>
#       <th style="text-align:center">Proof</th>
#       <th style="text-align:center">Rule</th>
#       <th style="text-align:center">Type</th>
#       <th style="text-align:center">Lines</th>
#       <th style="text-align:center">Proofs</th>
#       <th style="text-align:center">Comment</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th style="text-align:center"></th>
#       <td style="text-align:left">$\color{blue}B$</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">GOAL</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#     </tr>
#     <tr>
#       <th style="text-align:center">1</th>
#       <td style="text-align:left">$\Box~ A$</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">Premise</td>
#       <td style="text-align:left">PREM</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#     </tr>
#     <tr>
#       <th style="text-align:center">2</th>
#       <td style="text-align:left"></td>
#       <td style="text-align:left">1</td>
#       <td style="text-align:left">1</td>
#       <td style="text-align:left">Iff Intro</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left">STOPPED: The number of premises do not match the pattern.</td>
#     </tr>
#     <tr>
#       <th style="text-align:center">3</th>
#       <td style="text-align:left"></td>
#       <td style="text-align:left">1</td>
#       <td style="text-align:left">1</td>
#       <td style="text-align:left">Definition</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left">STOPPED: The subproof is not available.</td>
#     </tr>
#   </tbody>
# </table>

# %%
display(prf.definitions())
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th style="text-align:center"></th>
#       <th style="text-align:center">Definitions</th>
#       <th style="text-align:center">Description</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th style="text-align:center">iff intro</th>
#       <td style="text-align:left">$\{(\alpha \supset  \beta) \wedge (\beta \supset  \alpha)\} ~\vdash~ \alpha \equiv  \beta$</td>
#       <td style="text-align:left">Coimplication Introduction</td>
#     </tr>
#     <tr>
#       <th style="text-align:center">iff elim</th>
#       <td style="text-align:left">$\{\alpha \equiv  \beta\} ~\vdash~ (\alpha \supset  \beta) \wedge (\beta \supset  \alpha)$</td>
#       <td style="text-align:left">Coimplication Elimination</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# <a id='openclosesubproof'></a>
# ## Open/Close Subproof

# %%
# test_openclosesubproof_clean_1

from IPython.display import display, Math, Markdown, Latex, display_markdown, HTML
import pandas as pd
pd.options.display.max_colwidth=500
from altrea.wffs import And, Wff, Necessary
from altrea.rules import Proof

prf = Proof()
prf.setrestricted(True)
A = prf.proposition("A")
B = prf.proposition("B")
prf.setlogic()

prf.goal(B)

prf.opensubproof()
prf.hypothesis(A)
prf.closesubproof()
prf.implication_intro()

display(prf.thisproof())
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th style="text-align:center"></th>
#       <th style="text-align:center">Item</th>
#       <th style="text-align:center">Level</th>
#       <th style="text-align:center">Proof</th>
#       <th style="text-align:center">Rule</th>
#       <th style="text-align:center">Type</th>
#       <th style="text-align:center">Lines</th>
#       <th style="text-align:center">Proofs</th>
#       <th style="text-align:center">Comment</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th style="text-align:center"></th>
#       <td style="text-align:left">$\color{blue}B$</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">GOAL</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#     </tr>
#     <tr>
#       <th style="text-align:center">1</th>
#       <td style="text-align:left">$|\hspace{0.35cm} $$\color{red}A$</td>
#       <td style="text-align:left">1</td>
#       <td style="text-align:left">1</td>
#       <td style="text-align:left">Hypothesis</td>
#       <td style="text-align:left">HYPO</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#     </tr>
#     <tr>
#       <th style="text-align:center">2</th>
#       <td style="text-align:left">$\color{green}A \supset  A$</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">Implication Intro</td>
#       <td style="text-align:left">TR</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left">1-1</td>
#       <td style="text-align:left"></td>
#     </tr>
#   </tbody>
# </table>

# %%
# test_openclosesubproof_clean_2

from IPython.display import display, Math, Markdown, Latex, display_markdown, HTML
import pandas as pd
pd.options.display.max_colwidth=500
from altrea.wffs import And, Wff, Necessary
from altrea.rules import Proof

prf = Proof()
prf.setrestricted(True)
A = prf.proposition("A")
B = prf.proposition("B")
prf.setlogic()

prf.goal(B)

prf.opensubproof()
prf.hypothesis(A)
prf.opensubproof()
prf.hypothesis(B)
prf.closesubproof()
prf.implication_intro()
prf.closesubproof()
prf.implication_intro()

display(prf.thisproof())
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th style="text-align:center"></th>
#       <th style="text-align:center">Item</th>
#       <th style="text-align:center">Level</th>
#       <th style="text-align:center">Proof</th>
#       <th style="text-align:center">Rule</th>
#       <th style="text-align:center">Type</th>
#       <th style="text-align:center">Lines</th>
#       <th style="text-align:center">Proofs</th>
#       <th style="text-align:center">Comment</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th style="text-align:center"></th>
#       <td style="text-align:left">$\color{blue}B$</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">GOAL</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#     </tr>
#     <tr>
#       <th style="text-align:center">1</th>
#       <td style="text-align:left">$|\hspace{0.35cm} $$\color{red}A$</td>
#       <td style="text-align:left">1</td>
#       <td style="text-align:left">1</td>
#       <td style="text-align:left">Hypothesis</td>
#       <td style="text-align:left">HYPO</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#     </tr>
#     <tr>
#       <th style="text-align:center">2</th>
#       <td style="text-align:left">$|\hspace{0.35cm} $$|\hspace{0.35cm} $$\color{red}B$</td>
#       <td style="text-align:left">2</td>
#       <td style="text-align:left">2</td>
#       <td style="text-align:left">Hypothesis</td>
#       <td style="text-align:left">HYPO</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#     </tr>
#     <tr>
#       <th style="text-align:center">3</th>
#       <td style="text-align:left">$|\hspace{0.35cm} $$\color{red}B \supset  B$</td>
#       <td style="text-align:left">1</td>
#       <td style="text-align:left">1</td>
#       <td style="text-align:left">Implication Intro</td>
#       <td style="text-align:left">TR</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left">2-2</td>
#       <td style="text-align:left"></td>
#     </tr>
#     <tr>
#       <th style="text-align:center">4</th>
#       <td style="text-align:left">$\color{green}A \supset  (B \supset  B)$</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">Implication Intro</td>
#       <td style="text-align:left">TR</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left">1-3</td>
#       <td style="text-align:left"></td>
#     </tr>
#   </tbody>
# </table>

# %%
# test_openclosesubproof_unavailablesubproof_1

from IPython.display import display, Math, Markdown, Latex, display_markdown, HTML
import pandas as pd
pd.options.display.max_colwidth=500
from altrea.wffs import And, Wff, Necessary
from altrea.rules import Proof

prf = Proof()
prf.setrestricted(True)
A = prf.proposition("A")
B = prf.proposition("B")
prf.setlogic()

prf.goal(B)

prf.opensubproof()
prf.premise(A)


display(prf.thisproof())
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th style="text-align:center"></th>
#       <th style="text-align:center">Item</th>
#       <th style="text-align:center">Level</th>
#       <th style="text-align:center">Proof</th>
#       <th style="text-align:center">Rule</th>
#       <th style="text-align:center">Type</th>
#       <th style="text-align:center">Lines</th>
#       <th style="text-align:center">Proofs</th>
#       <th style="text-align:center">Comment</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th style="text-align:center"></th>
#       <td style="text-align:left">$\color{blue}B$</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">GOAL</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#     </tr>
#     <tr>
#       <th style="text-align:center">1</th>
#       <td style="text-align:left"></td>
#       <td style="text-align:left">1</td>
#       <td style="text-align:left">1</td>
#       <td style="text-align:left">Premise</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left">STOPPED: The subproof is not available.</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# <a id='possibly_elim'></a>
# ## Possibly Elimination

# %%
# test_possibly_elim_clean_1: Clean run

from IPython.display import display, Math, Markdown, Latex, display_markdown, HTML
import pandas as pd
pd.options.display.max_colwidth=500
from altrea.wffs import And, Wff, Possibly
from altrea.rules import Proof

prf = Proof()
prf.setrestricted(True)
A = prf.proposition("A")
prf.setlogic()

prf.goal(Possibly(A))

prf.openstrictsubproof()
prf.hypothesis(A)
prf.closestrictsubproof()
prf.possibly_elim()

display(prf.thisproof())
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th style="text-align:center"></th>
#       <th style="text-align:center">Item</th>
#       <th style="text-align:center">Level</th>
#       <th style="text-align:center">Proof</th>
#       <th style="text-align:center">Rule</th>
#       <th style="text-align:center">Type</th>
#       <th style="text-align:center">Lines</th>
#       <th style="text-align:center">Proofs</th>
#       <th style="text-align:center">Comment</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th style="text-align:center"></th>
#       <td style="text-align:left">$\color{blue}\Diamond~ A$</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">GOAL</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#     </tr>
#     <tr>
#       <th style="text-align:center">1</th>
#       <td style="text-align:left">$\Vert\hspace{0.35cm} $$A$</td>
#       <td style="text-align:left">1</td>
#       <td style="text-align:left">1</td>
#       <td style="text-align:left">Hypothesis</td>
#       <td style="text-align:left">HYPO</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#     </tr>
#     <tr>
#       <th style="text-align:center">2</th>
#       <td style="text-align:left">$\color{blue}\Diamond~ A$</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">Possibly Elim</td>
#       <td style="text-align:left">TR</td>
#       <td style="text-align:left">1</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left">COMPLETE</td>
#     </tr>
#   </tbody>
# </table>

# %%
# test_possibly_elim_ruleclass_1: Error: ruleclass

from IPython.display import display, Math, Markdown, Latex, display_markdown, HTML
import pandas as pd
pd.options.display.max_colwidth=500
from altrea.wffs import And, Wff, Possibly
from altrea.rules import Proof

prf = Proof()
prf.setrestricted(True)
A = prf.proposition("A")
prf.setlogic()

prf.goal(Possibly(A))

prf.openstrictsubproof()
prf.hypothesis(A)
prf.proofrules = prf.rule_axiomatic
prf.possibly_elim()

display(prf.thisproof())
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th style="text-align:center"></th>
#       <th style="text-align:center">Item</th>
#       <th style="text-align:center">Level</th>
#       <th style="text-align:center">Proof</th>
#       <th style="text-align:center">Rule</th>
#       <th style="text-align:center">Type</th>
#       <th style="text-align:center">Lines</th>
#       <th style="text-align:center">Proofs</th>
#       <th style="text-align:center">Comment</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th style="text-align:center"></th>
#       <td style="text-align:left">$\color{blue}\Diamond~ A$</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">GOAL</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#     </tr>
#     <tr>
#       <th style="text-align:center">1</th>
#       <td style="text-align:left">$\Vert\hspace{0.35cm} $$A$</td>
#       <td style="text-align:left">1</td>
#       <td style="text-align:left">1</td>
#       <td style="text-align:left">Hypothesis</td>
#       <td style="text-align:left">HYPO</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#     </tr>
#     <tr>
#       <th style="text-align:center">2</th>
#       <td style="text-align:left"></td>
#       <td style="text-align:left">1</td>
#       <td style="text-align:left">1</td>
#       <td style="text-align:left">Possibly Elim</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left">STOPPED: This inference rule is not part of the selected set of rules.</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# <a id='possibly_intro'></a>
# ## Possibly Introduction

# %%
# test_possibly_intro_clean_1: Clean run

from IPython.display import display, Math, Markdown, Latex, display_markdown, HTML
import pandas as pd
pd.options.display.max_colwidth=500
from altrea.wffs import And, Wff
from altrea.rules import Proof

prf = Proof()
prf.setrestricted(True)
A = prf.proposition("A")
prf.setlogic()
prf.goal(Possibly(A))
prf.premise(A)
prf.rule("pos intro", [A], [1])

display(prf.thisproof())
# Out:
#                         Item  Level  Proof            Rule  Type Lines Proofs  \
#    $\color{blue}\Diamond~ A$      0      0            GOAL
# 1                        $A$      0      0         Premise  PREM
# 2  $\color{blue}\Diamond~ A$      0      0  Possibly Intro  RULE     1
#
#     Comment
#
# 1
# 2  COMPLETE

# %%
# test_possibly_intro_nosuchline_1: Error: nosuchline

from IPython.display import display, Math, Markdown, Latex, display_markdown, HTML
import pandas as pd
pd.options.display.max_colwidth=500
from altrea.wffs import And, Wff
from altrea.rules import Proof

prf = Proof()
prf.setrestricted(True)
A = prf.proposition("A")
prf.setlogic()
prf.goal(Possibly(A))
prf.premise(A)
prf.rule("pos intro", [A], [2])

display(prf.thisproof())
# Out:
#                         Item  Level  Proof            Rule  Type Lines Proofs  \
#    $\color{blue}\Diamond~ A$      0      0            GOAL
# 1                        $A$      0      0         Premise  PREM
# 2                                 0      0  Possibly Intro           2
#
#                                                              Comment
#
# 1
# 2  STOPPED: The referenced line is not a previous line of the proof.

# %%
# test_possibly_intro_linescope_1: Error: linescope

from IPython.display import display, Math, Markdown, Latex, display_markdown, HTML
import pandas as pd
pd.options.display.max_colwidth=500
from altrea.wffs import And, Wff
from altrea.rules import Proof

prf = Proof()
prf.setrestricted(True)
A = prf.proposition("A")
prf.setlogic()

prf.goal(A)

prf.opensubproof()
prf.hypothesis(A)
prf.closesubproof()
prf.implication_intro()
prf.rule("pos intro", [A], [1])

display(prf.thisproof())
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th style="text-align:center"></th>
#       <th style="text-align:center">Item</th>
#       <th style="text-align:center">Level</th>
#       <th style="text-align:center">Proof</th>
#       <th style="text-align:center">Rule</th>
#       <th style="text-align:center">Type</th>
#       <th style="text-align:center">Lines</th>
#       <th style="text-align:center">Proofs</th>
#       <th style="text-align:center">Comment</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th style="text-align:center"></th>
#       <td style="text-align:left">$\color{blue}A$</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">GOAL</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#     </tr>
#     <tr>
#       <th style="text-align:center">1</th>
#       <td style="text-align:left">$|\hspace{0.35cm} $$A$</td>
#       <td style="text-align:left">1</td>
#       <td style="text-align:left">1</td>
#       <td style="text-align:left">Hypothesis</td>
#       <td style="text-align:left">HYPO</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#     </tr>
#     <tr>
#       <th style="text-align:center">2</th>
#       <td style="text-align:left">$A \supset  A$</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">Implication Intro</td>
#       <td style="text-align:left">TR</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left">1-1</td>
#       <td style="text-align:left"></td>
#     </tr>
#     <tr>
#       <th style="text-align:center">3</th>
#       <td style="text-align:left"></td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">Possibly Intro</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left">1</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left">STOPPED: Referenced item is out of scope.</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# <a id='premise'></a>
# ## Premise

# %%
# test_premise_clean_1: Clean run.

from IPython.display import display, Math, Markdown, Latex, display_markdown, HTML
import pandas as pd
pd.options.display.max_colwidth=500
from altrea.wffs import And, Wff, Not
from altrea.rules import Proof

prf = Proof()
A = prf.proposition("A")
prf.setlogic()
prf.goal(Not(Not(A)))
prf.premise(A)
prf.premise(Not(A))

display(prf.thisproof())
# Out:
#                           Item  Level  Proof     Rule  Type Lines Proofs  \
#    $\color{blue}\lnot~\lnot~A$      0      0     GOAL
# 1             $\color{green}A$      0      0  Premise  PREM
# 2       $\color{green}\lnot~A$      0      0  Premise  PREM
#
#              Comment
#
# 1
# 2  GOAL CONTRADICTED

# %%
# test_premise_notwff_1: The input item cannot be a string

from IPython.display import display, Math, Markdown, Latex, display_markdown, HTML
import pandas as pd
pd.options.display.max_colwidth=500
from altrea.wffs import And, Wff
from altrea.rules import Proof

prf = Proof()
A = prf.proposition("A")
prf.setlogic()
prf.goal(Not(Not(A)))
prf.premise("A")

display(prf.thisproof())
# Out:
#                           Item  Level  Proof     Rule Type Lines Proofs  \
#    $\color{blue}\lnot~\lnot~A$      0      0     GOAL
# 1                                   0      0  Premise
#
#                                                     Comment
#
# 1  STOPPED: The input is not an instance of the Wff object.

# %%
# test_premise_nogoal_1: A goal must first be set.

from IPython.display import display, Math, Markdown, Latex, display_markdown, HTML
import pandas as pd
pd.options.display.max_colwidth=500
from altrea.wffs import And, Wff
from altrea.rules import Proof

prf = Proof()
A = prf.proposition("A")
prf.setlogic()
# prf.goal(Not(Not(A)))
prf.premise(A)

display(prf.thisproof())
# Out:
#   Item  Level  Proof     Rule Type Lines Proofs  \
#             0      0
# 1           0      0  Premise
#
#                                         Comment
#
# 1  STOPPED: The proof does not yet have a goal.

# %%
# test_premise_ruleclass_1: Error: rule_axiomatic does not allow a natural deduction structure

from IPython.display import display, Math, Markdown, Latex, display_markdown, HTML
import pandas as pd
pd.options.display.max_colwidth=500
from altrea.wffs import *
from altrea.rules import Proof

prf = Proof()
prf.setrestricted(True)
A = prf.proposition("A")
prf.proofrules = prf.rule_axiomatic
prf.setlogic()
prf.goal(Possibly(A))
prf.premise(A)
prf.rule("pos intro", [A], [1])

display(prf.thisproof())
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th style="text-align:center"></th>
#       <th style="text-align:center">Item</th>
#       <th style="text-align:center">Level</th>
#       <th style="text-align:center">Proof</th>
#       <th style="text-align:center">Rule</th>
#       <th style="text-align:center">Type</th>
#       <th style="text-align:center">Lines</th>
#       <th style="text-align:center">Proofs</th>
#       <th style="text-align:center">Comment</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th style="text-align:center"></th>
#       <td style="text-align:left">$\color{blue}\Diamond~ A$</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">GOAL</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#     </tr>
#     <tr>
#       <th style="text-align:center">1</th>
#       <td style="text-align:left"></td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">Premise</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left">STOPPED: This inference rule is not part of the selected set of rules.</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# <a id='proposition'></a>
# ## Proposition

# %%
# test_proposition_clean_1: Clean run

from IPython.display import display, Math, Markdown, Latex, display_markdown, HTML
import pandas as pd
pd.options.display.max_colwidth=500
from altrea.wffs import And, Wff
from altrea.rules import Proof

prf = Proof()
A = prf.proposition("A", "\\alpha ")
B = prf.proposition("B", "\\textbf{\u05e9}")
主 = prf.proposition("主")
samsonisgood = prf.proposition("Samson_is_good", "\\textbf{Samson is good}")
prf.setlogic()
prf.goal(A)
prf.premise(B)
prf.premise(主)
prf.premise(samsonisgood)
prf.rule("conj intro", [prf.item(1), samsonisgood], [1, 3])
#prf.conjunction_intro(1, 3)

display(prf.thisproof())
# Out:
#                                                        Item  Level  Proof  \
#                                       $\color{blue}\alpha $      0      0
# 1                                 $\color{green}\textbf{ש}$      0      0
# 2                                          $\color{green}主$      0      0
# 3                    $\color{green}\textbf{Samson is good}$      0      0
# 4  $\color{green}\textbf{ש} \wedge \textbf{Samson is good}$      0      0
#
#                 Rule  Type Lines Proofs Comment
#                 GOAL
# 1            Premise  PREM
# 2            Premise  PREM
# 3            Premise  PREM
# 4  Conjunction Intro  RULE  1, 3

# %% [markdown]
# <a id='reiterate'></a>
# ## Reiterate

# %%
# test_reiterate_clean_1: Clean run.

from IPython.display import display, Math, Markdown, Latex, display_markdown, HTML
import pandas as pd
pd.options.display.max_colwidth=500
from altrea.wffs import And, Wff, Not
from altrea.rules import Proof

prf = Proof()
A = prf.proposition("A")
prf.setlogic()

prf.goal(Not(Not(A)))
prf.premise(A)

prf.opensubproof()
prf.hypothesis(Not(A))
prf.reiterate(1)

display(prf.thisproof())
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th style="text-align:center"></th>
#       <th style="text-align:center">Item</th>
#       <th style="text-align:center">Level</th>
#       <th style="text-align:center">Proof</th>
#       <th style="text-align:center">Rule</th>
#       <th style="text-align:center">Type</th>
#       <th style="text-align:center">Lines</th>
#       <th style="text-align:center">Proofs</th>
#       <th style="text-align:center">Comment</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th style="text-align:center"></th>
#       <td style="text-align:left">$\color{blue}\lnot~\lnot~A$</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">GOAL</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#     </tr>
#     <tr>
#       <th style="text-align:center">1</th>
#       <td style="text-align:left">$\color{green}A$</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">Premise</td>
#       <td style="text-align:left">PREM</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#     </tr>
#     <tr>
#       <th style="text-align:center">2</th>
#       <td style="text-align:left">$|\hspace{0.35cm} $$\color{green}\lnot~A$</td>
#       <td style="text-align:left">1</td>
#       <td style="text-align:left">1</td>
#       <td style="text-align:left">Hypothesis</td>
#       <td style="text-align:left">HYPO</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#     </tr>
#     <tr>
#       <th style="text-align:center">3</th>
#       <td style="text-align:left">$|\hspace{0.35cm} $$\color{green}A$</td>
#       <td style="text-align:left">1</td>
#       <td style="text-align:left">1</td>
#       <td style="text-align:left">Reiteration</td>
#       <td style="text-align:left">REIT</td>
#       <td style="text-align:left">1</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#     </tr>
#   </tbody>
# </table>

# %%
# test_reiterate_nosuchline_1: The line does not exist in the proof.

from IPython.display import display, Math, Markdown, Latex, display_markdown, HTML
import pandas as pd
pd.options.display.max_colwidth=500
from altrea.wffs import And, Wff, Not
from altrea.rules import Proof

prf = Proof()
A = prf.proposition("A")
prf.setlogic()

prf.goal(Not(Not(A)))
prf.premise(A)

prf.opensubproof()
prf.hypothesis(Not(A))
prf.reiterate(10)

display(prf.thisproof())
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th style="text-align:center"></th>
#       <th style="text-align:center">Item</th>
#       <th style="text-align:center">Level</th>
#       <th style="text-align:center">Proof</th>
#       <th style="text-align:center">Rule</th>
#       <th style="text-align:center">Type</th>
#       <th style="text-align:center">Lines</th>
#       <th style="text-align:center">Proofs</th>
#       <th style="text-align:center">Comment</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th style="text-align:center"></th>
#       <td style="text-align:left">$\color{blue}\lnot~\lnot~A$</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">GOAL</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#     </tr>
#     <tr>
#       <th style="text-align:center">1</th>
#       <td style="text-align:left">$A$</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">Premise</td>
#       <td style="text-align:left">PREM</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#     </tr>
#     <tr>
#       <th style="text-align:center">2</th>
#       <td style="text-align:left">$|\hspace{0.35cm} $$\lnot~A$</td>
#       <td style="text-align:left">1</td>
#       <td style="text-align:left">1</td>
#       <td style="text-align:left">Hypothesis</td>
#       <td style="text-align:left">HYPO</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#     </tr>
#     <tr>
#       <th style="text-align:center">3</th>
#       <td style="text-align:left"></td>
#       <td style="text-align:left">1</td>
#       <td style="text-align:left">1</td>
#       <td style="text-align:left">Reiteration</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left">10</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left">STOPPED: The referenced line is not a previous line of the proof.</td>
#     </tr>
#   </tbody>
# </table>

# %%
# test_reiterate_notreiteratescope_1: The line is not accessible.

from IPython.display import display, Math, Markdown, Latex, display_markdown, HTML
import pandas as pd
pd.options.display.max_colwidth=500
from altrea.wffs import *
from altrea.rules import Proof

prf = Proof()
A = prf.proposition("A")
prf.setlogic()

prf.goal(Not(Not(A)))

prf.opensubproof()
prf.hypothesis(A)
prf.closesubproof()
prf.implication_intro()
prf.reiterate(1)

display(prf.thisproof())
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th style="text-align:center"></th>
#       <th style="text-align:center">Item</th>
#       <th style="text-align:center">Level</th>
#       <th style="text-align:center">Proof</th>
#       <th style="text-align:center">Rule</th>
#       <th style="text-align:center">Type</th>
#       <th style="text-align:center">Lines</th>
#       <th style="text-align:center">Proofs</th>
#       <th style="text-align:center">Comment</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th style="text-align:center"></th>
#       <td style="text-align:left">$\color{blue}\lnot~\lnot~A$</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">GOAL</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#     </tr>
#     <tr>
#       <th style="text-align:center">1</th>
#       <td style="text-align:left">$|\hspace{0.35cm} $$A$</td>
#       <td style="text-align:left">1</td>
#       <td style="text-align:left">1</td>
#       <td style="text-align:left">Hypothesis</td>
#       <td style="text-align:left">HYPO</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#     </tr>
#     <tr>
#       <th style="text-align:center">2</th>
#       <td style="text-align:left">$A \supset  A$</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">Implication Intro</td>
#       <td style="text-align:left">TR</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left">1-1</td>
#       <td style="text-align:left"></td>
#     </tr>
#     <tr>
#       <th style="text-align:center">3</th>
#       <td style="text-align:left"></td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">Reiteration</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left">1</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left">STOPPED: The referenced item is not in the reiterate scope.</td>
#     </tr>
#   </tbody>
# </table>

# %%
# test_reiterate_notreiteratescope_2: The line cannot be reiterated because it is already in the same proofid.

from IPython.display import display, Math, Markdown, Latex, display_markdown, HTML
import pandas as pd
pd.options.display.max_colwidth=500
from altrea.wffs import And, Wff
from altrea.rules import Proof

prf = Proof()
A = prf.proposition("A")
prf.setlogic()

prf.goal(Not(Not(A)))

prf.opensubproof()
prf.hypothesis(A)
prf.reiterate(1)

display(prf.thisproof())
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th style="text-align:center"></th>
#       <th style="text-align:center">Item</th>
#       <th style="text-align:center">Level</th>
#       <th style="text-align:center">Proof</th>
#       <th style="text-align:center">Rule</th>
#       <th style="text-align:center">Type</th>
#       <th style="text-align:center">Lines</th>
#       <th style="text-align:center">Proofs</th>
#       <th style="text-align:center">Comment</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th style="text-align:center"></th>
#       <td style="text-align:left">$\color{blue}\lnot~\lnot~A$</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">GOAL</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#     </tr>
#     <tr>
#       <th style="text-align:center">1</th>
#       <td style="text-align:left">$|\hspace{0.35cm} $$A$</td>
#       <td style="text-align:left">1</td>
#       <td style="text-align:left">1</td>
#       <td style="text-align:left">Hypothesis</td>
#       <td style="text-align:left">HYPO</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#     </tr>
#     <tr>
#       <th style="text-align:center">2</th>
#       <td style="text-align:left"></td>
#       <td style="text-align:left">1</td>
#       <td style="text-align:left">1</td>
#       <td style="text-align:left">Reiteration</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left">1</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left">STOPPED: The referenced item is not in the reiterate scope.</td>
#     </tr>
#   </tbody>
# </table>

# %%
# test_reiterate_notreiteratescope_3: The line cannot be reiterated because it is already in the same proofid.

from IPython.display import display, Math, Markdown, Latex, display_markdown, HTML
import pandas as pd
pd.options.display.max_colwidth=500
from altrea.wffs import And, Wff
from altrea.rules import Proof

prf = Proof()
A = prf.proposition("A")
prf.setlogic()
prf.goal(Not(Not(A)))
prf.premise(A)
prf.reiterate(1)

display(prf.thisproof())
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th style="text-align:center"></th>
#       <th style="text-align:center">Item</th>
#       <th style="text-align:center">Level</th>
#       <th style="text-align:center">Proof</th>
#       <th style="text-align:center">Rule</th>
#       <th style="text-align:center">Type</th>
#       <th style="text-align:center">Lines</th>
#       <th style="text-align:center">Proofs</th>
#       <th style="text-align:center">Comment</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th style="text-align:center"></th>
#       <td style="text-align:left">$\color{blue}\lnot~\lnot~A$</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">GOAL</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#     </tr>
#     <tr>
#       <th style="text-align:center">1</th>
#       <td style="text-align:left">$A$</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">Premise</td>
#       <td style="text-align:left">PREM</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#     </tr>
#     <tr>
#       <th style="text-align:center">2</th>
#       <td style="text-align:left"></td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">Reiteration</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left">1</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left">STOPPED: The referenced item is not in the reiterate scope.</td>
#     </tr>
#   </tbody>
# </table>

# %%
print(prf.subproofavailable)
# Out:
# []

# %%
# test_reiterate_notreiteratescope_4: The line cannot be reiterated because it is at a proof id not in the chain of previous proofs.

from IPython.display import display, Math, Markdown, Latex, display_markdown, HTML
import pandas as pd
pd.options.display.max_colwidth=500
from altrea.wffs import And, Wff
from altrea.rules import Proof

prf = Proof()
A = prf.proposition("A")
B = prf.proposition("B")
C = prf.proposition("C")
prf.setlogic()

prf.goal(Not(Not(A)))

prf.opensubproof()
prf.hypothesis(A)
prf.opensubproof()
prf.hypothesis(B)
prf.closesubproof()
prf.implication_intro()
prf.opensubproof()
prf.hypothesis(C)
prf.reiterate(2)

display(prf.thisproof())
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th style="text-align:center"></th>
#       <th style="text-align:center">Item</th>
#       <th style="text-align:center">Level</th>
#       <th style="text-align:center">Proof</th>
#       <th style="text-align:center">Rule</th>
#       <th style="text-align:center">Type</th>
#       <th style="text-align:center">Lines</th>
#       <th style="text-align:center">Proofs</th>
#       <th style="text-align:center">Comment</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th style="text-align:center"></th>
#       <td style="text-align:left">$\color{blue}\lnot~\lnot~A$</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">GOAL</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#     </tr>
#     <tr>
#       <th style="text-align:center">1</th>
#       <td style="text-align:left">$|\hspace{0.35cm} $$A$</td>
#       <td style="text-align:left">1</td>
#       <td style="text-align:left">1</td>
#       <td style="text-align:left">Hypothesis</td>
#       <td style="text-align:left">HYPO</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#     </tr>
#     <tr>
#       <th style="text-align:center">2</th>
#       <td style="text-align:left">$|\hspace{0.35cm} $$|\hspace{0.35cm} $$B$</td>
#       <td style="text-align:left">2</td>
#       <td style="text-align:left">2</td>
#       <td style="text-align:left">Hypothesis</td>
#       <td style="text-align:left">HYPO</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#     </tr>
#     <tr>
#       <th style="text-align:center">3</th>
#       <td style="text-align:left">$|\hspace{0.35cm} $$B \supset  B$</td>
#       <td style="text-align:left">1</td>
#       <td style="text-align:left">1</td>
#       <td style="text-align:left">Implication Intro</td>
#       <td style="text-align:left">TR</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left">2-2</td>
#       <td style="text-align:left"></td>
#     </tr>
#     <tr>
#       <th style="text-align:center">4</th>
#       <td style="text-align:left">$|\hspace{0.35cm} $$|\hspace{0.35cm} $$C$</td>
#       <td style="text-align:left">2</td>
#       <td style="text-align:left">3</td>
#       <td style="text-align:left">Hypothesis</td>
#       <td style="text-align:left">HYPO</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#     </tr>
#     <tr>
#       <th style="text-align:center">5</th>
#       <td style="text-align:left"></td>
#       <td style="text-align:left">2</td>
#       <td style="text-align:left">3</td>
#       <td style="text-align:left">Reiteration</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left">2</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left">STOPPED: The referenced item is not in the reiterate scope.</td>
#     </tr>
#   </tbody>
# </table>

# %%
# test_reiterate_strict_notreiteratescope_5: The line cannot be reiterated because it is at a proof id not in the chain of previous proofs.

from IPython.display import display, Math, Markdown, Latex, display_markdown, HTML
import pandas as pd
pd.options.display.max_colwidth=500
from altrea.wffs import And, Wff, Not
from altrea.rules import Proof

prf = Proof()
A = prf.proposition("A")
prf.setlogic()

prf.goal(Not(Not(A)))
prf.premise(A)

prf.openstrictsubproof()
prf.reiterate(1)

display(prf.thisproof())
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th style="text-align:center"></th>
#       <th style="text-align:center">Item</th>
#       <th style="text-align:center">Level</th>
#       <th style="text-align:center">Proof</th>
#       <th style="text-align:center">Rule</th>
#       <th style="text-align:center">Type</th>
#       <th style="text-align:center">Lines</th>
#       <th style="text-align:center">Proofs</th>
#       <th style="text-align:center">Comment</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th style="text-align:center"></th>
#       <td style="text-align:left">$\color{blue}\lnot~\lnot~A$</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">GOAL</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#     </tr>
#     <tr>
#       <th style="text-align:center">1</th>
#       <td style="text-align:left">$A$</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">Premise</td>
#       <td style="text-align:left">PREM</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#     </tr>
#     <tr>
#       <th style="text-align:center">2</th>
#       <td style="text-align:left"></td>
#       <td style="text-align:left">1</td>
#       <td style="text-align:left">1</td>
#       <td style="text-align:left">Reiteration</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left">1</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left">STOPPED: The referenced item is not necessary.</td>
#     </tr>
#   </tbody>
# </table>

# %%
# test_reiterate_strict_notreiteratescope_6: The line cannot be reiterated because it is at a proof id not in the chain of previous proofs.

from IPython.display import display, Math, Markdown, Latex, display_markdown, HTML
import pandas as pd
pd.options.display.max_colwidth=500
from altrea.wffs import And, Wff, Not, Necessary
from altrea.rules import Proof

prf = Proof()
A = prf.proposition("A")
B = prf.proposition("B")
prf.setlogic()

prf.goal(Not(Not(A)))
prf.premise(Necessary(A))
prf.premise(B)

prf.openstrictsubproof()
prf.reiterate(1)
prf.reiterate(2)

display(prf.thisproof())
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th style="text-align:center"></th>
#       <th style="text-align:center">Item</th>
#       <th style="text-align:center">Level</th>
#       <th style="text-align:center">Proof</th>
#       <th style="text-align:center">Rule</th>
#       <th style="text-align:center">Type</th>
#       <th style="text-align:center">Lines</th>
#       <th style="text-align:center">Proofs</th>
#       <th style="text-align:center">Comment</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th style="text-align:center"></th>
#       <td style="text-align:left">$\color{blue}\lnot~\lnot~A$</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">GOAL</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#     </tr>
#     <tr>
#       <th style="text-align:center">1</th>
#       <td style="text-align:left">$\Box~ A$</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">Premise</td>
#       <td style="text-align:left">PREM</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#     </tr>
#     <tr>
#       <th style="text-align:center">2</th>
#       <td style="text-align:left">$B$</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">Premise</td>
#       <td style="text-align:left">PREM</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#     </tr>
#     <tr>
#       <th style="text-align:center">3</th>
#       <td style="text-align:left">$\Vert\hspace{0.35cm} $$\Box~ A$</td>
#       <td style="text-align:left">1</td>
#       <td style="text-align:left">1</td>
#       <td style="text-align:left">Reiteration</td>
#       <td style="text-align:left">REIT</td>
#       <td style="text-align:left">1</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#     </tr>
#     <tr>
#       <th style="text-align:center">4</th>
#       <td style="text-align:left"></td>
#       <td style="text-align:left">1</td>
#       <td style="text-align:left">1</td>
#       <td style="text-align:left">Reiteration</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left">2</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left">STOPPED: The referenced item is not necessary.</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# <a id='setlogic'></a>
# ## Set Logic

# %%
# test_setlogic_clean_1: Clean run

from IPython.display import display, Math, Markdown, Latex, display_markdown, HTML
import pandas as pd
pd.options.display.max_colwidth=500
from altrea.wffs import And, Wff
from altrea.rules import Proof

prf = Proof()
prf.setlogic()

display(prf.thisproof())
# Out:
#  Item  Level  Proof Rule Type Lines Proofs Comment
#            0      0

# %%
# test_setlogic_logicnotfound_1: Logic has been defined.

from IPython.display import display, Math, Markdown, Latex, display_markdown, HTML
import pandas as pd
pd.options.display.max_colwidth=500
from altrea.wffs import And, Wff
from altrea.rules import Proof

prf = Proof()
prf.setlogic("_?_")

display(prf.thisproof())
# Out:
#   Item  Level  Proof       Rule Type Lines Proofs  \
#             0      0
# 1           0      0  Set Logic
#
#                                           Comment
#
# 1  STOPPED: The desired logic could not be found.

# %% [markdown]
# <a id='substitution'></a>
# ## Substitution

# %%
# test_substitution_clean_1: substitution

from IPython.display import display, Math, Markdown, Latex, display_markdown, HTML
import pandas as pd
pd.options.display.max_colwidth=500
from altrea.wffs import And, Wff
from altrea.rules import Proof

prf = Proof()
prf.setrestricted(False)
prf.proofrules = prf.rule_axiomatic
B = prf.proposition("B")
C = prf.proposition("C")
prf.setlogic()
prf.goal(C)
prf.proofrules = prf.rule_naturaldeduction
prf.premise(B)
prf.proofrules = prf.rule_axiomatic
prf.substitution(1, [B], [Not(B)])

display(prf.thisproof())
# Out:
#                      Item  Level  Proof          Rule  Type Lines Proofs  \
#           $\color{blue}C$      0      0          GOAL
# 1        $\color{green}B$      0      0       Premise  PREM
# 2  $\color{green}\lnot~B$      0      0  Substitution   SUB     1
#
#   Comment
#
# 1
# 2

# %%
# test_substitution_rules_ruleclass_1

from IPython.display import display, Math, Markdown, Latex, display_markdown, HTML
import pandas as pd
pd.options.display.max_colwidth=500
from altrea.wffs import And, Wff
from altrea.rules import Proof

prf = Proof()
prf.setrestricted(False)
prf.proofrules = prf.rule_naturaldeduction
B = prf.proposition("B")
C = prf.proposition("C")
prf.setlogic()
prf.goal(C)
prf.premise(B)
prf.substitution(1, [B], [Not(B)])

display(prf.thisproof())
# Out:
#               Item  Level  Proof          Rule  Type Lines Proofs  \
#    $\color{blue}C$      0      0          GOAL
# 1              $B$      0      0       Premise  PREM
# 2                       0      0  Substitution
#
#                                                                   Comment
#
# 1
# 2  STOPPED: This inference rule is not part of the selected set of rules.

# %% [markdown]
# <a id='database'></a>
# # Database

# %% [markdown]
# <a id='addlogic'></a>
# ## Add Logic

# %%
# Set up

from altrea.wffs import Not, And, Implies
from altrea.rules import Proof
import altrea.data

logicname = "test"
logicdisplay = "testdisplay"
logicdescription = "testdescription"

connectors = [
    (logicname, "And", "Conjunction"),
    (logicname, "Or", "Disjunction"),
]
rules = [
    (
        logicname,
        "modusponens",
        "ConclusionPremises({1}, [{0}, Implies({0}, {1})])",
        "Modus Ponens",
        "Modus Ponens",
    ),
]
definitions = [
    (
        logicname,
        "not_from_notnot",
        "ConclusionPremises(Not({0}), [{0}])",
        "Not From Not Not",
        "Not Is the Same As What It Negates",
    ),
    # (logicname, 'notnot_from_not', 'ConclusionPremises({0}, [Not({0})])', 'Not Not From Not', 'Not Is the Same As What It Negates'),
]
axioms = [
    (
        logicname,
        "explosion",
        "ConclusionPremises({1}, [{0}, Not({0})])",
        "Explosion",
        "From a Contradiction Derive Anything",
    ),
    # (logicname, 'contradiction', 'ConclusionPremises(And({0}, Not({0})), [])', 'Contradiction', 'All Contradictions Are True'),
]
altrea.data.deletelogic(logicname)
# Out:
# The proofdetails table for logic test has been dropped.
# The proofs table for logic test does not exist.
# Any definitions associated with test have been deleted.
# Any axioms associated with test have been deleted.
# Any transformation rules associated with test have been deleted.
# Any connectors associated with test have been deleted.
# The record for test in the logics table has been deleted.

# %% [markdown]
# <a id="addlogic"></a>
# ## Add Logic

# %%
# clean construction
logicname = "test"
altrea.data.addlogic(
    logicname, logicdisplay, logicdescription, connectors, rules, definitions, axioms
)
# Out:
# The logics table has been loaded for logic test.
# The connectors table for logic test has been loaded.
# The rules table for logic test has been loaded.
# The definitions table for logic test has been loaded.
# The axioms table for logic test has been loaded.
# Data loaded to the altrea/data/metadata.db tables have been committed.
# The proofs table has been created in altrea/data/testdisplay.db.
# The proofdetails table has been created in altrea/data/testdisplay.db.
# Data loaded to the altrea/data/testdisplay.db tables have been committed.

# %% [markdown]
# <a id='setdblogic'></a>
# ## Set Database Logic

# %%
# test_database_setlogic_clean_1: Clean run

from IPython.display import display, Math, Markdown, Latex, display_markdown, HTML
import pandas as pd
pd.options.display.max_colwidth=500
from altrea.wffs import And, Wff
from altrea.rules import Proof

logicname = "test"

prf = Proof()
prf.setlogic(logicname)

display(prf.thisproof())
# Out:
#  Item  Level  Proof Rule Type Lines Proofs Comment
#            0      0

# %%
# test_database_setlogic_logicalreadydefined_1: Error: resetting the logic

from IPython.display import display, Math, Markdown, Latex, display_markdown, HTML
import pandas as pd
pd.options.display.max_colwidth=500
from altrea.wffs import And, Wff
from altrea.rules import Proof

logicname = 'test'

prf = Proof()
A = prf.proposition("A")
prf.setlogic(logicname)
prf.setlogic(logicname)
prf.goal(A)
prf.setlogic()

display(prf.thisproof())
# Out:
#   Item  Level  Proof       Rule Type Lines Proofs  \
#             0      0
# 1           0      0  Set Logic
#
#                                              Comment
#
# 1  STOPPED: A specified logic is already being used.

# %%
# test_database_setlogic_logicalreadydefined_2: Error: resetting the logic to empty logic

from IPython.display import display, Math, Markdown, Latex, display_markdown, HTML
import pandas as pd
pd.options.display.max_colwidth=500
from altrea.wffs import And, Wff
from altrea.rules import Proof

logicname = 'test'

A = prf.proposition("A")
prf.setlogic(logicname)
prf.setlogic()
prf.goal(A)
prf.setlogic()

display(prf.thisproof())
# Out:
#   Item  Level  Proof       Rule Type Lines Proofs  \
#             0      0
# 1           0      0  Set Logic
#
#                                              Comment
#
# 1  STOPPED: A specified logic is already being used.

# %%
# test_database_setlogic_logicnotfound_1: Error: logic not found

from IPython.display import display, Math, Markdown, Latex, display_markdown, HTML
import pandas as pd
pd.options.display.max_colwidth=500
from altrea.wffs import And, Wff
from altrea.rules import Proof

logicname = 'test'

prf = Proof()
A = prf.proposition("A")
prf.setlogic("Hi")
prf.goal(A)
prf.setlogic()

display(prf.thisproof())
# Out:
#   Item  Level  Proof       Rule Type Lines Proofs  \
#             0      0
# 1           0      0  Set Logic
#
#                                           Comment
#
# 1  STOPPED: The desired logic could not be found.

# %% [markdown]
# <a id='addaxiom'></a>
# ## Add Axiom

# %%
# test_database_axiom_1: Clean run save and use an axiom with the database.

from IPython.display import display, Math, Markdown, Latex, display_markdown, HTML
import pandas as pd
pd.options.display.max_colwidth=500
from altrea.wffs import And, Wff, Not
from altrea.rules import Proof

logicname = 'test'

prf = Proof()
A = prf.proposition("A")
C = prf.proposition("C")
prf.setlogic(logicname)
prf.saveaxiom(
    "contradiction",
    "Contradiction",
    "All Contradictions Are True",
    And(C, Not(C)),
    [],
)
prf.goal(A)
prf.axiom("contradiction", [A], comment="test comment")

display(prf.thisproof())
# Out:
# The axiom "contradiction" defined as "ConclusionPremises(And({0}, Not({0})), [])" has been loaded to the "test" database.
# SAVE AXIOM: The axiom named "contradiction" has been saved.
#                               Item  Level  Proof           Rule   Type Lines  \
#                    $\color{blue}A$      0      0           GOAL
# 1  $\color{green}A \wedge \lnot~A$      0      0  Contradiction  AXIOM
#
#   Proofs       Comment
#
# 1         test comment

# %%
# test_database_axiom_removeaxiom_1: Clean run remove axiom with error on trying to use it.

from IPython.display import display, Math, Markdown, Latex, display_markdown, HTML
import pandas as pd
pd.options.display.max_colwidth=500
from altrea.wffs import And, Wff
from altrea.rules import Proof

logicname = 'test'

prf = Proof()
A = prf.proposition("A")
prf.setlogic(logicname)
prf.removeaxiom("contradiction")
prf.goal(A)
prf.axiom("contradiction", [A])

display(prf.thisproof())
# Out:
#               Item  Level  Proof           Rule Type Lines Proofs  \
#    $\color{blue}A$      0      0           GOAL
# 1                       0      0  contradiction
#
#                                                   Comment
#
# 1  STOPPED: The referenced name is not in the axiom list.

# %% [markdown]
# <a id='saveproof'></a>
# ## Save Proof

# %%
# test_database_saveproof_1: Create a saved proof for the database without premises.

from IPython.display import display, Math, Markdown, Latex, display_markdown, HTML
import pandas as pd
pd.options.display.max_colwidth=500
from altrea.wffs import And, Wff, Not
from altrea.rules import Proof

logicname = 'test'

prf = Proof("testproof", "Special", "Trivial Proof")
B = prf.proposition("B")
prf.setlogic(logicname)
prf.saveaxiom(
    "contradiction",
    "Contradiction",
    "All Contradictions Are True",
    And(prf.mvalpha, Not(prf.mvalpha)),
    [],
)
prf.axiom("contradiction", [B], [])
prf.entailment(
    prf.mvalpha, 
    [And(prf.mvalpha, prf.mvbeta)], 
    name="conjeliml", 
    displayname= "Conjunction Elim Left", 
    description="Conjunction Elimination Left Side", 
    kind=prf.label_rule) 
prf.goal(B)
prf.rule("conjeliml", [prf.item(1).left, prf.item(1).right], [1])
prf.saveproof()

display(prf.thisproof())
# Out:
# The axiom "contradiction" defined as "ConclusionPremises(And({0}, Not({0})), [])" has been loaded to the "test" database.
# SAVE AXIOM: The axiom named "contradiction" has been saved.
# The rule "conjeliml" defined as "ConclusionPremises({0}, [And({0}, {1})])" has been loaded to the "test" database.
# SAVE RULE: The rule named "conjeliml" has been saved.
# Connecting to test using altrea/data/testdisplay.db to store proof testproof.
# The proof "testproof" has been added to "test".
# The proof details for "testproof" have been added to "test".
#                  Item  Level  Proof                   Rule   Type Lines  \
#       $\color{blue}B$      0      0                   GOAL
# 1  $B \wedge \lnot~B$      0      0          Contradiction  AXIOM
# 2     $\color{blue}B$      0      0  Conjunction Elim Left   RULE     1
#
#   Proofs   Comment
#
# 1
# 2         COMPLETE

# %%
# test_database_saveproof_withpremises_1: Create a saved proof for modus ponens

from IPython.display import display, Math, Markdown, Latex, display_markdown, HTML
import pandas as pd
pd.options.display.max_colwidth=500
from altrea.wffs import And, Wff
from altrea.rules import Proof

logicname = 'test'

prf = Proof("modusponens", "Modus Ponens", "A saved proof with premises.")
A = prf.proposition("A")
B = prf.proposition("B")
prf.setlogic(logicname)
prf.goal(B)
prf.premise(A)
prf.premise(Implies(A, B))
prf.entailment(
    prf.mvbeta, 
    [prf.mvalpha, Implies(prf.mvalpha, prf.mvbeta)], 
    name="mp", 
    displayname= "mp", 
    description="modusponens", 
    kind=prf.label_rule) 
prf.rule("mp", [A, B], [1, 2])
prf.saveproof()

display(prf.thisproof())
# Out:
# Connecting to test using altrea/data/testdisplay.db to store proof modusponens.
# The proof "modusponens" has been added to "test".
# The proof details for "modusponens" have been added to "test".
#               Item  Level  Proof     Rule  Type Lines Proofs   Comment
#    $\color{blue}B$      0      0     GOAL
# 1              $A$      0      0  Premise  PREM
# 2   $A \supset  B$      0      0  Premise  PREM
# 3  $\color{blue}B$      0      0       mp  RULE  1, 2         COMPLETE

# %%
# test_database_saveproof_noname_1: No name for the proof

from IPython.display import display, Math, Markdown, Latex, display_markdown, HTML
import pandas as pd
pd.options.display.max_colwidth=500
from altrea.wffs import And, Wff
from altrea.rules import Proof

logicname = 'test'

prf = Proof()
B = prf.proposition("B")
prf.setlogic(logicname)
prf.goal(B)
prf.premise(B)

display(prf.thisproof())
prf.saveproof()
# Out:
#               Item  Level  Proof     Rule  Type Lines Proofs   Comment
#    $\color{blue}B$      0      0     GOAL
# 1  $\color{blue}B$      0      0  Premise  PREM               COMPLETE
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[47], line 18
#      15 prf.premise(B)
#      17 display(prf.thisproof())
# ---> 18 prf.saveproof()
#
# File E:\Jupyter\AltRea\altrea\rules.py:3496, in Proof.saveproof(self, comment)
#    3494 if self.status == self.complete or self.status == self.vacuous:
#    3495     if self.name == "" or self.displayname == "" or self.description == "":
# -> 3496         raise ValueError(self.log_proofhasnoname.format(
#    3497                 self.saveproof_name.upper(),
#    3498                 self.name,
#    3499                 self.displayname,
#    3500                 self.description,
#    3501             ))
#    3502         # self.logstep(
#    3503         #     self.log_proofhasnoname.format(
#    3504         #         self.saveproof_name.upper(),
#    (...)
#    3509         # )
#    3510     else:
#    3511         howmany = altrea.data.addproof(self.proofdatafinal)
#
# ValueError: SAVE PROOF: The proof either has an empty name "" or empty displayname "" or empty description "".

# %%
# test_database_saveproof_notcomplete_1: Error: proof not yet complete  test_database_saveproof_notcomplete_1

from IPython.display import display, Math, Markdown, Latex, display_markdown, HTML
import pandas as pd
pd.options.display.max_colwidth=500
from altrea.wffs import And, Wff
from altrea.rules import Proof

logicname = 'test'

prf = Proof()
A = prf.proposition("A")
B = prf.proposition("B")
prf.setlogic(logicname)
prf.goal(B)
prf.premise(A)
prf.saveproof()

display(prf.thisproof())
# Out:
#               Item  Level  Proof        Rule  Type Lines Proofs  \
#    $\color{blue}B$      0      0        GOAL
# 1              $A$      0      0     Premise  PREM
# 2                       0      0  Save Proof
#
#                                                             Comment
#
# 1
# 2  STOPPED: The proof needs to be completed before it can be saved.

# %%
prf.saveproof()
prf.displaylog()

# %% [markdown]
# <a id='lemma'></a>
# ## Lemma

# %%
# test_database_useproof_clean_1: Clean run

from IPython.display import display, Math, Markdown, Latex, display_markdown, HTML
import pandas as pd
pd.options.display.max_colwidth=500
from altrea.wffs import And, Wff
from altrea.rules import Proof

logicname = 'test'

prf = Proof()
A = prf.proposition("A")
B = prf.proposition("B")
prf.setlogic(logicname)
prf.goal(And(A, B))
prf.lemma("testproof", [B], comment="test comment")

display(prf.thisproof())
# Out:
#                        Item  Level  Proof     Rule   Type Lines Proofs  \
#    $\color{blue}A \wedge B$      0      0     GOAL
# 1          $\color{green}B$      0      0  Special  LEMMA
#
#         Comment
#
# 1  test comment

# %%
# test_database_useproof_withpremises_1: Clean run using modus ponens, proof with premises

from IPython.display import display, Math, Markdown, Latex, display_markdown, HTML
import pandas as pd
pd.options.display.max_colwidth=500
from altrea.wffs import And, Wff, Implies
from altrea.rules import Proof

logicname = 'test'

prf = Proof()
A = prf.proposition("A")
B = prf.proposition("B")
prf.setlogic(logicname)
prf.goal(B)
prf.premise(A)
prf.premise(Implies(A, B))
prf.lemma("modusponens", [A, B], [1, 2])

display(prf.thisproof())
# Out:
#               Item  Level  Proof          Rule   Type Lines Proofs   Comment
#    $\color{blue}B$      0      0          GOAL
# 1              $A$      0      0       Premise   PREM
# 2   $A \supset  B$      0      0       Premise   PREM
# 3  $\color{blue}B$      0      0  Modus Ponens  LEMMA  1, 2         COMPLETE

# %%
# test_database_useproof_premisesdontmatch_1: Error: Premises don't match

from IPython.display import display, Math, Markdown, Latex, display_markdown, HTML
import pandas as pd
pd.options.display.max_colwidth=500
from altrea.wffs import And, Wff
from altrea.rules import Proof

logicname = 'test'

prf = Proof()
A = prf.proposition("A")
B = prf.proposition("B")
prf.setlogic(logicname)
prf.goal(B)
prf.premise(A)
prf.premise(Implies(A, B))
prf.lemma(
    "modusponens",
    [A, B],
    [
        1,
    ],
)

display(prf.thisproof())
# Out:
#               Item  Level  Proof          Rule  Type Lines Proofs  \
#    $\color{blue}B$      0      0          GOAL
# 1              $A$      0      0       Premise  PREM
# 2   $A \supset  B$      0      0       Premise  PREM
# 3                       0      0  Modus Ponens
#
#                                                      Comment
#
# 1
# 2
# 3  STOPPED: The number of premises do not match the pattern.

# %%
# test_database_lemma_notenoughsubs_1: Error: Not enough subs

from IPython.display import display, Math, Markdown, Latex, display_markdown, HTML
import pandas as pd
pd.options.display.max_colwidth=500
from altrea.wffs import And, Wff
from altrea.rules import Proof

logicname = 'test'

prf = Proof()
A = prf.proposition("A")
B = prf.proposition("B")
prf.setlogic(logicname)
prf.goal(B)
prf.premise(A)
prf.premise(Implies(A, B))
prf.lemma("modusponens", [A], [1, 2])

display(prf.thisproof())
# Out:
#               Item  Level  Proof          Rule  Type Lines Proofs  \
#    $\color{blue}B$      0      0          GOAL
# 1              $A$      0      0       Premise  PREM
# 2   $A \supset  B$      0      0       Premise  PREM
# 3                       0      0  Modus Ponens
#
#                                                                     Comment
#
# 1
# 2
# 3  STOPPED: There are not enough substitution values for the metavariables.

# %%
# test_database_lemma_notinteger_1: Error: Line number is not an integer

from IPython.display import display, Math, Markdown, Latex, display_markdown, HTML
import pandas as pd
pd.options.display.max_colwidth=500
from altrea.wffs import And, Wff
from altrea.rules import Proof

logicname = 'test'

prf = Proof()
A = prf.proposition("A")
B = prf.proposition("B")
prf.setlogic(logicname)
prf.goal(B)
prf.premise(A)
prf.premise(Implies(A, B))
prf.lemma("modusponens", [A, B], [1, 1.3])

display(prf.thisproof())
# Out:
#               Item  Level  Proof          Rule  Type Lines Proofs  \
#    $\color{blue}B$      0      0          GOAL
# 1              $A$      0      0       Premise  PREM
# 2   $A \supset  B$      0      0       Premise  PREM
# 3                       0      0  Modus Ponens         1.3
#
#                                        Comment
#
# 1
# 2
# 3  STOPPED: The line number is not an integer.

# %%
# test_database_lemma_nosuchproof_1

from IPython.display import display, Math, Markdown, Latex, display_markdown, HTML
import pandas as pd
pd.options.display.max_colwidth=500
from altrea.wffs import And, Wff
from altrea.rules import Proof

logicname = 'test'

prf = Proof()
A = prf.proposition("A")
B = prf.proposition("B")
prf.setlogic(logicname)
prf.goal(And(A, B))
prf.lemma("testpro", [B])

display(prf.thisproof())
# Out:
#                        Item  Level  Proof     Rule Type Lines Proofs  \
#    $\color{blue}A \wedge B$      0      0     GOAL
# 1                                0      0  testpro
#
#                                                                   Comment
#
# 1  STOPPED: The named saved proof does not exist in the logic's database.

# %%
# test_database_lemma_nosubs_1

from IPython.display import display, Math, Markdown, Latex, display_markdown, HTML
import pandas as pd
pd.options.display.max_colwidth=500
from altrea.wffs import And, Wff
from altrea.rules import Proof

logicname = 'test'

prf = Proof()
A = prf.proposition("A")
B = prf.proposition("B")
prf.setlogic(logicname)
prf.goal(And(A, B))
prf.lemma("testproof", [])

display(prf.thisproof())
# Out:
#                        Item  Level  Proof     Rule Type Lines Proofs  \
#    $\color{blue}A \wedge B$      0      0     GOAL
# 1                                0      0  Special
#
#                                          Comment
#
# 1  STOPPED: There were no substitutions entered.

# %%
# test_database_lemma_notwff_2

from IPython.display import display, Math, Markdown, Latex, display_markdown, HTML
import pandas as pd
pd.options.display.max_colwidth=500
from altrea.wffs import And, Wff
from altrea.rules import Proof

logicname = 'test'

prf = Proof()
A = prf.proposition("A")
B = prf.proposition("B")
prf.setlogic(logicname)
prf.goal(And(A, B))
prf.lemma("testproof", [1])

display(prf.thisproof())
# Out:
#                        Item  Level  Proof     Rule Type Lines Proofs  \
#    $\color{blue}A \wedge B$      0      0     GOAL
# 1                                0      0  Special
#
#                                                     Comment
#
# 1  STOPPED: The input is not an instance of the Wff object.

# %%
# test_database_lemma_nosuchline_1

from IPython.display import display, Math, Markdown, Latex, display_markdown, HTML
import pandas as pd
pd.options.display.max_colwidth=500
from altrea.wffs import And, Wff
from altrea.rules import Proof

logicname = 'test'

prf = Proof()
A = prf.proposition("A")
B = prf.proposition("B")
prf.setlogic(logicname)
prf.goal(B)
prf.premise(A)
prf.premise(Implies(A, B))
prf.lemma("modusponens", [A, B], [1, 4])

display(prf.thisproof())
# Out:
#               Item  Level  Proof          Rule  Type Lines Proofs  \
#    $\color{blue}B$      0      0          GOAL
# 1              $A$      0      0       Premise  PREM
# 2   $A \supset  B$      0      0       Premise  PREM
# 3                       0      0  Modus Ponens           4
#
#                                                              Comment
#
# 1
# 2
# 3  STOPPED: The referenced line is not a previous line of the proof.

# %%
# test_database_lemma_linescope_1

from IPython.display import display, Math, Markdown, Latex, display_markdown, HTML
import pandas as pd
pd.options.display.max_colwidth=500
from altrea.wffs import And, Wff
from altrea.rules import Proof

logicname = 'test'

prf = Proof()
A = prf.proposition("A")
B = prf.proposition("B")
prf.setlogic(logicname)

prf.goal(B)

prf.opensubproof()
prf.hypothesis(A)
prf.closesubproof()
prf.implication_intro()
prf.premise(Implies(A, B))
prf.lemma("modusponens", [A, B], [1, 4])

display(prf.thisproof())
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th style="text-align:center"></th>
#       <th style="text-align:center">Item</th>
#       <th style="text-align:center">Level</th>
#       <th style="text-align:center">Proof</th>
#       <th style="text-align:center">Rule</th>
#       <th style="text-align:center">Type</th>
#       <th style="text-align:center">Lines</th>
#       <th style="text-align:center">Proofs</th>
#       <th style="text-align:center">Comment</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th style="text-align:center"></th>
#       <td style="text-align:left">$\color{blue}B$</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">GOAL</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#     </tr>
#     <tr>
#       <th style="text-align:center">1</th>
#       <td style="text-align:left">$|\hspace{0.35cm} $$A$</td>
#       <td style="text-align:left">1</td>
#       <td style="text-align:left">1</td>
#       <td style="text-align:left">Hypothesis</td>
#       <td style="text-align:left">HYPO</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#     </tr>
#     <tr>
#       <th style="text-align:center">2</th>
#       <td style="text-align:left">$A \supset  A$</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">Implication Intro</td>
#       <td style="text-align:left">TR</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left">1-1</td>
#       <td style="text-align:left"></td>
#     </tr>
#     <tr>
#       <th style="text-align:center">3</th>
#       <td style="text-align:left">$A \supset  B$</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">Premise</td>
#       <td style="text-align:left">PREM</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#     </tr>
#     <tr>
#       <th style="text-align:center">4</th>
#       <td style="text-align:left"></td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">0</td>
#       <td style="text-align:left">modusponens</td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left"></td>
#       <td style="text-align:left">STOPPED: The named saved proof does not exist in the logic's database.</td>
#     </tr>
#   </tbody>
# </table>

# %%
# test_database_lemma_removeproof_1

from IPython.display import display, Math, Markdown, Latex, display_markdown, HTML
import pandas as pd
pd.options.display.max_colwidth=500
from altrea.wffs import And, Wff
from altrea.rules import Proof

logicname = 'test'

prf = Proof()
A = prf.proposition("A")
B = prf.proposition("B")
prf.setlogic(logicname)
prf.removeproof("modusponens")
prf.goal(B)
prf.premise(A)
prf.premise(Implies(A, B))
prf.lemma("modusponens", [A, B], [1, 2])

display(prf.thisproof())
# Out:
# The proof details for "modusponens" have been deleted from proofdetails for "test".
# The proof "modusponens" has been deleted from proofs for "test".
#               Item  Level  Proof         Rule  Type Lines Proofs  \
#    $\color{blue}B$      0      0         GOAL
# 1              $A$      0      0      Premise  PREM
# 2   $A \supset  B$      0      0      Premise  PREM
# 3                       0      0  modusponens
#
#                                                                   Comment
#
# 1
# 2
# 3  STOPPED: The named saved proof does not exist in the logic's database.

# %% [markdown]
# <a id='rule'></a>
# ## Use a Rule

# %%
# test_database_rule_clean_1

from IPython.display import display, Math, Markdown, Latex, display_markdown, HTML
import pandas as pd
pd.options.display.max_colwidth=500
from altrea.wffs import And, Wff
from altrea.rules import Proof

logicname = 'test'

prf = Proof()
A = prf.proposition("A")
B = prf.proposition("B")
C = prf.proposition("C")
prf.setlogic(logicname)
prf.removeproof("modusponens")
prf.goal(C)
prf.premise(A)
prf.premise(Implies(A, B))
prf.rule("modusponens", [A, B], [1, 2], "Testing")

display(prf.thisproof())
# Out:
# The proof details for "modusponens" have been deleted from proofdetails for "test".
# The proof "modusponens" has been deleted from proofs for "test".
#                           Item  Level  Proof          Rule  Type Lines Proofs  \
#                $\color{blue}C$      0      0          GOAL
# 1             $\color{green}A$      0      0       Premise  PREM
# 2  $\color{green}A \supset  B$      0      0       Premise  PREM
# 3             $\color{green}B$      0      0  Modus Ponens  RULE  1, 2
#
#    Comment
#
# 1
# 2
# 3  Testing

# %%
# test_database_rule_premisesdontmatch_1

from IPython.display import display, Math, Markdown, Latex, display_markdown, HTML
import pandas as pd
pd.options.display.max_colwidth=500
from altrea.wffs import And, Wff
from altrea.rules import Proof

logicname = 'test'

prf = Proof()
A = prf.proposition("A")
B = prf.proposition("B")
prf.setlogic(logicname)
prf.goal(B)
prf.premise(A)
prf.premise(Implies(A, B))
prf.rule(
    "modusponens",
    [A, B],
    [
        1,
    ],
)

display(prf.thisproof())
# Out:
#               Item  Level  Proof          Rule  Type Lines Proofs  \
#    $\color{blue}B$      0      0          GOAL
# 1              $A$      0      0       Premise  PREM
# 2   $A \supset  B$      0      0       Premise  PREM
# 3                       0      0  Modus Ponens
#
#                                                      Comment
#
# 1
# 2
# 3  STOPPED: The number of premises do not match the pattern.

# %%
# test_database_rule_notenoughsubs_1

from IPython.display import display, Math, Markdown, Latex, display_markdown, HTML
import pandas as pd
pd.options.display.max_colwidth=500
from altrea.wffs import And, Wff
from altrea.rules import Proof

logicname = 'test'

prf = Proof()
A = prf.proposition("A")
B = prf.proposition("B")
prf.setlogic(logicname)
prf.goal(B)
prf.premise(A)
prf.premise(Implies(A, B))
prf.rule("modusponens", [A], [1, 2])

display(prf.thisproof())
# Out:
#               Item  Level  Proof          Rule  Type Lines Proofs  \
#    $\color{blue}B$      0      0          GOAL
# 1              $A$      0      0       Premise  PREM
# 2   $A \supset  B$      0      0       Premise  PREM
# 3                       0      0  Modus Ponens
#
#                                                                     Comment
#
# 1
# 2
# 3  STOPPED: There are not enough substitution values for the metavariables.

# %%
# test_database_rule_nosuchproof_1

from IPython.display import display, Math, Markdown, Latex, display_markdown, HTML
import pandas as pd
pd.options.display.max_colwidth=500
from altrea.wffs import And, Wff
from altrea.rules import Proof

logicname = 'test'

prf = Proof()
A = prf.proposition("A")
B = prf.proposition("B")
prf.setlogic(logicname)
prf.goal(And(A, B))
prf.rule("testpro", [B])

display(prf.thisproof())
# Out:
#                        Item  Level  Proof     Rule Type Lines Proofs  \
#    $\color{blue}A \wedge B$      0      0     GOAL
# 1                                0      0  testpro
#
#                                                                   Comment
#
# 1  STOPPED: The transformation rule is not defined in the selected logic.

# %% [markdown]
# ## Substitution

# %%
# test_database_substitution_clean_1

from IPython.display import display, Math, Markdown, Latex, display_markdown, HTML
import pandas as pd
pd.options.display.max_colwidth=500
from altrea.wffs import And, Wff, Not
from altrea.rules import Proof

logicname = 'test'

prf = Proof()
prf.proofrules = prf.rule_axiomatic
prf.setrestricted(False)
A = prf.proposition("A")
B = prf.proposition("B")
prf.setlogic(logicname)
prf.goal(A)
prf.proofrules = prf.rule_naturaldeduction
prf.premise(B)
prf.proofrules = prf.rule_axiomatic
prf.substitution(1, [B], [Not(B)])

display(prf.thisproof())
# Out:
#                      Item  Level  Proof          Rule  Type Lines Proofs  \
#           $\color{blue}A$      0      0          GOAL
# 1        $\color{green}B$      0      0       Premise  PREM
# 2  $\color{green}\lnot~B$      0      0  Substitution   SUB     1
#
#   Comment
#
# 1
# 2

# %% [markdown]
# <a id='adddefinition'></a>
# ## Add Definition

# %%
# test_database_savedefinition_clean_1

from IPython.display import display, Math, Markdown, Latex, display_markdown, HTML
import pandas as pd
pd.options.display.max_colwidth=500
from altrea.wffs import And, Wff
from altrea.rules import Proof

logicname = 'test'

prf = Proof()
A = prf.proposition("A")
B = prf.proposition("B")
prf.setlogic(logicname)
prf.savedefinition(
    name="same",
    displayname="Same",
    description="One Letter Is Same As Other",
    conclusion=A,
    premise=[B],
)
prf.goal(A)
prf.premise(B)
prf.definition("same", [B, A], [1], comment="test comment")

display(prf.thisproof())
# Out:
# The definition "same" defined as "ConclusionPremises({1}, [{0}])" has been loaded to the "test" database.
# SAVE DEFINITION: The definition named "same" has been saved.
#               Item  Level  Proof     Rule  Type Lines Proofs  \
#    $\color{blue}A$      0      0     GOAL
# 1              $B$      0      0  Premise  PREM
# 2  $\color{blue}A$      0      0     Same   DEF     1
#
#                    Comment
#
# 1
# 2  COMPLETE - test comment

# %%
# test_database_definition_nosuchdefinition_1

from IPython.display import display, Math, Markdown, Latex, display_markdown, HTML
import pandas as pd
pd.options.display.max_colwidth=500
from altrea.wffs import And, Wff
from altrea.rules import Proof

logicname = 'test'

prf = Proof()
A = prf.proposition("A")
B = prf.proposition("B")
prf.setlogic(logicname)
prf.savedefinition(
    name="same",
    displayname="Same",
    description="One Letter Is Same As Other",
    conclusion=A,
    premise=[B],
)
prf.goal(A)
prf.premise(B)
prf.definition("sam", [B, A], [1])

display(prf.thisproof())
# Out:
#               Item  Level  Proof     Rule  Type Lines Proofs  \
#    $\color{blue}A$      0      0     GOAL
# 1              $B$      0      0  Premise  PREM
# 2                       0      0      sam
#
#                                                        Comment
#
# 1
# 2  STOPPED: The referenced name is not in the definition list.

# %%
# test_database_definition_premisesdontmatch_1

from IPython.display import display, Math, Markdown, Latex, display_markdown, HTML
import pandas as pd
pd.options.display.max_colwidth=500
from altrea.wffs import And, Wff
from altrea.rules import Proof

logicname = 'test'

prf = Proof()
A = prf.proposition("A")
B = prf.proposition("B")
prf.setlogic(logicname)
prf.savedefinition(
    name="same",
    displayname="Same",
    description="One Letter Is Same As Other",
    conclusion=A,
    premise=[B],
)
prf.goal(A)
prf.premise(B)
prf.definition("same", [B, A], [])

display(prf.thisproof())
# Out:
#               Item  Level  Proof     Rule  Type Lines Proofs  \
#    $\color{blue}A$      0      0     GOAL
# 1              $B$      0      0  Premise  PREM
# 2                       0      0     Same
#
#                                                      Comment
#
# 1
# 2  STOPPED: The number of premises do not match the pattern.

# %%
# test_database_definition_notenoughsubs_1

from IPython.display import display, Math, Markdown, Latex, display_markdown, HTML
import pandas as pd
pd.options.display.max_colwidth=500
from altrea.wffs import And, Wff
from altrea.rules import Proof

logicname = 'test'

prf = Proof()
A = prf.proposition("A")
B = prf.proposition("B")
prf.setlogic(logicname)
prf.savedefinition(
    name="same",
    displayname="Same",
    description="One Letter Is Same As Other",
    conclusion=A,
    premise=[B],
)
prf.goal(A)
prf.premise(B)
prf.definition("same", [B], [1])

display(prf.thisproof())
# Out:
#               Item  Level  Proof     Rule  Type Lines Proofs  \
#    $\color{blue}A$      0      0     GOAL
# 1              $B$      0      0  Premise  PREM
# 2                       0      0     Same
#
#                                                                     Comment
#
# 1
# 2  STOPPED: There are not enough substitution values for the metavariables.

# %%
# test_database_definition_notwff_1

from IPython.display import display, Math, Markdown, Latex, display_markdown, HTML
import pandas as pd
pd.options.display.max_colwidth=500
from altrea.wffs import And, Wff
from altrea.rules import Proof

logicname = 'test'

prf = Proof()
A = prf.proposition("A")
B = prf.proposition("B")
prf.setlogic(logicname)
prf.savedefinition(
    name="same",
    displayname="Same",
    description="One Letter Is Same As Other",
    conclusion=A,
    premise=[B],
)
prf.goal(A)
prf.premise(B)
prf.definition("same", [B, "A"], [1])

display(prf.thisproof())
# Out:
#               Item  Level  Proof     Rule  Type Lines Proofs  \
#    $\color{blue}A$      0      0     GOAL
# 1              $B$      0      0  Premise  PREM
# 2                       0      0     Same
#
#                                                     Comment
#
# 1
# 2  STOPPED: The input is not an instance of the Wff object.

# %%
# test_database_definition_notinteger_1

from IPython.display import display, Math, Markdown, Latex, display_markdown, HTML
import pandas as pd
pd.options.display.max_colwidth=500
from altrea.wffs import And, Wff
from altrea.rules import Proof

logicname = 'test'

prf = Proof()
A = prf.proposition("A")
B = prf.proposition("B")
prf.setlogic(logicname)
prf.savedefinition(
    name="same",
    displayname="Same",
    description="One Letter Is Same As Other",
    conclusion=A,
    premise=[B],
)
prf.goal(A)
prf.premise(B)
prf.definition("same", [B, A], [1.1])

display(prf.thisproof())
# Out:
#               Item  Level  Proof     Rule  Type Lines Proofs  \
#    $\color{blue}A$      0      0     GOAL
# 1              $B$      0      0  Premise  PREM
# 2                       0      0     Same         1.1
#
#                                        Comment
#
# 1
# 2  STOPPED: The line number is not an integer.

# %% [markdown]
# <a id='removedefinition'></a>
# ## Remove Definition

# %%
# test_database_definition_nosuchdefinition_2

from IPython.display import display, Math, Markdown, Latex, display_markdown, HTML
import pandas as pd
pd.options.display.max_colwidth=500
from altrea.wffs import And, Wff
from altrea.rules import Proof

logicname = 'test'

prf = Proof()
A = prf.proposition("A")
B = prf.proposition("B")
prf.setlogic(logicname)
prf.removedefinition(name="same")
prf.goal(A)
prf.premise(B)
prf.definition("same", [B, A], [1])

prf.displaylog()
display(prf.thisproof())
# Out:
# REMOVE DEFINITION: A definition with the name "same" was not found.
# 0 PROPOSITION: The letter "A" for a generic well-formed formula has been defined with 1 so far for this proof.
# 1 PROPOSITION: The letter "B" for a generic well-formed formula has been defined with 2 so far for this proof.
# 2 SET LOGIC: "test" has been selected as the logic described as "testdescription" and stored in database "altrea/data/testdisplay.db".
# 3 GOAL: The goal "A" has been added to the goals.
# 4 PREMISE: Item "B" has been added to the premises.
# 5 DEFINITION: The name "same" does not reference a definition.
#               Item  Level  Proof     Rule  Type Lines Proofs  \
#    $\color{blue}A$      0      0     GOAL
# 1              $B$      0      0  Premise  PREM
# 2                       0      0     same
#
#                                                        Comment
#
# 1
# 2  STOPPED: The referenced name is not in the definition list.

# %% [markdown]
# <a id='removelogic'></a>
# ## Remove Logic
